# %% [markdown]
# # K-Fold CV for Boosting Methods Using SKLearn

# %%
#Importing required libraries
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from tqdm import tqdm
import wfdb

from sklearn.model_selection import train_test_split
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from numpy import mean
from numpy import absolute
from numpy import sqrt
import pandas as pd
import random

# %%
import xgboost as xgb
from sklearn import metrics
from lightgbm import LGBMClassifier

import lightgbm
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
# Out:
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi'] = 70 #display 70 dpi in Jupyter Notebook, may consider100 dpi 
plt.rcParams['savefig.dpi'] = 300 #define 300 dpi for saving figures

import seaborn as sns
## here are some settings 
sns.set_style('whitegrid')
sns.set(rc={"figure.dpi":70, 'savefig.dpi':300}) #defining dpi setting
sns.set_context('notebook')
sns.set_style("ticks")
from IPython.display import set_matplotlib_formats

# %% [markdown]
# ### To load sklearn dataset
# sklearn.datasets.load_breast_cancer(*, return_X_y=False, as_frame=False)[source]¶
#
# Load and return the breast cancer wisconsin dataset (classification).

# %%
#data = load_breast_cancer(as_frame = True); 
#df = data.frame; 
#print(df.shape)
# In this block use the code we looked at on 6/30 as a reference to save our rr-intervals as a .
rlist = []
records = 'mit-bih-raw\RECORDS' # Replace the _______ with the name of the records file in your MIT-BIH data folder
with open(records) as rfile: #Then we open the file 
                             #The 'with' command only opens the file while we are in it. Automatically closes the file when we're not
    for record in rfile:  # Then we iterate through the lines in the file
        record = record[0:len(record)-1] # Remove any erronious new line characters at the end ('\n')
        rlist.append(record) # Then build an array with it
        

###### Step 1: Initialize all Arrays
             # Below, replace all of the ___ with the command that declares an array/list
             # hint: https://stackoverflow.com/questions/1514553/how-to-declare-an-array-in-python
samples = [] # will house the samples of all subjects
good_list = [] # will list the names of the subjects we successfully extracted
bad_list = [] # will house the names of the subjects we failed to extract
qrs = [] # will house the indices of R-Peaks for all subjects
atr_label = [] # will house the labels for each rhythm annotation for all subjects
atr_locs = [] # will house the locations corresponding to the rhythm annotation labels


###### Step 2: Extract Information
for x in tqdm(rlist): #this will iterate through te records that we found above
  
    try: # A try statement will run the except statement if for some reason the try commands fail
         # In this case I use the try statement because one of the subjects has no signal data causing failure
         # I then use bad_list and good_list so that all of the indices in rlist match with the arrays we initialized in Step 1, above
        ######################################################
            # Below find the wfdb function that will return the information that is described below 
        # Then replace _____ with the correct function call
        samp = wfdb.rdsamp('mit-bih-raw/'+x) # wfdb._____(file_location) will read the signal & header data and return a 2 value array
            # samp[0] - the signal data is the raw reading from the ecg. Each value is a sample taken.
            # samp[1] - the header data includes things about the signal data such as:
              # samples per section, denoted 'fs'
              # number of signals, denoted 'n_sig'
            
        ######################################################
        samples.append(samp) #add it to our array for all subject
            #What is our file extension that has the annotation we want? Find it here and replace _____ with it 
            #hint: READ THE VARIABLE NAMES!!!!
        qrs_tmp = wfdb.rdann('mit-bih-raw/'+x, extension='qrs') #extract the QRS Info
        qrs_locs = np.array(qrs_tmp.sample, dtype='int') #Get just the loccation of R-Peaks from the QRS Info
        qrs.append(qrs_locs) # Add to our array for all subjects
        
            #Do the same thing here
        atr = wfdb.rdann('mit-bih-raw/'+x,extension='atr') #extract the atr info which stores the rhythm type(s) over the whole signal
        atr_label.append(atr.aux_note) # aux_note stores the type of rhythm - main two are '(N' for normal and '(AFIB' for AFIB
        atr_locs.append(np.append(atr.sample, len(samp[0]))) #I add the length of the whole sample to the end for better visualization later
        
        good_list.append(x) # when all extraction is successful append the record name to good_list
    except Exception as exep:
        print(exep) # Alert the user of an exception
        bad_list.append(x) # add to the bad list
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# sampto must be greater than sampfrom
# sampto must be greater than sampfrom
# 100%|██████████| 25/25 [00:15<00:00,  1.56it/s]

# %%
features_df_list = []
for subject in good_list:
    data = pd.read_csv(f'subject-features-dataframes/subject{subject}.csv')
    data = data.assign(Subject = subject)
    #print(data)
    features_df_list.append(data)
#features_maindf = pd.concat(features_df_list, ignore_index = True)

# %%
#df.head(5)
# df.info()
# df.describe()
#features_df_list[0]
counter = 0
testing_arr = []
training_arr = []
for subject in features_df_list:
    if counter != 22:
        training_arr.append(subject)
    else:
        testing_arr.append(subject)
    counter += 1
    
print(len(training_arr))
# Out:
# 22

# %%
features_maindf = pd.concat(features_df_list, ignore_index = True)
print(features_maindf.columns)
# Out:
# Index(['Unnamed: 0', 'StoS', 'StoR', 'StoL', 'RtoS', 'RtoR', 'RtoL', 'LtoS',
#        'LtoR', 'LtoL', 'STD', 'CoefVar', 'Range', 'Volatility', 'ShEn',
#        'AppEn', 'SampEn', 'Rhythm', 'Subject'],
#       dtype='object')

# %%
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html
import lightgbm

#Implementing cross validation 
kf = KFold(n_splits=23, random_state=1, shuffle=True)


from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
n_estimators_list = []
max_depth_list = []

x_values = ['StoS', 'StoR', 'StoL', 'RtoS', 'RtoR', 'RtoL', 'LtoS',
       'LtoR', 'LtoL', 'STD', 'CoefVar', 'Range', 'Volatility', 'ShEn',
       'AppEn', 'SampEn']
y_values = ['Rhythm']
df = features_maindf

for idx, subject in enumerate(good_list):
    
    train_index = ~df['Subject'].str.contains(subject)
    test_index = df['Subject'].str.contains(subject)
    X_train , X_test = df.loc[train_index,x_values], df.loc[test_index,x_values]
    y_train , y_test = df.loc[train_index,y_values].values.ravel(), df.loc[test_index,y_values]

    temp_model = model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],eval_metric='logloss')    
    param_distributions = {'n_estimators': randint(105, 110),
                           'max_depth': randint(7,10)}

    search = RandomizedSearchCV(estimator=temp_model, param_distributions=param_distributions, random_state=0)
    search.fit(X_train, y_train)

    n_estimators_list.append(search.best_params_['n_estimators'])
    max_depth_list.append(search.best_params_['max_depth'])

#     model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],
#           eval_metric='logloss')
    model = lightgbm.LGBMClassifier(learning_rate=0.09,max_depth=search.best_params_['max_depth'],n_estimators=search.best_params_['n_estimators'], random_state=42)
    
    # Create the LightGBM data containers
    model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],
          eval_metric='logloss')

    pred_values = model.predict(X_test)
     
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list  
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)}, 
                          index = (X_train.columns))
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    #plt.savefig('plot1.png')


elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
# Out:
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618356	valid_0's binary_logloss: 0.571408
# [2]	training's binary_logloss: 0.55755	valid_0's binary_logloss: 0.521635
# [3]	training's binary_logloss: 0.505937	valid_0's binary_logloss: 0.479841
# [4]	training's binary_logloss: 0.461077	valid_0's binary_logloss: 0.444658
# [5]	training's binary_logloss: 0.422435	valid_0's binary_logloss: 0.413974
# [6]	training's binary_logloss: 0.38893	valid_0's binary_logloss: 0.388499
# [7]	training's binary_logloss: 0.359628	valid_0's binary_logloss: 0.365992
# [8]	training's binary_logloss: 0.333592	valid_0's binary_logloss: 0.347248
# [9]	training's binary_logloss: 0.310288	valid_0's binary_logloss: 0.331451
# [10]	training's binary_logloss: 0.289955	valid_0's binary_logloss: 0.316704
# [11]	training's binary_logloss: 0.271785	valid_0's binary_logloss: 0.30466
# [12]	training's binary_logloss: 0.255501	valid_0's binary_logloss: 0.293693
# [13]	training's binary_logloss: 0.240837	valid_0's binary_logloss: 0.283784
# [14]	training's binary_logloss: 0.22775	valid_0's binary_logloss: 0.275828
# [15]	training's binary_logloss: 0.21598	valid_0's binary_logloss: 0.268669
# [16]	training's binary_logloss: 0.205265	valid_0's binary_logloss: 0.262664
# [17]	training's binary_logloss: 0.195583	valid_0's binary_logloss: 0.257642
# [18]	training's binary_logloss: 0.186891	valid_0's binary_logloss: 0.253955
# [19]	training's binary_logloss: 0.178988	valid_0's binary_logloss: 0.250287
# [20]	training's binary_logloss: 0.171579	valid_0's binary_logloss: 0.246055
# [21]	training's binary_logloss: 0.164948	valid_0's binary_logloss: 0.243198
# [22]	training's binary_logloss: 0.158779	valid_0's binary_logloss: 0.24017
# [23]	training's binary_logloss: 0.153153	valid_0's binary_logloss: 0.238315
# [24]	training's binary_logloss: 0.148038	valid_0's binary_logloss: 0.237017
# [25]	training's binary_logloss: 0.143337	valid_0's binary_logloss: 0.235804
# [26]	training's binary_logloss: 0.138839	valid_0's binary_logloss: 0.235422
# [27]	training's binary_logloss: 0.134833	valid_0's binary_logloss: 0.23489
# [28]	training's binary_logloss: 0.131198	valid_0's binary_logloss: 0.234956
# [29]	training's binary_logloss: 0.127976	valid_0's binary_logloss: 0.235719
# [30]	training's binary_logloss: 0.124744	valid_0's binary_logloss: 0.236703
# [31]	training's binary_logloss: 0.121693	valid_0's binary_logloss: 0.236981
# [32]	training's binary_logloss: 0.119045	valid_0's binary_logloss: 0.237422
# [33]	training's binary_logloss: 0.116617	valid_0's binary_logloss: 0.238068
# [34]	training's binary_logloss: 0.114399	valid_0's binary_logloss: 0.237576
# [35]	training's binary_logloss: 0.112412	valid_0's binary_logloss: 0.237859
# [36]	training's binary_logloss: 0.110449	valid_0's binary_logloss: 0.238707
# [37]	training's binary_logloss: 0.108589	valid_0's binary_logloss: 0.239308
# [38]	training's binary_logloss: 0.106892	valid_0's binary_logloss: 0.240561
# [39]	training's binary_logloss: 0.10541	valid_0's binary_logloss: 0.241507
# [40]	training's binary_logloss: 0.103842	valid_0's binary_logloss: 0.242529
# [41]	training's binary_logloss: 0.102382	valid_0's binary_logloss: 0.243203
# [42]	training's binary_logloss: 0.101141	valid_0's binary_logloss: 0.243211
# [43]	training's binary_logloss: 0.0999207	valid_0's binary_logloss: 0.24374
# [44]	training's binary_logloss: 0.0987792	valid_0's binary_logloss: 0.245141
# [45]	training's binary_logloss: 0.097568	valid_0's binary_logloss: 0.245624
# [46]	training's binary_logloss: 0.0965263	valid_0's binary_logloss: 0.245333
# [47]	training's binary_logloss: 0.0955605	valid_0's binary_logloss: 0.245522
# [48]	training's binary_logloss: 0.0946074	valid_0's binary_logloss: 0.246207
# [49]	training's binary_logloss: 0.0935997	valid_0's binary_logloss: 0.247243
# [50]	training's binary_logloss: 0.0926684	valid_0's binary_logloss: 0.248311
# [51]	training's binary_logloss: 0.091886	valid_0's binary_logloss: 0.248501
# [52]	training's binary_logloss: 0.0910803	valid_0's binary_logloss: 0.249117
# [53]	training's binary_logloss: 0.0904185	valid_0's binary_logloss: 0.24943
# [54]	training's binary_logloss: 0.0897079	valid_0's binary_logloss: 0.250967
# [55]	training's binary_logloss: 0.0889824	valid_0's binary_logloss: 0.251137
# [56]	training's binary_logloss: 0.0883262	valid_0's binary_logloss: 0.251874
# [57]	training's binary_logloss: 0.0875399	valid_0's binary_logloss: 0.251896
# [58]	training's binary_logloss: 0.08696	valid_0's binary_logloss: 0.253454
# [59]	training's binary_logloss: 0.0864075	valid_0's binary_logloss: 0.254855
# [60]	training's binary_logloss: 0.0857856	valid_0's binary_logloss: 0.255505
# [61]	training's binary_logloss: 0.0852443	valid_0's binary_logloss: 0.256194
# [62]	training's binary_logloss: 0.0847203	valid_0's binary_logloss: 0.256376
# [63]	training's binary_logloss: 0.0841441	valid_0's binary_logloss: 0.257282
# [64]	training's binary_logloss: 0.0835178	valid_0's binary_logloss: 0.258187
# [65]	training's binary_logloss: 0.0830934	valid_0's binary_logloss: 0.259311
# [66]	training's binary_logloss: 0.0826018	valid_0's binary_logloss: 0.260636
# [67]	training's binary_logloss: 0.0820231	valid_0's binary_logloss: 0.260231
# [68]	training's binary_logloss: 0.0815971	valid_0's binary_logloss: 0.260457
# [69]	training's binary_logloss: 0.0811682	valid_0's binary_logloss: 0.260686
# [70]	training's binary_logloss: 0.0807191	valid_0's binary_logloss: 0.261219
# [71]	training's binary_logloss: 0.0802545	valid_0's binary_logloss: 0.262035
# [72]	training's binary_logloss: 0.0797633	valid_0's binary_logloss: 0.26194
# [73]	training's binary_logloss: 0.0792505	valid_0's binary_logloss: 0.262037
# [74]	training's binary_logloss: 0.0789179	valid_0's binary_logloss: 0.262045
# [75]	training's binary_logloss: 0.0784838	valid_0's binary_logloss: 0.263168
# [76]	training's binary_logloss: 0.0781269	valid_0's binary_logloss: 0.263171
# [77]	training's binary_logloss: 0.077788	valid_0's binary_logloss: 0.264908
# [78]	training's binary_logloss: 0.0773281	valid_0's binary_logloss: 0.265288
# [79]	training's binary_logloss: 0.0769978	valid_0's binary_logloss: 0.266321
# [80]	training's binary_logloss: 0.076544	valid_0's binary_logloss: 0.266132
# [81]	training's binary_logloss: 0.0762392	valid_0's binary_logloss: 0.266294
# [82]	training's binary_logloss: 0.0757551	valid_0's binary_logloss: 0.266484
# [83]	training's binary_logloss: 0.0753132	valid_0's binary_logloss: 0.266404
# [84]	training's binary_logloss: 0.0750424	valid_0's binary_logloss: 0.266935
# [85]	training's binary_logloss: 0.0746367	valid_0's binary_logloss: 0.267005
# [86]	training's binary_logloss: 0.0742564	valid_0's binary_logloss: 0.26758
# [87]	training's binary_logloss: 0.0739477	valid_0's binary_logloss: 0.267751
# [88]	training's binary_logloss: 0.073707	valid_0's binary_logloss: 0.2679
# [89]	training's binary_logloss: 0.0733864	valid_0's binary_logloss: 0.267644
# [90]	training's binary_logloss: 0.0731144	valid_0's binary_logloss: 0.267749
# [91]	training's binary_logloss: 0.0727821	valid_0's binary_logloss: 0.267896
# [92]	training's binary_logloss: 0.0724997	valid_0's binary_logloss: 0.267993
# [93]	training's binary_logloss: 0.072093	valid_0's binary_logloss: 0.267954
# [94]	training's binary_logloss: 0.0717777	valid_0's binary_logloss: 0.268081
# [95]	training's binary_logloss: 0.0714408	valid_0's binary_logloss: 0.268174
# [96]	training's binary_logloss: 0.0710647	valid_0's binary_logloss: 0.26817
# [97]	training's binary_logloss: 0.0707693	valid_0's binary_logloss: 0.267774
# [98]	training's binary_logloss: 0.0703727	valid_0's binary_logloss: 0.268492
# [99]	training's binary_logloss: 0.0701108	valid_0's binary_logloss: 0.268899
# [100]	training's binary_logloss: 0.0697843	valid_0's binary_logloss: 0.268959
# [101]	training's binary_logloss: 0.0694204	valid_0's binary_logloss: 0.269231
# [102]	training's binary_logloss: 0.0691587	valid_0's binary_logloss: 0.269176
# [103]	training's binary_logloss: 0.0688873	valid_0's binary_logloss: 0.270718
# [104]	training's binary_logloss: 0.0685957	valid_0's binary_logloss: 0.270364
# [105]	training's binary_logloss: 0.0682658	valid_0's binary_logloss: 0.271212
# [106]	training's binary_logloss: 0.0678927	valid_0's binary_logloss: 0.271092
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618356	valid_0's binary_logloss: 0.571408
# [2]	training's binary_logloss: 0.55755	valid_0's binary_logloss: 0.521635
# [3]	training's binary_logloss: 0.505937	valid_0's binary_logloss: 0.479841
# [4]	training's binary_logloss: 0.461077	valid_0's binary_logloss: 0.444658
# [5]	training's binary_logloss: 0.422435	valid_0's binary_logloss: 0.413974
# [6]	training's binary_logloss: 0.38893	valid_0's binary_logloss: 0.388499
# [7]	training's binary_logloss: 0.359628	valid_0's binary_logloss: 0.365992
# [8]	training's binary_logloss: 0.333592	valid_0's binary_logloss: 0.347248
# [9]	training's binary_logloss: 0.310288	valid_0's binary_logloss: 0.331451
# [10]	training's binary_logloss: 0.289955	valid_0's binary_logloss: 0.316704
# [11]	training's binary_logloss: 0.271785	valid_0's binary_logloss: 0.30466
# [12]	training's binary_logloss: 0.255501	valid_0's binary_logloss: 0.293693
# [13]	training's binary_logloss: 0.240837	valid_0's binary_logloss: 0.283784
# [14]	training's binary_logloss: 0.22775	valid_0's binary_logloss: 0.275828
# [15]	training's binary_logloss: 0.21598	valid_0's binary_logloss: 0.268669
# [16]	training's binary_logloss: 0.205265	valid_0's binary_logloss: 0.262664
# [17]	training's binary_logloss: 0.195583	valid_0's binary_logloss: 0.257642
# [18]	training's binary_logloss: 0.186891	valid_0's binary_logloss: 0.253955
# [19]	training's binary_logloss: 0.178988	valid_0's binary_logloss: 0.250287
# [20]	training's binary_logloss: 0.171579	valid_0's binary_logloss: 0.246055
# [21]	training's binary_logloss: 0.164948	valid_0's binary_logloss: 0.243198
# [22]	training's binary_logloss: 0.158779	valid_0's binary_logloss: 0.24017
# [23]	training's binary_logloss: 0.153153	valid_0's binary_logloss: 0.238315
# [24]	training's binary_logloss: 0.148038	valid_0's binary_logloss: 0.237017
# [25]	training's binary_logloss: 0.143337	valid_0's binary_logloss: 0.235804
# [26]	training's binary_logloss: 0.138839	valid_0's binary_logloss: 0.235422
# [27]	training's binary_logloss: 0.134833	valid_0's binary_logloss: 0.23489
# [28]	training's binary_logloss: 0.131198	valid_0's binary_logloss: 0.234956
# [29]	training's binary_logloss: 0.127976	valid_0's binary_logloss: 0.235719
# [30]	training's binary_logloss: 0.124744	valid_0's binary_logloss: 0.236703
# [31]	training's binary_logloss: 0.121693	valid_0's binary_logloss: 0.236981
# [32]	training's binary_logloss: 0.119045	valid_0's binary_logloss: 0.237422
# [33]	training's binary_logloss: 0.116617	valid_0's binary_logloss: 0.238068
# [34]	training's binary_logloss: 0.114399	valid_0's binary_logloss: 0.237576
# [35]	training's binary_logloss: 0.112412	valid_0's binary_logloss: 0.237859
# [36]	training's binary_logloss: 0.110449	valid_0's binary_logloss: 0.238707
# [37]	training's binary_logloss: 0.108589	valid_0's binary_logloss: 0.239308
# [38]	training's binary_logloss: 0.106892	valid_0's binary_logloss: 0.240561
# [39]	training's binary_logloss: 0.10541	valid_0's binary_logloss: 0.241507
# [40]	training's binary_logloss: 0.103842	valid_0's binary_logloss: 0.242529
# [41]	training's binary_logloss: 0.102382	valid_0's binary_logloss: 0.243203
# [42]	training's binary_logloss: 0.101141	valid_0's binary_logloss: 0.243211
# [43]	training's binary_logloss: 0.0999207	valid_0's binary_logloss: 0.24374
# [44]	training's binary_logloss: 0.0987792	valid_0's binary_logloss: 0.245141
# [45]	training's binary_logloss: 0.097568	valid_0's binary_logloss: 0.245624
# [46]	training's binary_logloss: 0.0965263	valid_0's binary_logloss: 0.245333
# [47]	training's binary_logloss: 0.0955605	valid_0's binary_logloss: 0.245522
# [48]	training's binary_logloss: 0.0946074	valid_0's binary_logloss: 0.246207
# [49]	training's binary_logloss: 0.0935997	valid_0's binary_logloss: 0.247243
# [50]	training's binary_logloss: 0.0926684	valid_0's binary_logloss: 0.248311
# [51]	training's binary_logloss: 0.091886	valid_0's binary_logloss: 0.248501
# [52]	training's binary_logloss: 0.0910803	valid_0's binary_logloss: 0.249117
# [53]	training's binary_logloss: 0.0904185	valid_0's binary_logloss: 0.24943
# [54]	training's binary_logloss: 0.0897079	valid_0's binary_logloss: 0.250967
# [55]	training's binary_logloss: 0.0889824	valid_0's binary_logloss: 0.251137
# [56]	training's binary_logloss: 0.0883262	valid_0's binary_logloss: 0.251874
# [57]	training's binary_logloss: 0.0875399	valid_0's binary_logloss: 0.251896
# [58]	training's binary_logloss: 0.08696	valid_0's binary_logloss: 0.253454
# [59]	training's binary_logloss: 0.0864075	valid_0's binary_logloss: 0.254855
# [60]	training's binary_logloss: 0.0857856	valid_0's binary_logloss: 0.255505
# [61]	training's binary_logloss: 0.0852443	valid_0's binary_logloss: 0.256194
# [62]	training's binary_logloss: 0.0847203	valid_0's binary_logloss: 0.256376
# [63]	training's binary_logloss: 0.0841441	valid_0's binary_logloss: 0.257282
# [64]	training's binary_logloss: 0.0835178	valid_0's binary_logloss: 0.258187
# [65]	training's binary_logloss: 0.0830934	valid_0's binary_logloss: 0.259311
# [66]	training's binary_logloss: 0.0826018	valid_0's binary_logloss: 0.260636
# [67]	training's binary_logloss: 0.0820231	valid_0's binary_logloss: 0.260231
# [68]	training's binary_logloss: 0.0815971	valid_0's binary_logloss: 0.260457
# [69]	training's binary_logloss: 0.0811682	valid_0's binary_logloss: 0.260686
# [70]	training's binary_logloss: 0.0807191	valid_0's binary_logloss: 0.261219
# [71]	training's binary_logloss: 0.0802545	valid_0's binary_logloss: 0.262035
# [72]	training's binary_logloss: 0.0797633	valid_0's binary_logloss: 0.26194
# [73]	training's binary_logloss: 0.0792505	valid_0's binary_logloss: 0.262037
# [74]	training's binary_logloss: 0.0789179	valid_0's binary_logloss: 0.262045
# [75]	training's binary_logloss: 0.0784838	valid_0's binary_logloss: 0.263168
# [76]	training's binary_logloss: 0.0781269	valid_0's binary_logloss: 0.263171
# [77]	training's binary_logloss: 0.077788	valid_0's binary_logloss: 0.264908
# [78]	training's binary_logloss: 0.0773281	valid_0's binary_logloss: 0.265288
# [79]	training's binary_logloss: 0.0769978	valid_0's binary_logloss: 0.266321
# [80]	training's binary_logloss: 0.076544	valid_0's binary_logloss: 0.266132
# [81]	training's binary_logloss: 0.0762392	valid_0's binary_logloss: 0.266294
# [82]	training's binary_logloss: 0.0757551	valid_0's binary_logloss: 0.266484
# [83]	training's binary_logloss: 0.0753132	valid_0's binary_logloss: 0.266404
# [84]	training's binary_logloss: 0.0750424	valid_0's binary_logloss: 0.266935
# [85]	training's binary_logloss: 0.0746367	valid_0's binary_logloss: 0.267005
# [86]	training's binary_logloss: 0.0742564	valid_0's binary_logloss: 0.26758
# [87]	training's binary_logloss: 0.0739477	valid_0's binary_logloss: 0.267751
# [88]	training's binary_logloss: 0.073707	valid_0's binary_logloss: 0.2679
# [89]	training's binary_logloss: 0.0733864	valid_0's binary_logloss: 0.267644
# [90]	training's binary_logloss: 0.0731144	valid_0's binary_logloss: 0.267749
# [91]	training's binary_logloss: 0.0727821	valid_0's binary_logloss: 0.267896
# [92]	training's binary_logloss: 0.0724997	valid_0's binary_logloss: 0.267993
# [93]	training's binary_logloss: 0.072093	valid_0's binary_logloss: 0.267954
# [94]	training's binary_logloss: 0.0717777	valid_0's binary_logloss: 0.268081
# [95]	training's binary_logloss: 0.0714408	valid_0's binary_logloss: 0.268174
# [96]	training's binary_logloss: 0.0710647	valid_0's binary_logloss: 0.26817
# [97]	training's binary_logloss: 0.0707693	valid_0's binary_logloss: 0.267774
# [98]	training's binary_logloss: 0.0703727	valid_0's binary_logloss: 0.268492
# [99]	training's binary_logloss: 0.0701108	valid_0's binary_logloss: 0.268899
# [100]	training's binary_logloss: 0.0697843	valid_0's binary_logloss: 0.268959
# [101]	training's binary_logloss: 0.0694204	valid_0's binary_logloss: 0.269231
# [102]	training's binary_logloss: 0.0691587	valid_0's binary_logloss: 0.269176
# [103]	training's binary_logloss: 0.0688873	valid_0's binary_logloss: 0.270718
# [104]	training's binary_logloss: 0.0685957	valid_0's binary_logloss: 0.270364
# [105]	training's binary_logloss: 0.0682658	valid_0's binary_logloss: 0.271212
# [106]	training's binary_logloss: 0.0678927	valid_0's binary_logloss: 0.271092
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618031	valid_0's binary_logloss: 0.587241
# [2]	training's binary_logloss: 0.557826	valid_0's binary_logloss: 0.529984
# [3]	training's binary_logloss: 0.506602	valid_0's binary_logloss: 0.481112
# [4]	training's binary_logloss: 0.462222	valid_0's binary_logloss: 0.439001
# [5]	training's binary_logloss: 0.423927	valid_0's binary_logloss: 0.403011
# [6]	training's binary_logloss: 0.390808	valid_0's binary_logloss: 0.372501
# [7]	training's binary_logloss: 0.361402	valid_0's binary_logloss: 0.344989
# [8]	training's binary_logloss: 0.335528	valid_0's binary_logloss: 0.321032
# [9]	training's binary_logloss: 0.312662	valid_0's binary_logloss: 0.299857
# [10]	training's binary_logloss: 0.292288	valid_0's binary_logloss: 0.281156
# [11]	training's binary_logloss: 0.274419	valid_0's binary_logloss: 0.264642
# [12]	training's binary_logloss: 0.258274	valid_0's binary_logloss: 0.249967
# [13]	training's binary_logloss: 0.243762	valid_0's binary_logloss: 0.237395
# [14]	training's binary_logloss: 0.230701	valid_0's binary_logloss: 0.225606
# [15]	training's binary_logloss: 0.218932	valid_0's binary_logloss: 0.215237
# [16]	training's binary_logloss: 0.208376	valid_0's binary_logloss: 0.205954
# [17]	training's binary_logloss: 0.198771	valid_0's binary_logloss: 0.19821
# [18]	training's binary_logloss: 0.190025	valid_0's binary_logloss: 0.190865
# [19]	training's binary_logloss: 0.18186	valid_0's binary_logloss: 0.184192
# [20]	training's binary_logloss: 0.174569	valid_0's binary_logloss: 0.178497
# [21]	training's binary_logloss: 0.167892	valid_0's binary_logloss: 0.173185
# [22]	training's binary_logloss: 0.161699	valid_0's binary_logloss: 0.168042
# [23]	training's binary_logloss: 0.156301	valid_0's binary_logloss: 0.163877
# [24]	training's binary_logloss: 0.151302	valid_0's binary_logloss: 0.159939
# [25]	training's binary_logloss: 0.146681	valid_0's binary_logloss: 0.156399
# [26]	training's binary_logloss: 0.142426	valid_0's binary_logloss: 0.1536
# [27]	training's binary_logloss: 0.138185	valid_0's binary_logloss: 0.150395
# [28]	training's binary_logloss: 0.134782	valid_0's binary_logloss: 0.148148
# [29]	training's binary_logloss: 0.131528	valid_0's binary_logloss: 0.14628
# [30]	training's binary_logloss: 0.128133	valid_0's binary_logloss: 0.143476
# [31]	training's binary_logloss: 0.125322	valid_0's binary_logloss: 0.141278
# [32]	training's binary_logloss: 0.122598	valid_0's binary_logloss: 0.139677
# [33]	training's binary_logloss: 0.119907	valid_0's binary_logloss: 0.137675
# [34]	training's binary_logloss: 0.1177	valid_0's binary_logloss: 0.13655
# [35]	training's binary_logloss: 0.115672	valid_0's binary_logloss: 0.13553
# [36]	training's binary_logloss: 0.113583	valid_0's binary_logloss: 0.133645
# [37]	training's binary_logloss: 0.111613	valid_0's binary_logloss: 0.132572
# [38]	training's binary_logloss: 0.109983	valid_0's binary_logloss: 0.131525
# [39]	training's binary_logloss: 0.108332	valid_0's binary_logloss: 0.130518
# [40]	training's binary_logloss: 0.106726	valid_0's binary_logloss: 0.129721
# [41]	training's binary_logloss: 0.105308	valid_0's binary_logloss: 0.128871
# [42]	training's binary_logloss: 0.104073	valid_0's binary_logloss: 0.128107
# [43]	training's binary_logloss: 0.102881	valid_0's binary_logloss: 0.127684
# [44]	training's binary_logloss: 0.101637	valid_0's binary_logloss: 0.126884
# [45]	training's binary_logloss: 0.100476	valid_0's binary_logloss: 0.12676
# [46]	training's binary_logloss: 0.0995037	valid_0's binary_logloss: 0.126529
# [47]	training's binary_logloss: 0.0984396	valid_0's binary_logloss: 0.125908
# [48]	training's binary_logloss: 0.0975251	valid_0's binary_logloss: 0.12564
# [49]	training's binary_logloss: 0.0967063	valid_0's binary_logloss: 0.125269
# [50]	training's binary_logloss: 0.0958276	valid_0's binary_logloss: 0.124447
# [51]	training's binary_logloss: 0.0950027	valid_0's binary_logloss: 0.124402
# [52]	training's binary_logloss: 0.0941942	valid_0's binary_logloss: 0.123986
# [53]	training's binary_logloss: 0.0935396	valid_0's binary_logloss: 0.123998
# [54]	training's binary_logloss: 0.0928637	valid_0's binary_logloss: 0.124037
# [55]	training's binary_logloss: 0.0920218	valid_0's binary_logloss: 0.123791
# [56]	training's binary_logloss: 0.091332	valid_0's binary_logloss: 0.123762
# [57]	training's binary_logloss: 0.0906994	valid_0's binary_logloss: 0.123492
# [58]	training's binary_logloss: 0.0901561	valid_0's binary_logloss: 0.123575
# [59]	training's binary_logloss: 0.089566	valid_0's binary_logloss: 0.123521
# [60]	training's binary_logloss: 0.0890076	valid_0's binary_logloss: 0.123421
# [61]	training's binary_logloss: 0.0883919	valid_0's binary_logloss: 0.123468
# [62]	training's binary_logloss: 0.0878229	valid_0's binary_logloss: 0.123449
# [63]	training's binary_logloss: 0.0872058	valid_0's binary_logloss: 0.123203
# [64]	training's binary_logloss: 0.0867052	valid_0's binary_logloss: 0.123236
# [65]	training's binary_logloss: 0.0861539	valid_0's binary_logloss: 0.123203
# [66]	training's binary_logloss: 0.0857701	valid_0's binary_logloss: 0.123189
# [67]	training's binary_logloss: 0.0852566	valid_0's binary_logloss: 0.122974
# [68]	training's binary_logloss: 0.0847311	valid_0's binary_logloss: 0.122943
# [69]	training's binary_logloss: 0.0843535	valid_0's binary_logloss: 0.123033
# [70]	training's binary_logloss: 0.0838119	valid_0's binary_logloss: 0.122743
# [71]	training's binary_logloss: 0.0834529	valid_0's binary_logloss: 0.122749
# [72]	training's binary_logloss: 0.0830918	valid_0's binary_logloss: 0.122778
# [73]	training's binary_logloss: 0.0826217	valid_0's binary_logloss: 0.12288
# [74]	training's binary_logloss: 0.082092	valid_0's binary_logloss: 0.122834
# [75]	training's binary_logloss: 0.0818525	valid_0's binary_logloss: 0.122899
# [76]	training's binary_logloss: 0.0814129	valid_0's binary_logloss: 0.122788
# [77]	training's binary_logloss: 0.0810452	valid_0's binary_logloss: 0.122814
# [78]	training's binary_logloss: 0.0806068	valid_0's binary_logloss: 0.122446
# [79]	training's binary_logloss: 0.0802069	valid_0's binary_logloss: 0.122468
# [80]	training's binary_logloss: 0.0798102	valid_0's binary_logloss: 0.122478
# [81]	training's binary_logloss: 0.0795881	valid_0's binary_logloss: 0.122456
# [82]	training's binary_logloss: 0.0791729	valid_0's binary_logloss: 0.122644
# [83]	training's binary_logloss: 0.0788105	valid_0's binary_logloss: 0.122609
# [84]	training's binary_logloss: 0.0783549	valid_0's binary_logloss: 0.122721
# [85]	training's binary_logloss: 0.0780976	valid_0's binary_logloss: 0.122741
# [86]	training's binary_logloss: 0.0778839	valid_0's binary_logloss: 0.123553
# [87]	training's binary_logloss: 0.0775466	valid_0's binary_logloss: 0.123711
# [88]	training's binary_logloss: 0.0771942	valid_0's binary_logloss: 0.123577
# [89]	training's binary_logloss: 0.0768374	valid_0's binary_logloss: 0.123761
# [90]	training's binary_logloss: 0.0763764	valid_0's binary_logloss: 0.123837
# [91]	training's binary_logloss: 0.0760573	valid_0's binary_logloss: 0.123915
# [92]	training's binary_logloss: 0.0757582	valid_0's binary_logloss: 0.124086
# [93]	training's binary_logloss: 0.0755285	valid_0's binary_logloss: 0.124178
# [94]	training's binary_logloss: 0.0750287	valid_0's binary_logloss: 0.124178
# [95]	training's binary_logloss: 0.074815	valid_0's binary_logloss: 0.124274
# [96]	training's binary_logloss: 0.0745265	valid_0's binary_logloss: 0.124311
# [97]	training's binary_logloss: 0.074227	valid_0's binary_logloss: 0.124272
# [98]	training's binary_logloss: 0.0739171	valid_0's binary_logloss: 0.124331
# [99]	training's binary_logloss: 0.0735876	valid_0's binary_logloss: 0.12444
# [100]	training's binary_logloss: 0.0733029	valid_0's binary_logloss: 0.124523
# [101]	training's binary_logloss: 0.0730667	valid_0's binary_logloss: 0.124567
# [102]	training's binary_logloss: 0.0727586	valid_0's binary_logloss: 0.124544
# [103]	training's binary_logloss: 0.0724675	valid_0's binary_logloss: 0.124541
# [104]	training's binary_logloss: 0.0721771	valid_0's binary_logloss: 0.124667
# [105]	training's binary_logloss: 0.071905	valid_0's binary_logloss: 0.124565
# [106]	training's binary_logloss: 0.071613	valid_0's binary_logloss: 0.124619
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618031	valid_0's binary_logloss: 0.587241
# [2]	training's binary_logloss: 0.557826	valid_0's binary_logloss: 0.529984
# [3]	training's binary_logloss: 0.506602	valid_0's binary_logloss: 0.481112
# [4]	training's binary_logloss: 0.462222	valid_0's binary_logloss: 0.439001
# [5]	training's binary_logloss: 0.423927	valid_0's binary_logloss: 0.403011
# [6]	training's binary_logloss: 0.390808	valid_0's binary_logloss: 0.372501
# [7]	training's binary_logloss: 0.361402	valid_0's binary_logloss: 0.344989
# [8]	training's binary_logloss: 0.335528	valid_0's binary_logloss: 0.321032
# [9]	training's binary_logloss: 0.312662	valid_0's binary_logloss: 0.299857
# [10]	training's binary_logloss: 0.292288	valid_0's binary_logloss: 0.281156
# [11]	training's binary_logloss: 0.274419	valid_0's binary_logloss: 0.264642
# [12]	training's binary_logloss: 0.258274	valid_0's binary_logloss: 0.249967
# [13]	training's binary_logloss: 0.243762	valid_0's binary_logloss: 0.237395
# [14]	training's binary_logloss: 0.230701	valid_0's binary_logloss: 0.225606
# [15]	training's binary_logloss: 0.218932	valid_0's binary_logloss: 0.215237
# [16]	training's binary_logloss: 0.208376	valid_0's binary_logloss: 0.205954
# [17]	training's binary_logloss: 0.198771	valid_0's binary_logloss: 0.19821
# [18]	training's binary_logloss: 0.190025	valid_0's binary_logloss: 0.190865
# [19]	training's binary_logloss: 0.18186	valid_0's binary_logloss: 0.184192
# [20]	training's binary_logloss: 0.174569	valid_0's binary_logloss: 0.178497
# [21]	training's binary_logloss: 0.167892	valid_0's binary_logloss: 0.173185
# [22]	training's binary_logloss: 0.161699	valid_0's binary_logloss: 0.168042
# [23]	training's binary_logloss: 0.156301	valid_0's binary_logloss: 0.163877
# [24]	training's binary_logloss: 0.151302	valid_0's binary_logloss: 0.159939
# [25]	training's binary_logloss: 0.146681	valid_0's binary_logloss: 0.156399
# [26]	training's binary_logloss: 0.142426	valid_0's binary_logloss: 0.1536
# [27]	training's binary_logloss: 0.138185	valid_0's binary_logloss: 0.150395
# [28]	training's binary_logloss: 0.134782	valid_0's binary_logloss: 0.148148
# [29]	training's binary_logloss: 0.131528	valid_0's binary_logloss: 0.14628
# [30]	training's binary_logloss: 0.128133	valid_0's binary_logloss: 0.143476
# [31]	training's binary_logloss: 0.125322	valid_0's binary_logloss: 0.141278
# [32]	training's binary_logloss: 0.122598	valid_0's binary_logloss: 0.139677
# [33]	training's binary_logloss: 0.119907	valid_0's binary_logloss: 0.137675
# [34]	training's binary_logloss: 0.1177	valid_0's binary_logloss: 0.13655
# [35]	training's binary_logloss: 0.115672	valid_0's binary_logloss: 0.13553
# [36]	training's binary_logloss: 0.113583	valid_0's binary_logloss: 0.133645
# [37]	training's binary_logloss: 0.111613	valid_0's binary_logloss: 0.132572
# [38]	training's binary_logloss: 0.109983	valid_0's binary_logloss: 0.131525
# [39]	training's binary_logloss: 0.108332	valid_0's binary_logloss: 0.130518
# [40]	training's binary_logloss: 0.106726	valid_0's binary_logloss: 0.129721
# [41]	training's binary_logloss: 0.105308	valid_0's binary_logloss: 0.128871
# [42]	training's binary_logloss: 0.104073	valid_0's binary_logloss: 0.128107
# [43]	training's binary_logloss: 0.102881	valid_0's binary_logloss: 0.127684
# [44]	training's binary_logloss: 0.101637	valid_0's binary_logloss: 0.126884
# [45]	training's binary_logloss: 0.100476	valid_0's binary_logloss: 0.12676
# [46]	training's binary_logloss: 0.0995037	valid_0's binary_logloss: 0.126529
# [47]	training's binary_logloss: 0.0984396	valid_0's binary_logloss: 0.125908
# [48]	training's binary_logloss: 0.0975251	valid_0's binary_logloss: 0.12564
# [49]	training's binary_logloss: 0.0967063	valid_0's binary_logloss: 0.125269
# [50]	training's binary_logloss: 0.0958276	valid_0's binary_logloss: 0.124447
# [51]	training's binary_logloss: 0.0950027	valid_0's binary_logloss: 0.124402
# [52]	training's binary_logloss: 0.0941942	valid_0's binary_logloss: 0.123986
# [53]	training's binary_logloss: 0.0935396	valid_0's binary_logloss: 0.123998
# [54]	training's binary_logloss: 0.0928637	valid_0's binary_logloss: 0.124037
# [55]	training's binary_logloss: 0.0920218	valid_0's binary_logloss: 0.123791
# [56]	training's binary_logloss: 0.091332	valid_0's binary_logloss: 0.123762
# [57]	training's binary_logloss: 0.0906994	valid_0's binary_logloss: 0.123492
# [58]	training's binary_logloss: 0.0901561	valid_0's binary_logloss: 0.123575
# [59]	training's binary_logloss: 0.089566	valid_0's binary_logloss: 0.123521
# [60]	training's binary_logloss: 0.0890076	valid_0's binary_logloss: 0.123421
# [61]	training's binary_logloss: 0.0883919	valid_0's binary_logloss: 0.123468
# [62]	training's binary_logloss: 0.0878229	valid_0's binary_logloss: 0.123449
# [63]	training's binary_logloss: 0.0872058	valid_0's binary_logloss: 0.123203
# [64]	training's binary_logloss: 0.0867052	valid_0's binary_logloss: 0.123236
# [65]	training's binary_logloss: 0.0861539	valid_0's binary_logloss: 0.123203
# [66]	training's binary_logloss: 0.0857701	valid_0's binary_logloss: 0.123189
# [67]	training's binary_logloss: 0.0852566	valid_0's binary_logloss: 0.122974
# [68]	training's binary_logloss: 0.0847311	valid_0's binary_logloss: 0.122943
# [69]	training's binary_logloss: 0.0843535	valid_0's binary_logloss: 0.123033
# [70]	training's binary_logloss: 0.0838119	valid_0's binary_logloss: 0.122743
# [71]	training's binary_logloss: 0.0834529	valid_0's binary_logloss: 0.122749
# [72]	training's binary_logloss: 0.0830918	valid_0's binary_logloss: 0.122778
# [73]	training's binary_logloss: 0.0826217	valid_0's binary_logloss: 0.12288
# [74]	training's binary_logloss: 0.082092	valid_0's binary_logloss: 0.122834
# [75]	training's binary_logloss: 0.0818525	valid_0's binary_logloss: 0.122899
# [76]	training's binary_logloss: 0.0814129	valid_0's binary_logloss: 0.122788
# [77]	training's binary_logloss: 0.0810452	valid_0's binary_logloss: 0.122814
# [78]	training's binary_logloss: 0.0806068	valid_0's binary_logloss: 0.122446
# [79]	training's binary_logloss: 0.0802069	valid_0's binary_logloss: 0.122468
# [80]	training's binary_logloss: 0.0798102	valid_0's binary_logloss: 0.122478
# [81]	training's binary_logloss: 0.0795881	valid_0's binary_logloss: 0.122456
# [82]	training's binary_logloss: 0.0791729	valid_0's binary_logloss: 0.122644
# [83]	training's binary_logloss: 0.0788105	valid_0's binary_logloss: 0.122609
# [84]	training's binary_logloss: 0.0783549	valid_0's binary_logloss: 0.122721
# [85]	training's binary_logloss: 0.0780976	valid_0's binary_logloss: 0.122741
# [86]	training's binary_logloss: 0.0778839	valid_0's binary_logloss: 0.123553
# [87]	training's binary_logloss: 0.0775466	valid_0's binary_logloss: 0.123711
# [88]	training's binary_logloss: 0.0771942	valid_0's binary_logloss: 0.123577
# [89]	training's binary_logloss: 0.0768374	valid_0's binary_logloss: 0.123761
# [90]	training's binary_logloss: 0.0763764	valid_0's binary_logloss: 0.123837
# [91]	training's binary_logloss: 0.0760573	valid_0's binary_logloss: 0.123915
# [92]	training's binary_logloss: 0.0757582	valid_0's binary_logloss: 0.124086
# [93]	training's binary_logloss: 0.0755285	valid_0's binary_logloss: 0.124178
# [94]	training's binary_logloss: 0.0750287	valid_0's binary_logloss: 0.124178
# [95]	training's binary_logloss: 0.074815	valid_0's binary_logloss: 0.124274
# [96]	training's binary_logloss: 0.0745265	valid_0's binary_logloss: 0.124311
# [97]	training's binary_logloss: 0.074227	valid_0's binary_logloss: 0.124272
# [98]	training's binary_logloss: 0.0739171	valid_0's binary_logloss: 0.124331
# [99]	training's binary_logloss: 0.0735876	valid_0's binary_logloss: 0.12444
# [100]	training's binary_logloss: 0.0733029	valid_0's binary_logloss: 0.124523
# [101]	training's binary_logloss: 0.0730667	valid_0's binary_logloss: 0.124567
# [102]	training's binary_logloss: 0.0727586	valid_0's binary_logloss: 0.124544
# [103]	training's binary_logloss: 0.0724675	valid_0's binary_logloss: 0.124541
# [104]	training's binary_logloss: 0.0721771	valid_0's binary_logloss: 0.124667
# [105]	training's binary_logloss: 0.071905	valid_0's binary_logloss: 0.124565
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618971	valid_0's binary_logloss: 0.555954
# [2]	training's binary_logloss: 0.558959	valid_0's binary_logloss: 0.494263
# [3]	training's binary_logloss: 0.507991	valid_0's binary_logloss: 0.440917
# [4]	training's binary_logloss: 0.464155	valid_0's binary_logloss: 0.395268
# [5]	training's binary_logloss: 0.425893	valid_0's binary_logloss: 0.355017
# [6]	training's binary_logloss: 0.392805	valid_0's binary_logloss: 0.319867
# [7]	training's binary_logloss: 0.363692	valid_0's binary_logloss: 0.288908
# [8]	training's binary_logloss: 0.338193	valid_0's binary_logloss: 0.261883
# [9]	training's binary_logloss: 0.315528	valid_0's binary_logloss: 0.237569
# [10]	training's binary_logloss: 0.295324	valid_0's binary_logloss: 0.216125
# [11]	training's binary_logloss: 0.277517	valid_0's binary_logloss: 0.196706
# [12]	training's binary_logloss: 0.26127	valid_0's binary_logloss: 0.179225
# [13]	training's binary_logloss: 0.247062	valid_0's binary_logloss: 0.163591
# [14]	training's binary_logloss: 0.234248	valid_0's binary_logloss: 0.149476
# [15]	training's binary_logloss: 0.222559	valid_0's binary_logloss: 0.136804
# [16]	training's binary_logloss: 0.212089	valid_0's binary_logloss: 0.125394
# [17]	training's binary_logloss: 0.202634	valid_0's binary_logloss: 0.115022
# [18]	training's binary_logloss: 0.193899	valid_0's binary_logloss: 0.10558
# [19]	training's binary_logloss: 0.18612	valid_0's binary_logloss: 0.0970949
# [20]	training's binary_logloss: 0.178849	valid_0's binary_logloss: 0.0894693
# [21]	training's binary_logloss: 0.172213	valid_0's binary_logloss: 0.0825229
# [22]	training's binary_logloss: 0.166064	valid_0's binary_logloss: 0.0761289
# [23]	training's binary_logloss: 0.16056	valid_0's binary_logloss: 0.0703196
# [24]	training's binary_logloss: 0.155452	valid_0's binary_logloss: 0.0650822
# [25]	training's binary_logloss: 0.150936	valid_0's binary_logloss: 0.0601945
# [26]	training's binary_logloss: 0.146777	valid_0's binary_logloss: 0.0557653
# [27]	training's binary_logloss: 0.142637	valid_0's binary_logloss: 0.0518168
# [28]	training's binary_logloss: 0.139155	valid_0's binary_logloss: 0.0481419
# [29]	training's binary_logloss: 0.135852	valid_0's binary_logloss: 0.0448129
# [30]	training's binary_logloss: 0.132651	valid_0's binary_logloss: 0.0417372
# [31]	training's binary_logloss: 0.12983	valid_0's binary_logloss: 0.0389251
# [32]	training's binary_logloss: 0.127238	valid_0's binary_logloss: 0.0365298
# [33]	training's binary_logloss: 0.124579	valid_0's binary_logloss: 0.034241
# [34]	training's binary_logloss: 0.122463	valid_0's binary_logloss: 0.0321325
# [35]	training's binary_logloss: 0.120425	valid_0's binary_logloss: 0.0301559
# [36]	training's binary_logloss: 0.118474	valid_0's binary_logloss: 0.0283984
# [37]	training's binary_logloss: 0.116749	valid_0's binary_logloss: 0.0268158
# [38]	training's binary_logloss: 0.115093	valid_0's binary_logloss: 0.0253637
# [39]	training's binary_logloss: 0.113528	valid_0's binary_logloss: 0.024057
# [40]	training's binary_logloss: 0.112045	valid_0's binary_logloss: 0.0229183
# [41]	training's binary_logloss: 0.110743	valid_0's binary_logloss: 0.0218876
# [42]	training's binary_logloss: 0.10937	valid_0's binary_logloss: 0.0209274
# [43]	training's binary_logloss: 0.10813	valid_0's binary_logloss: 0.0199471
# [44]	training's binary_logloss: 0.10684	valid_0's binary_logloss: 0.0189526
# [45]	training's binary_logloss: 0.105561	valid_0's binary_logloss: 0.0180333
# [46]	training's binary_logloss: 0.104374	valid_0's binary_logloss: 0.0172955
# [47]	training's binary_logloss: 0.103414	valid_0's binary_logloss: 0.0166938
# [48]	training's binary_logloss: 0.102445	valid_0's binary_logloss: 0.016028
# [49]	training's binary_logloss: 0.101553	valid_0's binary_logloss: 0.0154278
# [50]	training's binary_logloss: 0.100737	valid_0's binary_logloss: 0.0148936
# [51]	training's binary_logloss: 0.0998389	valid_0's binary_logloss: 0.014543
# [52]	training's binary_logloss: 0.0990066	valid_0's binary_logloss: 0.0142422
# [53]	training's binary_logloss: 0.0982887	valid_0's binary_logloss: 0.0139634
# [54]	training's binary_logloss: 0.0975282	valid_0's binary_logloss: 0.01355
# [55]	training's binary_logloss: 0.0966906	valid_0's binary_logloss: 0.0132372
# [56]	training's binary_logloss: 0.0960831	valid_0's binary_logloss: 0.0129778
# [57]	training's binary_logloss: 0.0954723	valid_0's binary_logloss: 0.0127005
# [58]	training's binary_logloss: 0.0948264	valid_0's binary_logloss: 0.0124171
# [59]	training's binary_logloss: 0.0941759	valid_0's binary_logloss: 0.0122515
# [60]	training's binary_logloss: 0.0936323	valid_0's binary_logloss: 0.0121176
# [61]	training's binary_logloss: 0.0930184	valid_0's binary_logloss: 0.0118599
# [62]	training's binary_logloss: 0.0925252	valid_0's binary_logloss: 0.0116778
# [63]	training's binary_logloss: 0.0919448	valid_0's binary_logloss: 0.0115126
# [64]	training's binary_logloss: 0.0913377	valid_0's binary_logloss: 0.0114191
# [65]	training's binary_logloss: 0.0908069	valid_0's binary_logloss: 0.0112938
# [66]	training's binary_logloss: 0.090343	valid_0's binary_logloss: 0.0112246
# [67]	training's binary_logloss: 0.0898663	valid_0's binary_logloss: 0.0111566
# [68]	training's binary_logloss: 0.0894682	valid_0's binary_logloss: 0.0111786
# [69]	training's binary_logloss: 0.0890135	valid_0's binary_logloss: 0.0110609
# [70]	training's binary_logloss: 0.0885937	valid_0's binary_logloss: 0.0110719
# [71]	training's binary_logloss: 0.0881413	valid_0's binary_logloss: 0.01108
# [72]	training's binary_logloss: 0.0876502	valid_0's binary_logloss: 0.0110029
# [73]	training's binary_logloss: 0.0871877	valid_0's binary_logloss: 0.0109801
# [74]	training's binary_logloss: 0.0868137	valid_0's binary_logloss: 0.0110597
# [75]	training's binary_logloss: 0.086438	valid_0's binary_logloss: 0.011006
# [76]	training's binary_logloss: 0.0860079	valid_0's binary_logloss: 0.010917
# [77]	training's binary_logloss: 0.0856357	valid_0's binary_logloss: 0.010862
# [78]	training's binary_logloss: 0.0852479	valid_0's binary_logloss: 0.0107626
# [79]	training's binary_logloss: 0.0848637	valid_0's binary_logloss: 0.01077
# [80]	training's binary_logloss: 0.0845061	valid_0's binary_logloss: 0.010717
# [81]	training's binary_logloss: 0.0840355	valid_0's binary_logloss: 0.0107165
# [82]	training's binary_logloss: 0.0837021	valid_0's binary_logloss: 0.0108063
# [83]	training's binary_logloss: 0.0832654	valid_0's binary_logloss: 0.0107431
# [84]	training's binary_logloss: 0.0829205	valid_0's binary_logloss: 0.0106909
# [85]	training's binary_logloss: 0.0825342	valid_0's binary_logloss: 0.0107111
# [86]	training's binary_logloss: 0.0823428	valid_0's binary_logloss: 0.0107432
# [87]	training's binary_logloss: 0.0821166	valid_0's binary_logloss: 0.0107051
# [88]	training's binary_logloss: 0.081729	valid_0's binary_logloss: 0.0107783
# [89]	training's binary_logloss: 0.0813773	valid_0's binary_logloss: 0.0107735
# [90]	training's binary_logloss: 0.081094	valid_0's binary_logloss: 0.0108168
# [91]	training's binary_logloss: 0.0808971	valid_0's binary_logloss: 0.0107795
# [92]	training's binary_logloss: 0.0804712	valid_0's binary_logloss: 0.010778
# [93]	training's binary_logloss: 0.0800635	valid_0's binary_logloss: 0.0107095
# [94]	training's binary_logloss: 0.0797369	valid_0's binary_logloss: 0.0107292
# [95]	training's binary_logloss: 0.0794033	valid_0's binary_logloss: 0.0107834
# [96]	training's binary_logloss: 0.0791334	valid_0's binary_logloss: 0.0108375
# [97]	training's binary_logloss: 0.0788379	valid_0's binary_logloss: 0.0108476
# [98]	training's binary_logloss: 0.0784569	valid_0's binary_logloss: 0.0108369
# [99]	training's binary_logloss: 0.0781419	valid_0's binary_logloss: 0.0108119
# [100]	training's binary_logloss: 0.0778783	valid_0's binary_logloss: 0.0108972
# [101]	training's binary_logloss: 0.077543	valid_0's binary_logloss: 0.0109045
# [102]	training's binary_logloss: 0.0772518	valid_0's binary_logloss: 0.0108876
# [103]	training's binary_logloss: 0.0768709	valid_0's binary_logloss: 0.0108649
# [104]	training's binary_logloss: 0.0766257	valid_0's binary_logloss: 0.0108758
# [105]	training's binary_logloss: 0.0764178	valid_0's binary_logloss: 0.0108443
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618971	valid_0's binary_logloss: 0.555954
# [2]	training's binary_logloss: 0.558959	valid_0's binary_logloss: 0.494263
# [3]	training's binary_logloss: 0.507991	valid_0's binary_logloss: 0.440917
# [4]	training's binary_logloss: 0.464155	valid_0's binary_logloss: 0.395268
# [5]	training's binary_logloss: 0.425893	valid_0's binary_logloss: 0.355017
# [6]	training's binary_logloss: 0.392805	valid_0's binary_logloss: 0.319867
# [7]	training's binary_logloss: 0.363692	valid_0's binary_logloss: 0.288908
# [8]	training's binary_logloss: 0.338193	valid_0's binary_logloss: 0.261883
# [9]	training's binary_logloss: 0.315528	valid_0's binary_logloss: 0.237569
# [10]	training's binary_logloss: 0.295324	valid_0's binary_logloss: 0.216125
# [11]	training's binary_logloss: 0.277517	valid_0's binary_logloss: 0.196706
# [12]	training's binary_logloss: 0.26127	valid_0's binary_logloss: 0.179225
# [13]	training's binary_logloss: 0.247062	valid_0's binary_logloss: 0.163591
# [14]	training's binary_logloss: 0.234248	valid_0's binary_logloss: 0.149476
# [15]	training's binary_logloss: 0.222559	valid_0's binary_logloss: 0.136804
# [16]	training's binary_logloss: 0.212089	valid_0's binary_logloss: 0.125394
# [17]	training's binary_logloss: 0.202634	valid_0's binary_logloss: 0.115022
# [18]	training's binary_logloss: 0.193899	valid_0's binary_logloss: 0.10558
# [19]	training's binary_logloss: 0.18612	valid_0's binary_logloss: 0.0970949
# [20]	training's binary_logloss: 0.178849	valid_0's binary_logloss: 0.0894693
# [21]	training's binary_logloss: 0.172213	valid_0's binary_logloss: 0.0825229
# [22]	training's binary_logloss: 0.166064	valid_0's binary_logloss: 0.0761289
# [23]	training's binary_logloss: 0.16056	valid_0's binary_logloss: 0.0703196
# [24]	training's binary_logloss: 0.155452	valid_0's binary_logloss: 0.0650822
# [25]	training's binary_logloss: 0.150936	valid_0's binary_logloss: 0.0601945
# [26]	training's binary_logloss: 0.146777	valid_0's binary_logloss: 0.0557653
# [27]	training's binary_logloss: 0.142637	valid_0's binary_logloss: 0.0518168
# [28]	training's binary_logloss: 0.139155	valid_0's binary_logloss: 0.0481419
# [29]	training's binary_logloss: 0.135852	valid_0's binary_logloss: 0.0448129
# [30]	training's binary_logloss: 0.132651	valid_0's binary_logloss: 0.0417372
# [31]	training's binary_logloss: 0.12983	valid_0's binary_logloss: 0.0389251
# [32]	training's binary_logloss: 0.127238	valid_0's binary_logloss: 0.0365298
# [33]	training's binary_logloss: 0.124579	valid_0's binary_logloss: 0.034241
# [34]	training's binary_logloss: 0.122463	valid_0's binary_logloss: 0.0321325
# [35]	training's binary_logloss: 0.120425	valid_0's binary_logloss: 0.0301559
# [36]	training's binary_logloss: 0.118474	valid_0's binary_logloss: 0.0283984
# [37]	training's binary_logloss: 0.116749	valid_0's binary_logloss: 0.0268158
# [38]	training's binary_logloss: 0.115093	valid_0's binary_logloss: 0.0253637
# [39]	training's binary_logloss: 0.113528	valid_0's binary_logloss: 0.024057
# [40]	training's binary_logloss: 0.112045	valid_0's binary_logloss: 0.0229183
# [41]	training's binary_logloss: 0.110743	valid_0's binary_logloss: 0.0218876
# [42]	training's binary_logloss: 0.10937	valid_0's binary_logloss: 0.0209274
# [43]	training's binary_logloss: 0.10813	valid_0's binary_logloss: 0.0199471
# [44]	training's binary_logloss: 0.10684	valid_0's binary_logloss: 0.0189526
# [45]	training's binary_logloss: 0.105561	valid_0's binary_logloss: 0.0180333
# [46]	training's binary_logloss: 0.104374	valid_0's binary_logloss: 0.0172955
# [47]	training's binary_logloss: 0.103414	valid_0's binary_logloss: 0.0166938
# [48]	training's binary_logloss: 0.102445	valid_0's binary_logloss: 0.016028
# [49]	training's binary_logloss: 0.101553	valid_0's binary_logloss: 0.0154278
# [50]	training's binary_logloss: 0.100737	valid_0's binary_logloss: 0.0148936
# [51]	training's binary_logloss: 0.0998389	valid_0's binary_logloss: 0.014543
# [52]	training's binary_logloss: 0.0990066	valid_0's binary_logloss: 0.0142422
# [53]	training's binary_logloss: 0.0982887	valid_0's binary_logloss: 0.0139634
# [54]	training's binary_logloss: 0.0975282	valid_0's binary_logloss: 0.01355
# [55]	training's binary_logloss: 0.0966906	valid_0's binary_logloss: 0.0132372
# [56]	training's binary_logloss: 0.0960831	valid_0's binary_logloss: 0.0129778
# [57]	training's binary_logloss: 0.0954723	valid_0's binary_logloss: 0.0127005
# [58]	training's binary_logloss: 0.0948264	valid_0's binary_logloss: 0.0124171
# [59]	training's binary_logloss: 0.0941759	valid_0's binary_logloss: 0.0122515
# [60]	training's binary_logloss: 0.0936323	valid_0's binary_logloss: 0.0121176
# [61]	training's binary_logloss: 0.0930184	valid_0's binary_logloss: 0.0118599
# [62]	training's binary_logloss: 0.0925252	valid_0's binary_logloss: 0.0116778
# [63]	training's binary_logloss: 0.0919448	valid_0's binary_logloss: 0.0115126
# [64]	training's binary_logloss: 0.0913377	valid_0's binary_logloss: 0.0114191
# [65]	training's binary_logloss: 0.0908069	valid_0's binary_logloss: 0.0112938
# [66]	training's binary_logloss: 0.090343	valid_0's binary_logloss: 0.0112246
# [67]	training's binary_logloss: 0.0898663	valid_0's binary_logloss: 0.0111566
# [68]	training's binary_logloss: 0.0894682	valid_0's binary_logloss: 0.0111786
# [69]	training's binary_logloss: 0.0890135	valid_0's binary_logloss: 0.0110609
# [70]	training's binary_logloss: 0.0885937	valid_0's binary_logloss: 0.0110719
# [71]	training's binary_logloss: 0.0881413	valid_0's binary_logloss: 0.01108
# [72]	training's binary_logloss: 0.0876502	valid_0's binary_logloss: 0.0110029
# [73]	training's binary_logloss: 0.0871877	valid_0's binary_logloss: 0.0109801
# [74]	training's binary_logloss: 0.0868137	valid_0's binary_logloss: 0.0110597
# [75]	training's binary_logloss: 0.086438	valid_0's binary_logloss: 0.011006
# [76]	training's binary_logloss: 0.0860079	valid_0's binary_logloss: 0.010917
# [77]	training's binary_logloss: 0.0856357	valid_0's binary_logloss: 0.010862
# ...
# [21]	training's binary_logloss: 0.171423	valid_0's binary_logloss: 0.126301
# [22]	training's binary_logloss: 0.165589	valid_0's binary_logloss: 0.11883
# [23]	training's binary_logloss: 0.160189	valid_0's binary_logloss: 0.112089
# [24]	training's binary_logloss: 0.155225	valid_0's binary_logloss: 0.106087
# [25]	training's binary_logloss: 0.150655	valid_0's binary_logloss: 0.100502
# [26]	training's binary_logloss: 0.146627	valid_0's binary_logloss: 0.0955149
# [27]	training's binary_logloss: 0.142565	valid_0's binary_logloss: 0.0904877
# [28]	training's binary_logloss: 0.139138	valid_0's binary_logloss: 0.0858627
# [29]	training's binary_logloss: 0.135749	valid_0's binary_logloss: 0.082092
# [30]	training's binary_logloss: 0.132731	valid_0's binary_logloss: 0.0783685
# [31]	training's binary_logloss: 0.129805	valid_0's binary_logloss: 0.0747072
# [32]	training's binary_logloss: 0.12736	valid_0's binary_logloss: 0.0717964
# [33]	training's binary_logloss: 0.125002	valid_0's binary_logloss: 0.0687168
# [34]	training's binary_logloss: 0.122787	valid_0's binary_logloss: 0.0659298
# [35]	training's binary_logloss: 0.120807	valid_0's binary_logloss: 0.0633767
# [36]	training's binary_logloss: 0.118979	valid_0's binary_logloss: 0.0614338
# [37]	training's binary_logloss: 0.117177	valid_0's binary_logloss: 0.0593783
# [38]	training's binary_logloss: 0.115538	valid_0's binary_logloss: 0.0574468
# [39]	training's binary_logloss: 0.114057	valid_0's binary_logloss: 0.0557413
# [40]	training's binary_logloss: 0.11262	valid_0's binary_logloss: 0.053949
# [41]	training's binary_logloss: 0.111249	valid_0's binary_logloss: 0.0523418
# [42]	training's binary_logloss: 0.1097	valid_0's binary_logloss: 0.0507884
# [43]	training's binary_logloss: 0.108523	valid_0's binary_logloss: 0.0496028
# [44]	training's binary_logloss: 0.107243	valid_0's binary_logloss: 0.0480489
# [45]	training's binary_logloss: 0.106176	valid_0's binary_logloss: 0.0469326
# [46]	training's binary_logloss: 0.105035	valid_0's binary_logloss: 0.0455485
# [47]	training's binary_logloss: 0.104142	valid_0's binary_logloss: 0.0446073
# [48]	training's binary_logloss: 0.103298	valid_0's binary_logloss: 0.0436601
# [49]	training's binary_logloss: 0.102387	valid_0's binary_logloss: 0.0428403
# [50]	training's binary_logloss: 0.101479	valid_0's binary_logloss: 0.0417768
# [51]	training's binary_logloss: 0.100662	valid_0's binary_logloss: 0.0410717
# [52]	training's binary_logloss: 0.0998536	valid_0's binary_logloss: 0.0405517
# [53]	training's binary_logloss: 0.09906	valid_0's binary_logloss: 0.0399273
# [54]	training's binary_logloss: 0.0984868	valid_0's binary_logloss: 0.0391943
# [55]	training's binary_logloss: 0.0977699	valid_0's binary_logloss: 0.0384678
# [56]	training's binary_logloss: 0.0970916	valid_0's binary_logloss: 0.0378825
# [57]	training's binary_logloss: 0.0963302	valid_0's binary_logloss: 0.0371019
# [58]	training's binary_logloss: 0.0957393	valid_0's binary_logloss: 0.0366089
# [59]	training's binary_logloss: 0.0952749	valid_0's binary_logloss: 0.0361847
# [60]	training's binary_logloss: 0.0947178	valid_0's binary_logloss: 0.0356322
# [61]	training's binary_logloss: 0.0940856	valid_0's binary_logloss: 0.035364
# [62]	training's binary_logloss: 0.093448	valid_0's binary_logloss: 0.0348089
# [63]	training's binary_logloss: 0.0929348	valid_0's binary_logloss: 0.0345123
# [64]	training's binary_logloss: 0.0923636	valid_0's binary_logloss: 0.0341755
# [65]	training's binary_logloss: 0.0919366	valid_0's binary_logloss: 0.0339891
# [66]	training's binary_logloss: 0.0913943	valid_0's binary_logloss: 0.0336319
# [67]	training's binary_logloss: 0.0909382	valid_0's binary_logloss: 0.0334963
# [68]	training's binary_logloss: 0.09047	valid_0's binary_logloss: 0.0333712
# [69]	training's binary_logloss: 0.0900397	valid_0's binary_logloss: 0.0331317
# [70]	training's binary_logloss: 0.0894596	valid_0's binary_logloss: 0.0330053
# [71]	training's binary_logloss: 0.088985	valid_0's binary_logloss: 0.0328326
# [72]	training's binary_logloss: 0.0886361	valid_0's binary_logloss: 0.0326294
# [73]	training's binary_logloss: 0.0882799	valid_0's binary_logloss: 0.0324586
# [74]	training's binary_logloss: 0.0876845	valid_0's binary_logloss: 0.0320221
# [75]	training's binary_logloss: 0.0873729	valid_0's binary_logloss: 0.0318722
# [76]	training's binary_logloss: 0.0868885	valid_0's binary_logloss: 0.0317162
# [77]	training's binary_logloss: 0.0865455	valid_0's binary_logloss: 0.0315645
# [78]	training's binary_logloss: 0.0860508	valid_0's binary_logloss: 0.0312907
# [79]	training's binary_logloss: 0.0856657	valid_0's binary_logloss: 0.031206
# [80]	training's binary_logloss: 0.0852881	valid_0's binary_logloss: 0.0310634
# [81]	training's binary_logloss: 0.0847716	valid_0's binary_logloss: 0.0306921
# [82]	training's binary_logloss: 0.0845878	valid_0's binary_logloss: 0.0306135
# [83]	training's binary_logloss: 0.0841493	valid_0's binary_logloss: 0.0304666
# [84]	training's binary_logloss: 0.0838337	valid_0's binary_logloss: 0.0303887
# [85]	training's binary_logloss: 0.0834399	valid_0's binary_logloss: 0.0301401
# [86]	training's binary_logloss: 0.0830044	valid_0's binary_logloss: 0.029928
# [87]	training's binary_logloss: 0.0827307	valid_0's binary_logloss: 0.0297695
# [88]	training's binary_logloss: 0.0823401	valid_0's binary_logloss: 0.029725
# [89]	training's binary_logloss: 0.081994	valid_0's binary_logloss: 0.0296178
# [90]	training's binary_logloss: 0.0818792	valid_0's binary_logloss: 0.0296099
# [91]	training's binary_logloss: 0.0815863	valid_0's binary_logloss: 0.0295287
# [92]	training's binary_logloss: 0.0812685	valid_0's binary_logloss: 0.0293628
# [93]	training's binary_logloss: 0.0809198	valid_0's binary_logloss: 0.0293635
# [94]	training's binary_logloss: 0.0805619	valid_0's binary_logloss: 0.0291132
# [95]	training's binary_logloss: 0.080223	valid_0's binary_logloss: 0.0290626
# [96]	training's binary_logloss: 0.079903	valid_0's binary_logloss: 0.0289976
# [97]	training's binary_logloss: 0.0794705	valid_0's binary_logloss: 0.0287295
# [98]	training's binary_logloss: 0.0790978	valid_0's binary_logloss: 0.0284661
# [99]	training's binary_logloss: 0.0787748	valid_0's binary_logloss: 0.0285217
# [100]	training's binary_logloss: 0.0785057	valid_0's binary_logloss: 0.0284691
# [101]	training's binary_logloss: 0.0781953	valid_0's binary_logloss: 0.0283798
# [102]	training's binary_logloss: 0.0779398	valid_0's binary_logloss: 0.0281766
# [103]	training's binary_logloss: 0.0777018	valid_0's binary_logloss: 0.0281126
# [104]	training's binary_logloss: 0.0774462	valid_0's binary_logloss: 0.0280648
# [105]	training's binary_logloss: 0.0772414	valid_0's binary_logloss: 0.0280526
# [106]	training's binary_logloss: 0.0770193	valid_0's binary_logloss: 0.0280286
# [107]	training's binary_logloss: 0.076694	valid_0's binary_logloss: 0.0278134
# [108]	training's binary_logloss: 0.0763761	valid_0's binary_logloss: 0.0276242
# [109]	training's binary_logloss: 0.076097	valid_0's binary_logloss: 0.0274594
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.612732	valid_0's binary_logloss: 0.675837
# [2]	training's binary_logloss: 0.553241	valid_0's binary_logloss: 0.600325
# [3]	training's binary_logloss: 0.502439	valid_0's binary_logloss: 0.536319
# [4]	training's binary_logloss: 0.458981	valid_0's binary_logloss: 0.482263
# [5]	training's binary_logloss: 0.421251	valid_0's binary_logloss: 0.435297
# [6]	training's binary_logloss: 0.388755	valid_0's binary_logloss: 0.395148
# [7]	training's binary_logloss: 0.360096	valid_0's binary_logloss: 0.359322
# [8]	training's binary_logloss: 0.33496	valid_0's binary_logloss: 0.328216
# [9]	training's binary_logloss: 0.312656	valid_0's binary_logloss: 0.300674
# [10]	training's binary_logloss: 0.292556	valid_0's binary_logloss: 0.276058
# [11]	training's binary_logloss: 0.274973	valid_0's binary_logloss: 0.254324
# [12]	training's binary_logloss: 0.259111	valid_0's binary_logloss: 0.234686
# [13]	training's binary_logloss: 0.24505	valid_0's binary_logloss: 0.217141
# [14]	training's binary_logloss: 0.232305	valid_0's binary_logloss: 0.20151
# [15]	training's binary_logloss: 0.22094	valid_0's binary_logloss: 0.187399
# [16]	training's binary_logloss: 0.210634	valid_0's binary_logloss: 0.174348
# [17]	training's binary_logloss: 0.201208	valid_0's binary_logloss: 0.162907
# [18]	training's binary_logloss: 0.192673	valid_0's binary_logloss: 0.152661
# [19]	training's binary_logloss: 0.184983	valid_0's binary_logloss: 0.143528
# [20]	training's binary_logloss: 0.177741	valid_0's binary_logloss: 0.13428
# [21]	training's binary_logloss: 0.171219	valid_0's binary_logloss: 0.126103
# [22]	training's binary_logloss: 0.16527	valid_0's binary_logloss: 0.118459
# [23]	training's binary_logloss: 0.159717	valid_0's binary_logloss: 0.111988
# [24]	training's binary_logloss: 0.154824	valid_0's binary_logloss: 0.105703
# [25]	training's binary_logloss: 0.150324	valid_0's binary_logloss: 0.100113
# [26]	training's binary_logloss: 0.146197	valid_0's binary_logloss: 0.095163
# [27]	training's binary_logloss: 0.142124	valid_0's binary_logloss: 0.0902326
# [28]	training's binary_logloss: 0.138739	valid_0's binary_logloss: 0.0861091
# [29]	training's binary_logloss: 0.135584	valid_0's binary_logloss: 0.0823349
# [30]	training's binary_logloss: 0.132521	valid_0's binary_logloss: 0.0787084
# [31]	training's binary_logloss: 0.129911	valid_0's binary_logloss: 0.0753693
# [32]	training's binary_logloss: 0.127259	valid_0's binary_logloss: 0.0722956
# [33]	training's binary_logloss: 0.124868	valid_0's binary_logloss: 0.0691473
# [34]	training's binary_logloss: 0.122389	valid_0's binary_logloss: 0.0662496
# [35]	training's binary_logloss: 0.120284	valid_0's binary_logloss: 0.0641143
# [36]	training's binary_logloss: 0.118286	valid_0's binary_logloss: 0.0614666
# [37]	training's binary_logloss: 0.116545	valid_0's binary_logloss: 0.0589182
# [38]	training's binary_logloss: 0.114767	valid_0's binary_logloss: 0.0568742
# [39]	training's binary_logloss: 0.113267	valid_0's binary_logloss: 0.0550057
# [40]	training's binary_logloss: 0.111733	valid_0's binary_logloss: 0.0533617
# [41]	training's binary_logloss: 0.110334	valid_0's binary_logloss: 0.0518403
# [42]	training's binary_logloss: 0.108899	valid_0's binary_logloss: 0.0500104
# [43]	training's binary_logloss: 0.107669	valid_0's binary_logloss: 0.0490057
# [44]	training's binary_logloss: 0.106414	valid_0's binary_logloss: 0.0476533
# [45]	training's binary_logloss: 0.105299	valid_0's binary_logloss: 0.046254
# [46]	training's binary_logloss: 0.104217	valid_0's binary_logloss: 0.0450973
# [47]	training's binary_logloss: 0.103321	valid_0's binary_logloss: 0.044025
# [48]	training's binary_logloss: 0.102349	valid_0's binary_logloss: 0.04262
# [49]	training's binary_logloss: 0.101424	valid_0's binary_logloss: 0.04168
# [50]	training's binary_logloss: 0.100578	valid_0's binary_logloss: 0.0411573
# [51]	training's binary_logloss: 0.0998502	valid_0's binary_logloss: 0.0403685
# [52]	training's binary_logloss: 0.0991412	valid_0's binary_logloss: 0.0396413
# [53]	training's binary_logloss: 0.0983547	valid_0's binary_logloss: 0.0390173
# [54]	training's binary_logloss: 0.0976967	valid_0's binary_logloss: 0.0384632
# [55]	training's binary_logloss: 0.0970041	valid_0's binary_logloss: 0.0378182
# [56]	training's binary_logloss: 0.0963179	valid_0's binary_logloss: 0.0372568
# [57]	training's binary_logloss: 0.0957273	valid_0's binary_logloss: 0.0367005
# [58]	training's binary_logloss: 0.0950256	valid_0's binary_logloss: 0.03596
# [59]	training's binary_logloss: 0.0943834	valid_0's binary_logloss: 0.0355753
# [60]	training's binary_logloss: 0.0937542	valid_0's binary_logloss: 0.0352387
# [61]	training's binary_logloss: 0.0931613	valid_0's binary_logloss: 0.0347293
# [62]	training's binary_logloss: 0.0926341	valid_0's binary_logloss: 0.0345071
# [63]	training's binary_logloss: 0.0921625	valid_0's binary_logloss: 0.0342544
# [64]	training's binary_logloss: 0.0916654	valid_0's binary_logloss: 0.0340302
# [65]	training's binary_logloss: 0.0911631	valid_0's binary_logloss: 0.0336986
# [66]	training's binary_logloss: 0.0906636	valid_0's binary_logloss: 0.0334799
# [67]	training's binary_logloss: 0.0901194	valid_0's binary_logloss: 0.0332724
# [68]	training's binary_logloss: 0.0898105	valid_0's binary_logloss: 0.0328892
# [69]	training's binary_logloss: 0.0894377	valid_0's binary_logloss: 0.032663
# [70]	training's binary_logloss: 0.0889965	valid_0's binary_logloss: 0.0324992
# [71]	training's binary_logloss: 0.0887485	valid_0's binary_logloss: 0.0323234
# [72]	training's binary_logloss: 0.0881958	valid_0's binary_logloss: 0.0318423
# [73]	training's binary_logloss: 0.0876492	valid_0's binary_logloss: 0.0312551
# [74]	training's binary_logloss: 0.08709	valid_0's binary_logloss: 0.0310022
# [75]	training's binary_logloss: 0.0867671	valid_0's binary_logloss: 0.0306993
# [76]	training's binary_logloss: 0.086293	valid_0's binary_logloss: 0.0305545
# [77]	training's binary_logloss: 0.0858134	valid_0's binary_logloss: 0.0302922
# [78]	training's binary_logloss: 0.0853764	valid_0's binary_logloss: 0.0301768
# [79]	training's binary_logloss: 0.0849164	valid_0's binary_logloss: 0.0300822
# [80]	training's binary_logloss: 0.084683	valid_0's binary_logloss: 0.0298788
# [81]	training's binary_logloss: 0.0842759	valid_0's binary_logloss: 0.0297679
# [82]	training's binary_logloss: 0.0838548	valid_0's binary_logloss: 0.0297039
# [83]	training's binary_logloss: 0.083448	valid_0's binary_logloss: 0.0295254
# [84]	training's binary_logloss: 0.0832295	valid_0's binary_logloss: 0.0294662
# [85]	training's binary_logloss: 0.0828553	valid_0's binary_logloss: 0.0293738
# [86]	training's binary_logloss: 0.0825058	valid_0's binary_logloss: 0.0293535
# [87]	training's binary_logloss: 0.0821357	valid_0's binary_logloss: 0.0290392
# [88]	training's binary_logloss: 0.081963	valid_0's binary_logloss: 0.0288879
# [89]	training's binary_logloss: 0.0815429	valid_0's binary_logloss: 0.0287975
# [90]	training's binary_logloss: 0.0811231	valid_0's binary_logloss: 0.0286751
# [91]	training's binary_logloss: 0.0809491	valid_0's binary_logloss: 0.0285551
# [92]	training's binary_logloss: 0.0805306	valid_0's binary_logloss: 0.0284796
# [93]	training's binary_logloss: 0.0801727	valid_0's binary_logloss: 0.0283934
# [94]	training's binary_logloss: 0.0798543	valid_0's binary_logloss: 0.0283787
# [95]	training's binary_logloss: 0.0796302	valid_0's binary_logloss: 0.0283406
# [96]	training's binary_logloss: 0.0793967	valid_0's binary_logloss: 0.0282461
# [97]	training's binary_logloss: 0.0790843	valid_0's binary_logloss: 0.0281617
# [98]	training's binary_logloss: 0.0787082	valid_0's binary_logloss: 0.0280997
# [99]	training's binary_logloss: 0.0783856	valid_0's binary_logloss: 0.0280945
# [100]	training's binary_logloss: 0.0781018	valid_0's binary_logloss: 0.0280258
# [101]	training's binary_logloss: 0.0777481	valid_0's binary_logloss: 0.0279276
# [102]	training's binary_logloss: 0.0773781	valid_0's binary_logloss: 0.0277272
# [103]	training's binary_logloss: 0.077182	valid_0's binary_logloss: 0.0276198
# [104]	training's binary_logloss: 0.0768419	valid_0's binary_logloss: 0.0274498
# [105]	training's binary_logloss: 0.0766163	valid_0's binary_logloss: 0.0274337
# [106]	training's binary_logloss: 0.0763147	valid_0's binary_logloss: 0.027354
# ---Run time is 171.71956379999756 seconds ---
#
# Accuracy of each fold:
#  [0.9164759725400458, 0.9545638945233266, 0.9962216624685138, 0.9316546762589928, 0.9973876698014629, 0.9553752535496958, 0.7580569827183559, 0.998638529611981, 0.9397590361445783, 0.9707828004410143, 0.9823049001814882, 0.9913854989231874, 0.8235827664399092, 0.956687898089172, 0.6024146544546212, 0.9884802835622508, 0.9890335846470185, 0.9855741488747836, 0.7565511411665258, 0.9582188015393073, 0.9965782720273738, 0.9962335216572504, 0.9978858350951374]
#
# Avg accuracy :
# 0.93234120803113
#
# Std of accuracy :
# 0.09921926389738983

# %%
print(confusion_matrix(Truth, Output))
print(classification_report(Truth, Output))
print(acc_score)
print(elapsed)
print(n_estimators_list)
print(max_depth_list)
#old confusion matrix
#[23104  1639]
#  [ 1720 18505]]
# ---Run time is 155.16974349999873 seconds ---

# Accuracy of each fold: 
#  [0.9164759725400458, 0.9537525354969574, 0.9962216624685138, 0.9268585131894485, 0.9979101358411703, 0.959026369168357, 0.7678654834189631, 0.998638529611981, 0.9392570281124498, 0.9718853362734289, 0.9823049001814882, 0.990667623833453, 0.8285714285714286, 0.9560509554140127, 0.6040799333888426, 0.9880372175454143, 0.9897189856065799, 0.9873052510098096, 0.7514792899408284, 0.959868059373282, 0.9957228400342173, 0.997489014438167, 0.9974630021141649]

# Avg accuracy : 
# 0.9328978290249132

# Std of accuracy : 
# 0.09852275116924226
# Out:
# [[23104  1639]
#  [ 1720 18505]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93     24743
#            1       0.92      0.91      0.92     20225
#
#     accuracy                           0.93     44968
#    macro avg       0.92      0.92      0.92     44968
# weighted avg       0.93      0.93      0.93     44968
#
# [0.9164759725400458, 0.9537525354969574, 0.9962216624685138, 0.9268585131894485, 0.9979101358411703, 0.959026369168357, 0.7678654834189631, 0.998638529611981, 0.9392570281124498, 0.9718853362734289, 0.9823049001814882, 0.990667623833453, 0.8285714285714286, 0.9560509554140127, 0.6040799333888426, 0.9880372175454143, 0.9897189856065799, 0.9873052510098096, 0.7514792899408284, 0.959868059373282, 0.9957228400342173, 0.997489014438167, 0.9974630021141649]
# 199.88120800000615
# [106, 105, 106, 106, 106, 107, 106, 105, 107, 105, 106, 109, 106, 106, 108, 108, 106, 108, 107, 106, 106, 109, 106]
# [9, 9, 9, 9, 9, 8, 9, 9, 8, 9, 9, 8, 8, 9, 8, 8, 9, 8, 8, 8, 9, 8, 9]

# %%
# ---Run time is 199.88120800000615 seconds ---

# Accuracy of each fold: 
#  [0.9164759725400458, 0.9537525354969574, 0.9962216624685138, 0.9268585131894485, 0.9979101358411703, 0.959026369168357, 0.7678654834189631, 0.998638529611981, 0.9392570281124498, 0.9718853362734289, 0.9823049001814882, 0.990667623833453, 0.8285714285714286, 0.9560509554140127, 0.6040799333888426, 0.9880372175454143, 0.9897189856065799, 0.9873052510098096, 0.7514792899408284, 0.959868059373282, 0.9957228400342173, 0.997489014438167, 0.9974630021141649]

# Avg accuracy : 
# 0.9328978290249132

# Std of accuracy : 
# 0.09852275116924226
#[[23104  1639]
# [ 1720 18505]]

# %%
temp_list = []
temp_idx = []
for acc in acc_score:
    if acc >= 0.97:
        temp_list.append(acc)
        temp_idx.append(acc_score.index(acc))
for idx in temp_idx:
    print(n_estimators_list[idx])
    print(max_depth_list[idx])
# Out:
# 106
# 9
# 106
# 9
# 105
# 9
# 105
# 9
# 106
# 9
# 109
# 8
# 108
# 8
# 106
# 9
# 108
# 8
# 106
# 9
# 109
# 8
# 106
# 9

# %%
import statistics

print(statistics.mode(n_estimators_list))
print(statistics.mode(max_depth_list))
# Out:
# 106
# 9

# %%
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html
import lightgbm

#Implementing cross validation 
kf = KFold(n_splits=23, random_state=1, shuffle=True)


from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
n_estimators_list = []
max_depth_list = []

x_values = ['StoS', 'StoR', 'StoL', 'RtoS', 'RtoR', 'RtoL', 'LtoS',
       'LtoR', 'LtoL', 'STD', 'CoefVar', 'Range', 'Volatility', 'ShEn',
       'AppEn', 'SampEn']
y_values = ['Rhythm']
df = features_maindf

for idx, subject in enumerate(good_list):
    
    train_index = ~df['Subject'].str.contains(subject)
    test_index = df['Subject'].str.contains(subject)
    X_train , X_test = df.loc[train_index,x_values], df.loc[test_index,x_values]
    y_train , y_test = df.loc[train_index,y_values].values.ravel(), df.loc[test_index,y_values]

#     temp_model = model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],eval_metric='logloss')    
#     param_distributions = {'n_estimators': randint(105, 110),
#                            'max_depth': randint(7,10)}

#     search = RandomizedSearchCV(estimator=temp_model, param_distributions=param_distributions, random_state=0)
#     search.fit(X_train, y_train)

#     n_estimators_list.append(search.best_params_['n_estimators'])
#     max_depth_list.append(search.best_params_['max_depth'])

#     model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],
#           eval_metric='logloss')
    model = lightgbm.LGBMClassifier(learning_rate=0.09,max_depth=9,n_estimators=106, random_state=42)
    
    # Create the LightGBM data containers
    model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],
          eval_metric='logloss')

    pred_values = model.predict(X_test)
     
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list  
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)}, 
                          index = (X_train.columns))
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    #plt.savefig('plot1.png')


elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
# Out:
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618356	valid_0's binary_logloss: 0.571408
# [2]	training's binary_logloss: 0.55755	valid_0's binary_logloss: 0.521635
# [3]	training's binary_logloss: 0.505937	valid_0's binary_logloss: 0.479841
# [4]	training's binary_logloss: 0.461077	valid_0's binary_logloss: 0.444658
# [5]	training's binary_logloss: 0.422435	valid_0's binary_logloss: 0.413974
# [6]	training's binary_logloss: 0.38893	valid_0's binary_logloss: 0.388499
# [7]	training's binary_logloss: 0.359628	valid_0's binary_logloss: 0.365992
# [8]	training's binary_logloss: 0.333592	valid_0's binary_logloss: 0.347248
# [9]	training's binary_logloss: 0.310288	valid_0's binary_logloss: 0.331451
# [10]	training's binary_logloss: 0.289955	valid_0's binary_logloss: 0.316704
# [11]	training's binary_logloss: 0.271785	valid_0's binary_logloss: 0.30466
# [12]	training's binary_logloss: 0.255501	valid_0's binary_logloss: 0.293693
# [13]	training's binary_logloss: 0.240837	valid_0's binary_logloss: 0.283784
# [14]	training's binary_logloss: 0.22775	valid_0's binary_logloss: 0.275828
# [15]	training's binary_logloss: 0.21598	valid_0's binary_logloss: 0.268669
# [16]	training's binary_logloss: 0.205265	valid_0's binary_logloss: 0.262664
# [17]	training's binary_logloss: 0.195583	valid_0's binary_logloss: 0.257642
# [18]	training's binary_logloss: 0.186891	valid_0's binary_logloss: 0.253955
# [19]	training's binary_logloss: 0.178988	valid_0's binary_logloss: 0.250287
# [20]	training's binary_logloss: 0.171579	valid_0's binary_logloss: 0.246055
# [21]	training's binary_logloss: 0.164948	valid_0's binary_logloss: 0.243198
# [22]	training's binary_logloss: 0.158779	valid_0's binary_logloss: 0.24017
# [23]	training's binary_logloss: 0.153153	valid_0's binary_logloss: 0.238315
# [24]	training's binary_logloss: 0.148038	valid_0's binary_logloss: 0.237017
# [25]	training's binary_logloss: 0.143337	valid_0's binary_logloss: 0.235804
# [26]	training's binary_logloss: 0.138839	valid_0's binary_logloss: 0.235422
# [27]	training's binary_logloss: 0.134833	valid_0's binary_logloss: 0.23489
# [28]	training's binary_logloss: 0.131198	valid_0's binary_logloss: 0.234956
# [29]	training's binary_logloss: 0.127976	valid_0's binary_logloss: 0.235719
# [30]	training's binary_logloss: 0.124744	valid_0's binary_logloss: 0.236703
# [31]	training's binary_logloss: 0.121693	valid_0's binary_logloss: 0.236981
# [32]	training's binary_logloss: 0.119045	valid_0's binary_logloss: 0.237422
# [33]	training's binary_logloss: 0.116617	valid_0's binary_logloss: 0.238068
# [34]	training's binary_logloss: 0.114399	valid_0's binary_logloss: 0.237576
# [35]	training's binary_logloss: 0.112412	valid_0's binary_logloss: 0.237859
# [36]	training's binary_logloss: 0.110449	valid_0's binary_logloss: 0.238707
# [37]	training's binary_logloss: 0.108589	valid_0's binary_logloss: 0.239308
# [38]	training's binary_logloss: 0.106892	valid_0's binary_logloss: 0.240561
# [39]	training's binary_logloss: 0.10541	valid_0's binary_logloss: 0.241507
# [40]	training's binary_logloss: 0.103842	valid_0's binary_logloss: 0.242529
# [41]	training's binary_logloss: 0.102382	valid_0's binary_logloss: 0.243203
# [42]	training's binary_logloss: 0.101141	valid_0's binary_logloss: 0.243211
# [43]	training's binary_logloss: 0.0999207	valid_0's binary_logloss: 0.24374
# [44]	training's binary_logloss: 0.0987792	valid_0's binary_logloss: 0.245141
# [45]	training's binary_logloss: 0.097568	valid_0's binary_logloss: 0.245624
# [46]	training's binary_logloss: 0.0965263	valid_0's binary_logloss: 0.245333
# [47]	training's binary_logloss: 0.0955605	valid_0's binary_logloss: 0.245522
# [48]	training's binary_logloss: 0.0946074	valid_0's binary_logloss: 0.246207
# [49]	training's binary_logloss: 0.0935997	valid_0's binary_logloss: 0.247243
# [50]	training's binary_logloss: 0.0926684	valid_0's binary_logloss: 0.248311
# [51]	training's binary_logloss: 0.091886	valid_0's binary_logloss: 0.248501
# [52]	training's binary_logloss: 0.0910803	valid_0's binary_logloss: 0.249117
# [53]	training's binary_logloss: 0.0904185	valid_0's binary_logloss: 0.24943
# [54]	training's binary_logloss: 0.0897079	valid_0's binary_logloss: 0.250967
# [55]	training's binary_logloss: 0.0889824	valid_0's binary_logloss: 0.251137
# [56]	training's binary_logloss: 0.0883262	valid_0's binary_logloss: 0.251874
# [57]	training's binary_logloss: 0.0875399	valid_0's binary_logloss: 0.251896
# [58]	training's binary_logloss: 0.08696	valid_0's binary_logloss: 0.253454
# [59]	training's binary_logloss: 0.0864075	valid_0's binary_logloss: 0.254855
# [60]	training's binary_logloss: 0.0857856	valid_0's binary_logloss: 0.255505
# [61]	training's binary_logloss: 0.0852443	valid_0's binary_logloss: 0.256194
# [62]	training's binary_logloss: 0.0847203	valid_0's binary_logloss: 0.256376
# [63]	training's binary_logloss: 0.0841441	valid_0's binary_logloss: 0.257282
# [64]	training's binary_logloss: 0.0835178	valid_0's binary_logloss: 0.258187
# [65]	training's binary_logloss: 0.0830934	valid_0's binary_logloss: 0.259311
# [66]	training's binary_logloss: 0.0826018	valid_0's binary_logloss: 0.260636
# [67]	training's binary_logloss: 0.0820231	valid_0's binary_logloss: 0.260231
# [68]	training's binary_logloss: 0.0815971	valid_0's binary_logloss: 0.260457
# [69]	training's binary_logloss: 0.0811682	valid_0's binary_logloss: 0.260686
# [70]	training's binary_logloss: 0.0807191	valid_0's binary_logloss: 0.261219
# [71]	training's binary_logloss: 0.0802545	valid_0's binary_logloss: 0.262035
# [72]	training's binary_logloss: 0.0797633	valid_0's binary_logloss: 0.26194
# [73]	training's binary_logloss: 0.0792505	valid_0's binary_logloss: 0.262037
# [74]	training's binary_logloss: 0.0789179	valid_0's binary_logloss: 0.262045
# [75]	training's binary_logloss: 0.0784838	valid_0's binary_logloss: 0.263168
# [76]	training's binary_logloss: 0.0781269	valid_0's binary_logloss: 0.263171
# [77]	training's binary_logloss: 0.077788	valid_0's binary_logloss: 0.264908
# [78]	training's binary_logloss: 0.0773281	valid_0's binary_logloss: 0.265288
# [79]	training's binary_logloss: 0.0769978	valid_0's binary_logloss: 0.266321
# [80]	training's binary_logloss: 0.076544	valid_0's binary_logloss: 0.266132
# [81]	training's binary_logloss: 0.0762392	valid_0's binary_logloss: 0.266294
# [82]	training's binary_logloss: 0.0757551	valid_0's binary_logloss: 0.266484
# [83]	training's binary_logloss: 0.0753132	valid_0's binary_logloss: 0.266404
# [84]	training's binary_logloss: 0.0750424	valid_0's binary_logloss: 0.266935
# [85]	training's binary_logloss: 0.0746367	valid_0's binary_logloss: 0.267005
# [86]	training's binary_logloss: 0.0742564	valid_0's binary_logloss: 0.26758
# [87]	training's binary_logloss: 0.0739477	valid_0's binary_logloss: 0.267751
# [88]	training's binary_logloss: 0.073707	valid_0's binary_logloss: 0.2679
# [89]	training's binary_logloss: 0.0733864	valid_0's binary_logloss: 0.267644
# [90]	training's binary_logloss: 0.0731144	valid_0's binary_logloss: 0.267749
# [91]	training's binary_logloss: 0.0727821	valid_0's binary_logloss: 0.267896
# [92]	training's binary_logloss: 0.0724997	valid_0's binary_logloss: 0.267993
# [93]	training's binary_logloss: 0.072093	valid_0's binary_logloss: 0.267954
# [94]	training's binary_logloss: 0.0717777	valid_0's binary_logloss: 0.268081
# [95]	training's binary_logloss: 0.0714408	valid_0's binary_logloss: 0.268174
# [96]	training's binary_logloss: 0.0710647	valid_0's binary_logloss: 0.26817
# [97]	training's binary_logloss: 0.0707693	valid_0's binary_logloss: 0.267774
# [98]	training's binary_logloss: 0.0703727	valid_0's binary_logloss: 0.268492
# [99]	training's binary_logloss: 0.0701108	valid_0's binary_logloss: 0.268899
# [100]	training's binary_logloss: 0.0697843	valid_0's binary_logloss: 0.268959
# [101]	training's binary_logloss: 0.0694204	valid_0's binary_logloss: 0.269231
# [102]	training's binary_logloss: 0.0691587	valid_0's binary_logloss: 0.269176
# [103]	training's binary_logloss: 0.0688873	valid_0's binary_logloss: 0.270718
# [104]	training's binary_logloss: 0.0685957	valid_0's binary_logloss: 0.270364
# [105]	training's binary_logloss: 0.0682658	valid_0's binary_logloss: 0.271212
# [106]	training's binary_logloss: 0.0678927	valid_0's binary_logloss: 0.271092
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618031	valid_0's binary_logloss: 0.587241
# [2]	training's binary_logloss: 0.557826	valid_0's binary_logloss: 0.529984
# [3]	training's binary_logloss: 0.506602	valid_0's binary_logloss: 0.481112
# [4]	training's binary_logloss: 0.462222	valid_0's binary_logloss: 0.439001
# [5]	training's binary_logloss: 0.423927	valid_0's binary_logloss: 0.403011
# [6]	training's binary_logloss: 0.390808	valid_0's binary_logloss: 0.372501
# [7]	training's binary_logloss: 0.361402	valid_0's binary_logloss: 0.344989
# [8]	training's binary_logloss: 0.335528	valid_0's binary_logloss: 0.321032
# [9]	training's binary_logloss: 0.312662	valid_0's binary_logloss: 0.299857
# [10]	training's binary_logloss: 0.292288	valid_0's binary_logloss: 0.281156
# [11]	training's binary_logloss: 0.274419	valid_0's binary_logloss: 0.264642
# [12]	training's binary_logloss: 0.258274	valid_0's binary_logloss: 0.249967
# [13]	training's binary_logloss: 0.243762	valid_0's binary_logloss: 0.237395
# [14]	training's binary_logloss: 0.230701	valid_0's binary_logloss: 0.225606
# [15]	training's binary_logloss: 0.218932	valid_0's binary_logloss: 0.215237
# [16]	training's binary_logloss: 0.208376	valid_0's binary_logloss: 0.205954
# [17]	training's binary_logloss: 0.198771	valid_0's binary_logloss: 0.19821
# [18]	training's binary_logloss: 0.190025	valid_0's binary_logloss: 0.190865
# [19]	training's binary_logloss: 0.18186	valid_0's binary_logloss: 0.184192
# [20]	training's binary_logloss: 0.174569	valid_0's binary_logloss: 0.178497
# [21]	training's binary_logloss: 0.167892	valid_0's binary_logloss: 0.173185
# [22]	training's binary_logloss: 0.161699	valid_0's binary_logloss: 0.168042
# [23]	training's binary_logloss: 0.156301	valid_0's binary_logloss: 0.163877
# [24]	training's binary_logloss: 0.151302	valid_0's binary_logloss: 0.159939
# [25]	training's binary_logloss: 0.146681	valid_0's binary_logloss: 0.156399
# [26]	training's binary_logloss: 0.142426	valid_0's binary_logloss: 0.1536
# [27]	training's binary_logloss: 0.138185	valid_0's binary_logloss: 0.150395
# [28]	training's binary_logloss: 0.134782	valid_0's binary_logloss: 0.148148
# [29]	training's binary_logloss: 0.131528	valid_0's binary_logloss: 0.14628
# [30]	training's binary_logloss: 0.128133	valid_0's binary_logloss: 0.143476
# [31]	training's binary_logloss: 0.125322	valid_0's binary_logloss: 0.141278
# [32]	training's binary_logloss: 0.122598	valid_0's binary_logloss: 0.139677
# [33]	training's binary_logloss: 0.119907	valid_0's binary_logloss: 0.137675
# [34]	training's binary_logloss: 0.1177	valid_0's binary_logloss: 0.13655
# [35]	training's binary_logloss: 0.115672	valid_0's binary_logloss: 0.13553
# [36]	training's binary_logloss: 0.113583	valid_0's binary_logloss: 0.133645
# [37]	training's binary_logloss: 0.111613	valid_0's binary_logloss: 0.132572
# [38]	training's binary_logloss: 0.109983	valid_0's binary_logloss: 0.131525
# [39]	training's binary_logloss: 0.108332	valid_0's binary_logloss: 0.130518
# [40]	training's binary_logloss: 0.106726	valid_0's binary_logloss: 0.129721
# [41]	training's binary_logloss: 0.105308	valid_0's binary_logloss: 0.128871
# [42]	training's binary_logloss: 0.104073	valid_0's binary_logloss: 0.128107
# [43]	training's binary_logloss: 0.102881	valid_0's binary_logloss: 0.127684
# [44]	training's binary_logloss: 0.101637	valid_0's binary_logloss: 0.126884
# [45]	training's binary_logloss: 0.100476	valid_0's binary_logloss: 0.12676
# [46]	training's binary_logloss: 0.0995037	valid_0's binary_logloss: 0.126529
# [47]	training's binary_logloss: 0.0984396	valid_0's binary_logloss: 0.125908
# [48]	training's binary_logloss: 0.0975251	valid_0's binary_logloss: 0.12564
# [49]	training's binary_logloss: 0.0967063	valid_0's binary_logloss: 0.125269
# [50]	training's binary_logloss: 0.0958276	valid_0's binary_logloss: 0.124447
# [51]	training's binary_logloss: 0.0950027	valid_0's binary_logloss: 0.124402
# [52]	training's binary_logloss: 0.0941942	valid_0's binary_logloss: 0.123986
# [53]	training's binary_logloss: 0.0935396	valid_0's binary_logloss: 0.123998
# [54]	training's binary_logloss: 0.0928637	valid_0's binary_logloss: 0.124037
# [55]	training's binary_logloss: 0.0920218	valid_0's binary_logloss: 0.123791
# [56]	training's binary_logloss: 0.091332	valid_0's binary_logloss: 0.123762
# [57]	training's binary_logloss: 0.0906994	valid_0's binary_logloss: 0.123492
# [58]	training's binary_logloss: 0.0901561	valid_0's binary_logloss: 0.123575
# [59]	training's binary_logloss: 0.089566	valid_0's binary_logloss: 0.123521
# [60]	training's binary_logloss: 0.0890076	valid_0's binary_logloss: 0.123421
# [61]	training's binary_logloss: 0.0883919	valid_0's binary_logloss: 0.123468
# [62]	training's binary_logloss: 0.0878229	valid_0's binary_logloss: 0.123449
# [63]	training's binary_logloss: 0.0872058	valid_0's binary_logloss: 0.123203
# [64]	training's binary_logloss: 0.0867052	valid_0's binary_logloss: 0.123236
# [65]	training's binary_logloss: 0.0861539	valid_0's binary_logloss: 0.123203
# [66]	training's binary_logloss: 0.0857701	valid_0's binary_logloss: 0.123189
# [67]	training's binary_logloss: 0.0852566	valid_0's binary_logloss: 0.122974
# [68]	training's binary_logloss: 0.0847311	valid_0's binary_logloss: 0.122943
# [69]	training's binary_logloss: 0.0843535	valid_0's binary_logloss: 0.123033
# [70]	training's binary_logloss: 0.0838119	valid_0's binary_logloss: 0.122743
# [71]	training's binary_logloss: 0.0834529	valid_0's binary_logloss: 0.122749
# [72]	training's binary_logloss: 0.0830918	valid_0's binary_logloss: 0.122778
# [73]	training's binary_logloss: 0.0826217	valid_0's binary_logloss: 0.12288
# [74]	training's binary_logloss: 0.082092	valid_0's binary_logloss: 0.122834
# [75]	training's binary_logloss: 0.0818525	valid_0's binary_logloss: 0.122899
# [76]	training's binary_logloss: 0.0814129	valid_0's binary_logloss: 0.122788
# [77]	training's binary_logloss: 0.0810452	valid_0's binary_logloss: 0.122814
# [78]	training's binary_logloss: 0.0806068	valid_0's binary_logloss: 0.122446
# [79]	training's binary_logloss: 0.0802069	valid_0's binary_logloss: 0.122468
# [80]	training's binary_logloss: 0.0798102	valid_0's binary_logloss: 0.122478
# [81]	training's binary_logloss: 0.0795881	valid_0's binary_logloss: 0.122456
# [82]	training's binary_logloss: 0.0791729	valid_0's binary_logloss: 0.122644
# [83]	training's binary_logloss: 0.0788105	valid_0's binary_logloss: 0.122609
# [84]	training's binary_logloss: 0.0783549	valid_0's binary_logloss: 0.122721
# [85]	training's binary_logloss: 0.0780976	valid_0's binary_logloss: 0.122741
# [86]	training's binary_logloss: 0.0778839	valid_0's binary_logloss: 0.123553
# [87]	training's binary_logloss: 0.0775466	valid_0's binary_logloss: 0.123711
# [88]	training's binary_logloss: 0.0771942	valid_0's binary_logloss: 0.123577
# [89]	training's binary_logloss: 0.0768374	valid_0's binary_logloss: 0.123761
# [90]	training's binary_logloss: 0.0763764	valid_0's binary_logloss: 0.123837
# [91]	training's binary_logloss: 0.0760573	valid_0's binary_logloss: 0.123915
# [92]	training's binary_logloss: 0.0757582	valid_0's binary_logloss: 0.124086
# [93]	training's binary_logloss: 0.0755285	valid_0's binary_logloss: 0.124178
# [94]	training's binary_logloss: 0.0750287	valid_0's binary_logloss: 0.124178
# [95]	training's binary_logloss: 0.074815	valid_0's binary_logloss: 0.124274
# [96]	training's binary_logloss: 0.0745265	valid_0's binary_logloss: 0.124311
# [97]	training's binary_logloss: 0.074227	valid_0's binary_logloss: 0.124272
# [98]	training's binary_logloss: 0.0739171	valid_0's binary_logloss: 0.124331
# [99]	training's binary_logloss: 0.0735876	valid_0's binary_logloss: 0.12444
# [100]	training's binary_logloss: 0.0733029	valid_0's binary_logloss: 0.124523
# [101]	training's binary_logloss: 0.0730667	valid_0's binary_logloss: 0.124567
# [102]	training's binary_logloss: 0.0727586	valid_0's binary_logloss: 0.124544
# [103]	training's binary_logloss: 0.0724675	valid_0's binary_logloss: 0.124541
# [104]	training's binary_logloss: 0.0721771	valid_0's binary_logloss: 0.124667
# [105]	training's binary_logloss: 0.071905	valid_0's binary_logloss: 0.124565
# [106]	training's binary_logloss: 0.071613	valid_0's binary_logloss: 0.124619
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618971	valid_0's binary_logloss: 0.555954
# [2]	training's binary_logloss: 0.558959	valid_0's binary_logloss: 0.494263
# [3]	training's binary_logloss: 0.507991	valid_0's binary_logloss: 0.440917
# [4]	training's binary_logloss: 0.464155	valid_0's binary_logloss: 0.395268
# [5]	training's binary_logloss: 0.425893	valid_0's binary_logloss: 0.355017
# [6]	training's binary_logloss: 0.392805	valid_0's binary_logloss: 0.319867
# [7]	training's binary_logloss: 0.363692	valid_0's binary_logloss: 0.288908
# [8]	training's binary_logloss: 0.338193	valid_0's binary_logloss: 0.261883
# [9]	training's binary_logloss: 0.315528	valid_0's binary_logloss: 0.237569
# [10]	training's binary_logloss: 0.295324	valid_0's binary_logloss: 0.216125
# [11]	training's binary_logloss: 0.277517	valid_0's binary_logloss: 0.196706
# [12]	training's binary_logloss: 0.26127	valid_0's binary_logloss: 0.179225
# [13]	training's binary_logloss: 0.247062	valid_0's binary_logloss: 0.163591
# [14]	training's binary_logloss: 0.234248	valid_0's binary_logloss: 0.149476
# [15]	training's binary_logloss: 0.222559	valid_0's binary_logloss: 0.136804
# [16]	training's binary_logloss: 0.212089	valid_0's binary_logloss: 0.125394
# [17]	training's binary_logloss: 0.202634	valid_0's binary_logloss: 0.115022
# [18]	training's binary_logloss: 0.193899	valid_0's binary_logloss: 0.10558
# [19]	training's binary_logloss: 0.18612	valid_0's binary_logloss: 0.0970949
# [20]	training's binary_logloss: 0.178849	valid_0's binary_logloss: 0.0894693
# [21]	training's binary_logloss: 0.172213	valid_0's binary_logloss: 0.0825229
# [22]	training's binary_logloss: 0.166064	valid_0's binary_logloss: 0.0761289
# [23]	training's binary_logloss: 0.16056	valid_0's binary_logloss: 0.0703196
# [24]	training's binary_logloss: 0.155452	valid_0's binary_logloss: 0.0650822
# [25]	training's binary_logloss: 0.150936	valid_0's binary_logloss: 0.0601945
# [26]	training's binary_logloss: 0.146777	valid_0's binary_logloss: 0.0557653
# [27]	training's binary_logloss: 0.142637	valid_0's binary_logloss: 0.0518168
# [28]	training's binary_logloss: 0.139155	valid_0's binary_logloss: 0.0481419
# [29]	training's binary_logloss: 0.135852	valid_0's binary_logloss: 0.0448129
# [30]	training's binary_logloss: 0.132651	valid_0's binary_logloss: 0.0417372
# [31]	training's binary_logloss: 0.12983	valid_0's binary_logloss: 0.0389251
# [32]	training's binary_logloss: 0.127238	valid_0's binary_logloss: 0.0365298
# [33]	training's binary_logloss: 0.124579	valid_0's binary_logloss: 0.034241
# [34]	training's binary_logloss: 0.122463	valid_0's binary_logloss: 0.0321325
# [35]	training's binary_logloss: 0.120425	valid_0's binary_logloss: 0.0301559
# [36]	training's binary_logloss: 0.118474	valid_0's binary_logloss: 0.0283984
# [37]	training's binary_logloss: 0.116749	valid_0's binary_logloss: 0.0268158
# [38]	training's binary_logloss: 0.115093	valid_0's binary_logloss: 0.0253637
# [39]	training's binary_logloss: 0.113528	valid_0's binary_logloss: 0.024057
# [40]	training's binary_logloss: 0.112045	valid_0's binary_logloss: 0.0229183
# [41]	training's binary_logloss: 0.110743	valid_0's binary_logloss: 0.0218876
# [42]	training's binary_logloss: 0.10937	valid_0's binary_logloss: 0.0209274
# [43]	training's binary_logloss: 0.10813	valid_0's binary_logloss: 0.0199471
# [44]	training's binary_logloss: 0.10684	valid_0's binary_logloss: 0.0189526
# [45]	training's binary_logloss: 0.105561	valid_0's binary_logloss: 0.0180333
# [46]	training's binary_logloss: 0.104374	valid_0's binary_logloss: 0.0172955
# [47]	training's binary_logloss: 0.103414	valid_0's binary_logloss: 0.0166938
# [48]	training's binary_logloss: 0.102445	valid_0's binary_logloss: 0.016028
# [49]	training's binary_logloss: 0.101553	valid_0's binary_logloss: 0.0154278
# [50]	training's binary_logloss: 0.100737	valid_0's binary_logloss: 0.0148936
# [51]	training's binary_logloss: 0.0998389	valid_0's binary_logloss: 0.014543
# [52]	training's binary_logloss: 0.0990066	valid_0's binary_logloss: 0.0142422
# [53]	training's binary_logloss: 0.0982887	valid_0's binary_logloss: 0.0139634
# [54]	training's binary_logloss: 0.0975282	valid_0's binary_logloss: 0.01355
# [55]	training's binary_logloss: 0.0966906	valid_0's binary_logloss: 0.0132372
# [56]	training's binary_logloss: 0.0960831	valid_0's binary_logloss: 0.0129778
# [57]	training's binary_logloss: 0.0954723	valid_0's binary_logloss: 0.0127005
# [58]	training's binary_logloss: 0.0948264	valid_0's binary_logloss: 0.0124171
# [59]	training's binary_logloss: 0.0941759	valid_0's binary_logloss: 0.0122515
# [60]	training's binary_logloss: 0.0936323	valid_0's binary_logloss: 0.0121176
# [61]	training's binary_logloss: 0.0930184	valid_0's binary_logloss: 0.0118599
# [62]	training's binary_logloss: 0.0925252	valid_0's binary_logloss: 0.0116778
# [63]	training's binary_logloss: 0.0919448	valid_0's binary_logloss: 0.0115126
# [64]	training's binary_logloss: 0.0913377	valid_0's binary_logloss: 0.0114191
# [65]	training's binary_logloss: 0.0908069	valid_0's binary_logloss: 0.0112938
# [66]	training's binary_logloss: 0.090343	valid_0's binary_logloss: 0.0112246
# [67]	training's binary_logloss: 0.0898663	valid_0's binary_logloss: 0.0111566
# [68]	training's binary_logloss: 0.0894682	valid_0's binary_logloss: 0.0111786
# [69]	training's binary_logloss: 0.0890135	valid_0's binary_logloss: 0.0110609
# [70]	training's binary_logloss: 0.0885937	valid_0's binary_logloss: 0.0110719
# [71]	training's binary_logloss: 0.0881413	valid_0's binary_logloss: 0.01108
# [72]	training's binary_logloss: 0.0876502	valid_0's binary_logloss: 0.0110029
# [73]	training's binary_logloss: 0.0871877	valid_0's binary_logloss: 0.0109801
# [74]	training's binary_logloss: 0.0868137	valid_0's binary_logloss: 0.0110597
# [75]	training's binary_logloss: 0.086438	valid_0's binary_logloss: 0.011006
# [76]	training's binary_logloss: 0.0860079	valid_0's binary_logloss: 0.010917
# [77]	training's binary_logloss: 0.0856357	valid_0's binary_logloss: 0.010862
# [78]	training's binary_logloss: 0.0852479	valid_0's binary_logloss: 0.0107626
# [79]	training's binary_logloss: 0.0848637	valid_0's binary_logloss: 0.01077
# [80]	training's binary_logloss: 0.0845061	valid_0's binary_logloss: 0.010717
# [81]	training's binary_logloss: 0.0840355	valid_0's binary_logloss: 0.0107165
# [82]	training's binary_logloss: 0.0837021	valid_0's binary_logloss: 0.0108063
# [83]	training's binary_logloss: 0.0832654	valid_0's binary_logloss: 0.0107431
# [84]	training's binary_logloss: 0.0829205	valid_0's binary_logloss: 0.0106909
# [85]	training's binary_logloss: 0.0825342	valid_0's binary_logloss: 0.0107111
# [86]	training's binary_logloss: 0.0823428	valid_0's binary_logloss: 0.0107432
# [87]	training's binary_logloss: 0.0821166	valid_0's binary_logloss: 0.0107051
# [88]	training's binary_logloss: 0.081729	valid_0's binary_logloss: 0.0107783
# [89]	training's binary_logloss: 0.0813773	valid_0's binary_logloss: 0.0107735
# [90]	training's binary_logloss: 0.081094	valid_0's binary_logloss: 0.0108168
# [91]	training's binary_logloss: 0.0808971	valid_0's binary_logloss: 0.0107795
# [92]	training's binary_logloss: 0.0804712	valid_0's binary_logloss: 0.010778
# [93]	training's binary_logloss: 0.0800635	valid_0's binary_logloss: 0.0107095
# [94]	training's binary_logloss: 0.0797369	valid_0's binary_logloss: 0.0107292
# [95]	training's binary_logloss: 0.0794033	valid_0's binary_logloss: 0.0107834
# [96]	training's binary_logloss: 0.0791334	valid_0's binary_logloss: 0.0108375
# [97]	training's binary_logloss: 0.0788379	valid_0's binary_logloss: 0.0108476
# [98]	training's binary_logloss: 0.0784569	valid_0's binary_logloss: 0.0108369
# [99]	training's binary_logloss: 0.0781419	valid_0's binary_logloss: 0.0108119
# [100]	training's binary_logloss: 0.0778783	valid_0's binary_logloss: 0.0108972
# [101]	training's binary_logloss: 0.077543	valid_0's binary_logloss: 0.0109045
# [102]	training's binary_logloss: 0.0772518	valid_0's binary_logloss: 0.0108876
# [103]	training's binary_logloss: 0.0768709	valid_0's binary_logloss: 0.0108649
# [104]	training's binary_logloss: 0.0766257	valid_0's binary_logloss: 0.0108758
# [105]	training's binary_logloss: 0.0764178	valid_0's binary_logloss: 0.0108443
# [106]	training's binary_logloss: 0.0761558	valid_0's binary_logloss: 0.0109713
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.617806	valid_0's binary_logloss: 0.582015
# [2]	training's binary_logloss: 0.55692	valid_0's binary_logloss: 0.538577
# [3]	training's binary_logloss: 0.505198	valid_0's binary_logloss: 0.500806
# [4]	training's binary_logloss: 0.461029	valid_0's binary_logloss: 0.468758
# [5]	training's binary_logloss: 0.422621	valid_0's binary_logloss: 0.44201
# [6]	training's binary_logloss: 0.389259	valid_0's binary_logloss: 0.418793
# [7]	training's binary_logloss: 0.359896	valid_0's binary_logloss: 0.39805
# [8]	training's binary_logloss: 0.334028	valid_0's binary_logloss: 0.379569
# [9]	training's binary_logloss: 0.31119	valid_0's binary_logloss: 0.363359
# [10]	training's binary_logloss: 0.290954	valid_0's binary_logloss: 0.347904
# [11]	training's binary_logloss: 0.27288	valid_0's binary_logloss: 0.3349
# [12]	training's binary_logloss: 0.256822	valid_0's binary_logloss: 0.324482
# [13]	training's binary_logloss: 0.242465	valid_0's binary_logloss: 0.313196
# [14]	training's binary_logloss: 0.229574	valid_0's binary_logloss: 0.30489
# [15]	training's binary_logloss: 0.217858	valid_0's binary_logloss: 0.295106
# [16]	training's binary_logloss: 0.207491	valid_0's binary_logloss: 0.287063
# [17]	training's binary_logloss: 0.197825	valid_0's binary_logloss: 0.27914
# [18]	training's binary_logloss: 0.188944	valid_0's binary_logloss: 0.270867
# [19]	training's binary_logloss: 0.181106	valid_0's binary_logloss: 0.265142
# [20]	training's binary_logloss: 0.173898	valid_0's binary_logloss: 0.259255
# [21]	training's binary_logloss: 0.167357	valid_0's binary_logloss: 0.253456
# [22]	training's binary_logloss: 0.161273	valid_0's binary_logloss: 0.249052
# [23]	training's binary_logloss: 0.155831	valid_0's binary_logloss: 0.243877
# [24]	training's binary_logloss: 0.150884	valid_0's binary_logloss: 0.240056
# [25]	training's binary_logloss: 0.146126	valid_0's binary_logloss: 0.234875
# [26]	training's binary_logloss: 0.141897	valid_0's binary_logloss: 0.23129
# [27]	training's binary_logloss: 0.138077	valid_0's binary_logloss: 0.227953
# [28]	training's binary_logloss: 0.134416	valid_0's binary_logloss: 0.223254
# [29]	training's binary_logloss: 0.13126	valid_0's binary_logloss: 0.220553
# [30]	training's binary_logloss: 0.128072	valid_0's binary_logloss: 0.218069
# [31]	training's binary_logloss: 0.125168	valid_0's binary_logloss: 0.215105
# [32]	training's binary_logloss: 0.122496	valid_0's binary_logloss: 0.2119
# [33]	training's binary_logloss: 0.119699	valid_0's binary_logloss: 0.209033
# [34]	training's binary_logloss: 0.117413	valid_0's binary_logloss: 0.206243
# [35]	training's binary_logloss: 0.115417	valid_0's binary_logloss: 0.204672
# [36]	training's binary_logloss: 0.113493	valid_0's binary_logloss: 0.202716
# [37]	training's binary_logloss: 0.111501	valid_0's binary_logloss: 0.201685
# [38]	training's binary_logloss: 0.109851	valid_0's binary_logloss: 0.199298
# [39]	training's binary_logloss: 0.108291	valid_0's binary_logloss: 0.19835
# [40]	training's binary_logloss: 0.106779	valid_0's binary_logloss: 0.197488
# [41]	training's binary_logloss: 0.105548	valid_0's binary_logloss: 0.19734
# [42]	training's binary_logloss: 0.104378	valid_0's binary_logloss: 0.197732
# [43]	training's binary_logloss: 0.103133	valid_0's binary_logloss: 0.197811
# [44]	training's binary_logloss: 0.101905	valid_0's binary_logloss: 0.19686
# [45]	training's binary_logloss: 0.100774	valid_0's binary_logloss: 0.197546
# [46]	training's binary_logloss: 0.0997374	valid_0's binary_logloss: 0.196651
# [47]	training's binary_logloss: 0.0988711	valid_0's binary_logloss: 0.195765
# [48]	training's binary_logloss: 0.0978255	valid_0's binary_logloss: 0.194098
# [49]	training's binary_logloss: 0.096999	valid_0's binary_logloss: 0.193468
# [50]	training's binary_logloss: 0.0960951	valid_0's binary_logloss: 0.194071
# [51]	training's binary_logloss: 0.0952956	valid_0's binary_logloss: 0.192861
# [52]	training's binary_logloss: 0.0945698	valid_0's binary_logloss: 0.192201
# [53]	training's binary_logloss: 0.0938855	valid_0's binary_logloss: 0.192926
# [54]	training's binary_logloss: 0.0931121	valid_0's binary_logloss: 0.191891
# [55]	training's binary_logloss: 0.0923143	valid_0's binary_logloss: 0.190977
# [56]	training's binary_logloss: 0.091631	valid_0's binary_logloss: 0.190788
# [57]	training's binary_logloss: 0.0909615	valid_0's binary_logloss: 0.189912
# [58]	training's binary_logloss: 0.0902611	valid_0's binary_logloss: 0.188387
# [59]	training's binary_logloss: 0.0896037	valid_0's binary_logloss: 0.187895
# [60]	training's binary_logloss: 0.0889995	valid_0's binary_logloss: 0.188276
# [61]	training's binary_logloss: 0.0883854	valid_0's binary_logloss: 0.187659
# [62]	training's binary_logloss: 0.0878805	valid_0's binary_logloss: 0.187465
# [63]	training's binary_logloss: 0.0873303	valid_0's binary_logloss: 0.186618
# [64]	training's binary_logloss: 0.0867807	valid_0's binary_logloss: 0.185723
# [65]	training's binary_logloss: 0.0863127	valid_0's binary_logloss: 0.184405
# [66]	training's binary_logloss: 0.0857691	valid_0's binary_logloss: 0.183751
# [67]	training's binary_logloss: 0.0852559	valid_0's binary_logloss: 0.184957
# [68]	training's binary_logloss: 0.084889	valid_0's binary_logloss: 0.184955
# [69]	training's binary_logloss: 0.0843759	valid_0's binary_logloss: 0.185344
# [70]	training's binary_logloss: 0.0839853	valid_0's binary_logloss: 0.185651
# [71]	training's binary_logloss: 0.0836815	valid_0's binary_logloss: 0.185857
# [72]	training's binary_logloss: 0.083198	valid_0's binary_logloss: 0.185886
# [73]	training's binary_logloss: 0.0828109	valid_0's binary_logloss: 0.187765
# [74]	training's binary_logloss: 0.0823874	valid_0's binary_logloss: 0.186048
# [75]	training's binary_logloss: 0.082026	valid_0's binary_logloss: 0.185489
# [76]	training's binary_logloss: 0.0816233	valid_0's binary_logloss: 0.185182
# [77]	training's binary_logloss: 0.0812196	valid_0's binary_logloss: 0.18504
# [78]	training's binary_logloss: 0.0808305	valid_0's binary_logloss: 0.184689
# [79]	training's binary_logloss: 0.0806201	valid_0's binary_logloss: 0.183218
# [80]	training's binary_logloss: 0.0803506	valid_0's binary_logloss: 0.183255
# [81]	training's binary_logloss: 0.0801189	valid_0's binary_logloss: 0.184517
# [82]	training's binary_logloss: 0.079727	valid_0's binary_logloss: 0.183881
# [83]	training's binary_logloss: 0.0794478	valid_0's binary_logloss: 0.183759
# [84]	training's binary_logloss: 0.0791337	valid_0's binary_logloss: 0.183726
# [85]	training's binary_logloss: 0.0786053	valid_0's binary_logloss: 0.182723
# [86]	training's binary_logloss: 0.0782859	valid_0's binary_logloss: 0.18233
# [87]	training's binary_logloss: 0.0780191	valid_0's binary_logloss: 0.184123
# [88]	training's binary_logloss: 0.077616	valid_0's binary_logloss: 0.184411
# [89]	training's binary_logloss: 0.0773164	valid_0's binary_logloss: 0.18411
# [90]	training's binary_logloss: 0.0769729	valid_0's binary_logloss: 0.184423
# [91]	training's binary_logloss: 0.076651	valid_0's binary_logloss: 0.183726
# [92]	training's binary_logloss: 0.0763145	valid_0's binary_logloss: 0.183796
# [93]	training's binary_logloss: 0.0760113	valid_0's binary_logloss: 0.183637
# [94]	training's binary_logloss: 0.0756576	valid_0's binary_logloss: 0.183489
# [95]	training's binary_logloss: 0.0752468	valid_0's binary_logloss: 0.183132
# [96]	training's binary_logloss: 0.0748051	valid_0's binary_logloss: 0.183053
# [97]	training's binary_logloss: 0.0744764	valid_0's binary_logloss: 0.182314
# [98]	training's binary_logloss: 0.0741403	valid_0's binary_logloss: 0.182167
# [99]	training's binary_logloss: 0.0738533	valid_0's binary_logloss: 0.182378
# [100]	training's binary_logloss: 0.0735417	valid_0's binary_logloss: 0.182733
# [101]	training's binary_logloss: 0.0731408	valid_0's binary_logloss: 0.183072
# [102]	training's binary_logloss: 0.0728183	valid_0's binary_logloss: 0.183085
# [103]	training's binary_logloss: 0.0725796	valid_0's binary_logloss: 0.18311
# [104]	training's binary_logloss: 0.0723031	valid_0's binary_logloss: 0.18312
# [105]	training's binary_logloss: 0.0721308	valid_0's binary_logloss: 0.183255
# [106]	training's binary_logloss: 0.0718367	valid_0's binary_logloss: 0.18307
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.61445	valid_0's binary_logloss: 0.645708
# [2]	training's binary_logloss: 0.55478	valid_0's binary_logloss: 0.572508
# [3]	training's binary_logloss: 0.504202	valid_0's binary_logloss: 0.510262
# [4]	training's binary_logloss: 0.460493	valid_0's binary_logloss: 0.45734
# [5]	training's binary_logloss: 0.422878	valid_0's binary_logloss: 0.411441
# [6]	training's binary_logloss: 0.389921	valid_0's binary_logloss: 0.371323
# [7]	training's binary_logloss: 0.361302	valid_0's binary_logloss: 0.336232
# [8]	training's binary_logloss: 0.335705	valid_0's binary_logloss: 0.305397
# [9]	training's binary_logloss: 0.313508	valid_0's binary_logloss: 0.278328
# [10]	training's binary_logloss: 0.293543	valid_0's binary_logloss: 0.25383
# [11]	training's binary_logloss: 0.275866	valid_0's binary_logloss: 0.232286
# [12]	training's binary_logloss: 0.259752	valid_0's binary_logloss: 0.212982
# [13]	training's binary_logloss: 0.245542	valid_0's binary_logloss: 0.195566
# [14]	training's binary_logloss: 0.232859	valid_0's binary_logloss: 0.179917
# [15]	training's binary_logloss: 0.221195	valid_0's binary_logloss: 0.165687
# [16]	training's binary_logloss: 0.210916	valid_0's binary_logloss: 0.152964
# [17]	training's binary_logloss: 0.201447	valid_0's binary_logloss: 0.141069
# [18]	training's binary_logloss: 0.192874	valid_0's binary_logloss: 0.130762
# [19]	training's binary_logloss: 0.185085	valid_0's binary_logloss: 0.121271
# [20]	training's binary_logloss: 0.178002	valid_0's binary_logloss: 0.112464
# [21]	training's binary_logloss: 0.171382	valid_0's binary_logloss: 0.104724
# [22]	training's binary_logloss: 0.165166	valid_0's binary_logloss: 0.0974869
# [23]	training's binary_logloss: 0.159857	valid_0's binary_logloss: 0.0910508
# [24]	training's binary_logloss: 0.154936	valid_0's binary_logloss: 0.0851713
# [25]	training's binary_logloss: 0.150315	valid_0's binary_logloss: 0.0796905
# [26]	training's binary_logloss: 0.146131	valid_0's binary_logloss: 0.0745742
# [27]	training's binary_logloss: 0.142183	valid_0's binary_logloss: 0.0700004
# [28]	training's binary_logloss: 0.138539	valid_0's binary_logloss: 0.0657237
# [29]	training's binary_logloss: 0.135032	valid_0's binary_logloss: 0.0620965
# [30]	training's binary_logloss: 0.131993	valid_0's binary_logloss: 0.0585945
# [31]	training's binary_logloss: 0.12935	valid_0's binary_logloss: 0.0554668
# [32]	training's binary_logloss: 0.126791	valid_0's binary_logloss: 0.0525716
# [33]	training's binary_logloss: 0.124387	valid_0's binary_logloss: 0.0498387
# [34]	training's binary_logloss: 0.122259	valid_0's binary_logloss: 0.0474301
# [35]	training's binary_logloss: 0.120273	valid_0's binary_logloss: 0.0450788
# [36]	training's binary_logloss: 0.118269	valid_0's binary_logloss: 0.0429561
# [37]	training's binary_logloss: 0.116186	valid_0's binary_logloss: 0.041041
# [38]	training's binary_logloss: 0.114541	valid_0's binary_logloss: 0.0391875
# [39]	training's binary_logloss: 0.113076	valid_0's binary_logloss: 0.0376191
# [40]	training's binary_logloss: 0.111629	valid_0's binary_logloss: 0.0361334
# [41]	training's binary_logloss: 0.110294	valid_0's binary_logloss: 0.0348212
# [42]	training's binary_logloss: 0.108838	valid_0's binary_logloss: 0.0334811
# [43]	training's binary_logloss: 0.107464	valid_0's binary_logloss: 0.032338
# [44]	training's binary_logloss: 0.10628	valid_0's binary_logloss: 0.0311782
# [45]	training's binary_logloss: 0.105103	valid_0's binary_logloss: 0.0302123
# [46]	training's binary_logloss: 0.104144	valid_0's binary_logloss: 0.0292172
# [47]	training's binary_logloss: 0.103113	valid_0's binary_logloss: 0.0283681
# [48]	training's binary_logloss: 0.102144	valid_0's binary_logloss: 0.0275136
# [49]	training's binary_logloss: 0.101174	valid_0's binary_logloss: 0.026836
# [50]	training's binary_logloss: 0.100317	valid_0's binary_logloss: 0.0261059
# [51]	training's binary_logloss: 0.0994543	valid_0's binary_logloss: 0.0255474
# [52]	training's binary_logloss: 0.0985855	valid_0's binary_logloss: 0.0250314
# [53]	training's binary_logloss: 0.0977974	valid_0's binary_logloss: 0.024353
# [54]	training's binary_logloss: 0.097165	valid_0's binary_logloss: 0.0239117
# [55]	training's binary_logloss: 0.0964867	valid_0's binary_logloss: 0.0234216
# [56]	training's binary_logloss: 0.0958329	valid_0's binary_logloss: 0.0230064
# [57]	training's binary_logloss: 0.0950814	valid_0's binary_logloss: 0.0226201
# [58]	training's binary_logloss: 0.0944517	valid_0's binary_logloss: 0.0223333
# [59]	training's binary_logloss: 0.0937858	valid_0's binary_logloss: 0.0218893
# [60]	training's binary_logloss: 0.093189	valid_0's binary_logloss: 0.02149
# [61]	training's binary_logloss: 0.0926429	valid_0's binary_logloss: 0.021188
# [62]	training's binary_logloss: 0.0921207	valid_0's binary_logloss: 0.0209613
# [63]	training's binary_logloss: 0.091693	valid_0's binary_logloss: 0.020675
# [64]	training's binary_logloss: 0.0911193	valid_0's binary_logloss: 0.0204738
# [65]	training's binary_logloss: 0.0906811	valid_0's binary_logloss: 0.0203327
# [66]	training's binary_logloss: 0.0902694	valid_0's binary_logloss: 0.0200236
# [67]	training's binary_logloss: 0.0898321	valid_0's binary_logloss: 0.0198855
# [68]	training's binary_logloss: 0.0891456	valid_0's binary_logloss: 0.0195967
# [69]	training's binary_logloss: 0.0886458	valid_0's binary_logloss: 0.0195667
# [70]	training's binary_logloss: 0.0883851	valid_0's binary_logloss: 0.0194971
# [71]	training's binary_logloss: 0.0879859	valid_0's binary_logloss: 0.0192577
# [72]	training's binary_logloss: 0.0875623	valid_0's binary_logloss: 0.0192401
# [73]	training's binary_logloss: 0.0871966	valid_0's binary_logloss: 0.0191571
# [74]	training's binary_logloss: 0.0868055	valid_0's binary_logloss: 0.0189593
# [75]	training's binary_logloss: 0.0863784	valid_0's binary_logloss: 0.0189483
# [76]	training's binary_logloss: 0.0859399	valid_0's binary_logloss: 0.018768
# [77]	training's binary_logloss: 0.0855561	valid_0's binary_logloss: 0.0186433
# [78]	training's binary_logloss: 0.0851186	valid_0's binary_logloss: 0.0186476
# [79]	training's binary_logloss: 0.0846896	valid_0's binary_logloss: 0.0185087
# [80]	training's binary_logloss: 0.0844745	valid_0's binary_logloss: 0.0184507
# [81]	training's binary_logloss: 0.0841124	valid_0's binary_logloss: 0.0184156
# [82]	training's binary_logloss: 0.0837212	valid_0's binary_logloss: 0.0183477
# [83]	training's binary_logloss: 0.0833826	valid_0's binary_logloss: 0.0183597
# [84]	training's binary_logloss: 0.0829454	valid_0's binary_logloss: 0.0183143
# [85]	training's binary_logloss: 0.082476	valid_0's binary_logloss: 0.0181999
# [86]	training's binary_logloss: 0.0821259	valid_0's binary_logloss: 0.0181176
# [87]	training's binary_logloss: 0.0816325	valid_0's binary_logloss: 0.0180188
# [88]	training's binary_logloss: 0.0812304	valid_0's binary_logloss: 0.017857
# [89]	training's binary_logloss: 0.0808902	valid_0's binary_logloss: 0.017848
# [90]	training's binary_logloss: 0.0805921	valid_0's binary_logloss: 0.0177332
# [91]	training's binary_logloss: 0.0802784	valid_0's binary_logloss: 0.0177302
# [92]	training's binary_logloss: 0.0799178	valid_0's binary_logloss: 0.0177544
# [93]	training's binary_logloss: 0.0795137	valid_0's binary_logloss: 0.0176551
# [94]	training's binary_logloss: 0.0791704	valid_0's binary_logloss: 0.0176909
# [95]	training's binary_logloss: 0.0788123	valid_0's binary_logloss: 0.0175852
# [96]	training's binary_logloss: 0.0784653	valid_0's binary_logloss: 0.0175997
# [97]	training's binary_logloss: 0.078179	valid_0's binary_logloss: 0.0174891
# [98]	training's binary_logloss: 0.0781267	valid_0's binary_logloss: 0.0174793
# [99]	training's binary_logloss: 0.0778945	valid_0's binary_logloss: 0.0173287
# [100]	training's binary_logloss: 0.0775907	valid_0's binary_logloss: 0.0173217
# [101]	training's binary_logloss: 0.0773163	valid_0's binary_logloss: 0.0172702
# [102]	training's binary_logloss: 0.0770609	valid_0's binary_logloss: 0.01722
# [103]	training's binary_logloss: 0.0768072	valid_0's binary_logloss: 0.0171847
# [104]	training's binary_logloss: 0.0765658	valid_0's binary_logloss: 0.0171386
# [105]	training's binary_logloss: 0.0763501	valid_0's binary_logloss: 0.0171457
# [106]	training's binary_logloss: 0.0761622	valid_0's binary_logloss: 0.0171516
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.619273	valid_0's binary_logloss: 0.586657
# [2]	training's binary_logloss: 0.558414	valid_0's binary_logloss: 0.529604
# [3]	training's binary_logloss: 0.506881	valid_0's binary_logloss: 0.481345
# [4]	training's binary_logloss: 0.462765	valid_0's binary_logloss: 0.439885
# [5]	training's binary_logloss: 0.424584	valid_0's binary_logloss: 0.40474
# [6]	training's binary_logloss: 0.391336	valid_0's binary_logloss: 0.373663
# [7]	training's binary_logloss: 0.362068	valid_0's binary_logloss: 0.346935
# [8]	training's binary_logloss: 0.33646	valid_0's binary_logloss: 0.323364
# [9]	training's binary_logloss: 0.313695	valid_0's binary_logloss: 0.302781
# [10]	training's binary_logloss: 0.293503	valid_0's binary_logloss: 0.284574
# [11]	training's binary_logloss: 0.275447	valid_0's binary_logloss: 0.268775
# [12]	training's binary_logloss: 0.259284	valid_0's binary_logloss: 0.259389
# [13]	training's binary_logloss: 0.244673	valid_0's binary_logloss: 0.247979
# [14]	training's binary_logloss: 0.231599	valid_0's binary_logloss: 0.237693
# [15]	training's binary_logloss: 0.219724	valid_0's binary_logloss: 0.228156
# [16]	training's binary_logloss: 0.209136	valid_0's binary_logloss: 0.219481
# [17]	training's binary_logloss: 0.199601	valid_0's binary_logloss: 0.211967
# [18]	training's binary_logloss: 0.19076	valid_0's binary_logloss: 0.207316
# [19]	training's binary_logloss: 0.182929	valid_0's binary_logloss: 0.201309
# [20]	training's binary_logloss: 0.175711	valid_0's binary_logloss: 0.196162
# [21]	training's binary_logloss: 0.169009	valid_0's binary_logloss: 0.193574
# [22]	training's binary_logloss: 0.1629	valid_0's binary_logloss: 0.19137
# [23]	training's binary_logloss: 0.157461	valid_0's binary_logloss: 0.187879
# [24]	training's binary_logloss: 0.152406	valid_0's binary_logloss: 0.182581
# [25]	training's binary_logloss: 0.147803	valid_0's binary_logloss: 0.179236
# [26]	training's binary_logloss: 0.143537	valid_0's binary_logloss: 0.175584
# [27]	training's binary_logloss: 0.139618	valid_0's binary_logloss: 0.17221
# [28]	training's binary_logloss: 0.135987	valid_0's binary_logloss: 0.169056
# [29]	training's binary_logloss: 0.132423	valid_0's binary_logloss: 0.165858
# [30]	training's binary_logloss: 0.12942	valid_0's binary_logloss: 0.163976
# [31]	training's binary_logloss: 0.126734	valid_0's binary_logloss: 0.160188
# [32]	training's binary_logloss: 0.124005	valid_0's binary_logloss: 0.158784
# [33]	training's binary_logloss: 0.121736	valid_0's binary_logloss: 0.156766
# [34]	training's binary_logloss: 0.119488	valid_0's binary_logloss: 0.155801
# [35]	training's binary_logloss: 0.11741	valid_0's binary_logloss: 0.153569
# [36]	training's binary_logloss: 0.115216	valid_0's binary_logloss: 0.152622
# [37]	training's binary_logloss: 0.11338	valid_0's binary_logloss: 0.149004
# [38]	training's binary_logloss: 0.111712	valid_0's binary_logloss: 0.148918
# [39]	training's binary_logloss: 0.110124	valid_0's binary_logloss: 0.146
# [40]	training's binary_logloss: 0.108455	valid_0's binary_logloss: 0.14492
# [41]	training's binary_logloss: 0.106946	valid_0's binary_logloss: 0.145174
# [42]	training's binary_logloss: 0.105478	valid_0's binary_logloss: 0.14231
# [43]	training's binary_logloss: 0.104341	valid_0's binary_logloss: 0.142251
# [44]	training's binary_logloss: 0.103069	valid_0's binary_logloss: 0.140125
# [45]	training's binary_logloss: 0.10181	valid_0's binary_logloss: 0.138101
# [46]	training's binary_logloss: 0.100727	valid_0's binary_logloss: 0.137668
# [47]	training's binary_logloss: 0.0997413	valid_0's binary_logloss: 0.135756
# [48]	training's binary_logloss: 0.098754	valid_0's binary_logloss: 0.135261
# [49]	training's binary_logloss: 0.097841	valid_0's binary_logloss: 0.13487
# [50]	training's binary_logloss: 0.0969879	valid_0's binary_logloss: 0.133855
# [51]	training's binary_logloss: 0.0961542	valid_0's binary_logloss: 0.132488
# [52]	training's binary_logloss: 0.095431	valid_0's binary_logloss: 0.131032
# [53]	training's binary_logloss: 0.0947227	valid_0's binary_logloss: 0.130475
# [54]	training's binary_logloss: 0.0939558	valid_0's binary_logloss: 0.130655
# [55]	training's binary_logloss: 0.0932523	valid_0's binary_logloss: 0.129322
# [56]	training's binary_logloss: 0.0925604	valid_0's binary_logloss: 0.128779
# [57]	training's binary_logloss: 0.0920142	valid_0's binary_logloss: 0.127525
# [58]	training's binary_logloss: 0.0914026	valid_0's binary_logloss: 0.127012
# [59]	training's binary_logloss: 0.0908882	valid_0's binary_logloss: 0.12699
# [60]	training's binary_logloss: 0.0902819	valid_0's binary_logloss: 0.126813
# [61]	training's binary_logloss: 0.0897479	valid_0's binary_logloss: 0.126071
# [62]	training's binary_logloss: 0.0891043	valid_0's binary_logloss: 0.125596
# [63]	training's binary_logloss: 0.0885582	valid_0's binary_logloss: 0.124899
# [64]	training's binary_logloss: 0.0880744	valid_0's binary_logloss: 0.123728
# [65]	training's binary_logloss: 0.0874645	valid_0's binary_logloss: 0.122673
# [66]	training's binary_logloss: 0.0869199	valid_0's binary_logloss: 0.121888
# [67]	training's binary_logloss: 0.0864441	valid_0's binary_logloss: 0.122067
# [68]	training's binary_logloss: 0.0859062	valid_0's binary_logloss: 0.12235
# [69]	training's binary_logloss: 0.0856024	valid_0's binary_logloss: 0.122356
# [70]	training's binary_logloss: 0.0851906	valid_0's binary_logloss: 0.122285
# [71]	training's binary_logloss: 0.0846677	valid_0's binary_logloss: 0.121636
# [72]	training's binary_logloss: 0.0842459	valid_0's binary_logloss: 0.12151
# [73]	training's binary_logloss: 0.0838726	valid_0's binary_logloss: 0.12139
# [74]	training's binary_logloss: 0.0832803	valid_0's binary_logloss: 0.12112
# ...
# [18]	training's binary_logloss: 0.193815	valid_0's binary_logloss: 0.115371
# [19]	training's binary_logloss: 0.185916	valid_0's binary_logloss: 0.106951
# [20]	training's binary_logloss: 0.178731	valid_0's binary_logloss: 0.0990325
# [21]	training's binary_logloss: 0.172254	valid_0's binary_logloss: 0.0916539
# [22]	training's binary_logloss: 0.166231	valid_0's binary_logloss: 0.0853051
# [23]	training's binary_logloss: 0.160743	valid_0's binary_logloss: 0.0793861
# [24]	training's binary_logloss: 0.155797	valid_0's binary_logloss: 0.0740937
# [25]	training's binary_logloss: 0.151259	valid_0's binary_logloss: 0.0689287
# [26]	training's binary_logloss: 0.147007	valid_0's binary_logloss: 0.0643223
# [27]	training's binary_logloss: 0.143115	valid_0's binary_logloss: 0.0601084
# [28]	training's binary_logloss: 0.139516	valid_0's binary_logloss: 0.0560939
# [29]	training's binary_logloss: 0.136068	valid_0's binary_logloss: 0.0523919
# [30]	training's binary_logloss: 0.133046	valid_0's binary_logloss: 0.0492431
# [31]	training's binary_logloss: 0.130271	valid_0's binary_logloss: 0.0464573
# [32]	training's binary_logloss: 0.127643	valid_0's binary_logloss: 0.0438957
# [33]	training's binary_logloss: 0.125151	valid_0's binary_logloss: 0.0413171
# [34]	training's binary_logloss: 0.122874	valid_0's binary_logloss: 0.038809
# [35]	training's binary_logloss: 0.120728	valid_0's binary_logloss: 0.0367832
# [36]	training's binary_logloss: 0.11878	valid_0's binary_logloss: 0.0348157
# [37]	training's binary_logloss: 0.116902	valid_0's binary_logloss: 0.03289
# [38]	training's binary_logloss: 0.115274	valid_0's binary_logloss: 0.0311521
# [39]	training's binary_logloss: 0.113702	valid_0's binary_logloss: 0.0295958
# [40]	training's binary_logloss: 0.112177	valid_0's binary_logloss: 0.0283805
# [41]	training's binary_logloss: 0.110885	valid_0's binary_logloss: 0.0269875
# [42]	training's binary_logloss: 0.109603	valid_0's binary_logloss: 0.0260002
# [43]	training's binary_logloss: 0.108145	valid_0's binary_logloss: 0.0249137
# [44]	training's binary_logloss: 0.106828	valid_0's binary_logloss: 0.0237193
# [45]	training's binary_logloss: 0.105627	valid_0's binary_logloss: 0.0228759
# [46]	training's binary_logloss: 0.104505	valid_0's binary_logloss: 0.021861
# [47]	training's binary_logloss: 0.103402	valid_0's binary_logloss: 0.0211906
# [48]	training's binary_logloss: 0.102478	valid_0's binary_logloss: 0.0202673
# [49]	training's binary_logloss: 0.101512	valid_0's binary_logloss: 0.0196681
# [50]	training's binary_logloss: 0.10072	valid_0's binary_logloss: 0.0188243
# [51]	training's binary_logloss: 0.0998586	valid_0's binary_logloss: 0.018345
# [52]	training's binary_logloss: 0.0990785	valid_0's binary_logloss: 0.0178283
# [53]	training's binary_logloss: 0.098318	valid_0's binary_logloss: 0.0172794
# [54]	training's binary_logloss: 0.0975678	valid_0's binary_logloss: 0.016763
# [55]	training's binary_logloss: 0.0969416	valid_0's binary_logloss: 0.0163495
# [56]	training's binary_logloss: 0.0962958	valid_0's binary_logloss: 0.0159954
# [57]	training's binary_logloss: 0.0955815	valid_0's binary_logloss: 0.0156283
# [58]	training's binary_logloss: 0.0950064	valid_0's binary_logloss: 0.0153489
# [59]	training's binary_logloss: 0.0944243	valid_0's binary_logloss: 0.0150044
# [60]	training's binary_logloss: 0.0938623	valid_0's binary_logloss: 0.0146135
# [61]	training's binary_logloss: 0.0933372	valid_0's binary_logloss: 0.0142758
# [62]	training's binary_logloss: 0.0927523	valid_0's binary_logloss: 0.0141216
# [63]	training's binary_logloss: 0.0921512	valid_0's binary_logloss: 0.0138886
# [64]	training's binary_logloss: 0.0916212	valid_0's binary_logloss: 0.0137596
# [65]	training's binary_logloss: 0.0910616	valid_0's binary_logloss: 0.0135806
# [66]	training's binary_logloss: 0.0906041	valid_0's binary_logloss: 0.0134667
# [67]	training's binary_logloss: 0.0900517	valid_0's binary_logloss: 0.0133006
# [68]	training's binary_logloss: 0.0895948	valid_0's binary_logloss: 0.0131822
# [69]	training's binary_logloss: 0.0891386	valid_0's binary_logloss: 0.0130917
# [70]	training's binary_logloss: 0.0886578	valid_0's binary_logloss: 0.0127984
# [71]	training's binary_logloss: 0.0882839	valid_0's binary_logloss: 0.012692
# [72]	training's binary_logloss: 0.0878265	valid_0's binary_logloss: 0.0125977
# [73]	training's binary_logloss: 0.0874366	valid_0's binary_logloss: 0.0123867
# [74]	training's binary_logloss: 0.0870254	valid_0's binary_logloss: 0.0123065
# [75]	training's binary_logloss: 0.0866624	valid_0's binary_logloss: 0.0122843
# [76]	training's binary_logloss: 0.0863353	valid_0's binary_logloss: 0.012001
# [77]	training's binary_logloss: 0.0858804	valid_0's binary_logloss: 0.0119007
# [78]	training's binary_logloss: 0.0853924	valid_0's binary_logloss: 0.0118827
# [79]	training's binary_logloss: 0.0850318	valid_0's binary_logloss: 0.0118071
# [80]	training's binary_logloss: 0.0846043	valid_0's binary_logloss: 0.0117034
# [81]	training's binary_logloss: 0.0841612	valid_0's binary_logloss: 0.0116574
# [82]	training's binary_logloss: 0.0837819	valid_0's binary_logloss: 0.0116217
# [83]	training's binary_logloss: 0.0835287	valid_0's binary_logloss: 0.0115728
# [84]	training's binary_logloss: 0.0830967	valid_0's binary_logloss: 0.0115479
# [85]	training's binary_logloss: 0.0825618	valid_0's binary_logloss: 0.0115495
# [86]	training's binary_logloss: 0.0822328	valid_0's binary_logloss: 0.0114837
# [87]	training's binary_logloss: 0.0819919	valid_0's binary_logloss: 0.0114688
# [88]	training's binary_logloss: 0.081669	valid_0's binary_logloss: 0.0114573
# [89]	training's binary_logloss: 0.0812764	valid_0's binary_logloss: 0.0114312
# [90]	training's binary_logloss: 0.0809752	valid_0's binary_logloss: 0.0114652
# [91]	training's binary_logloss: 0.0805637	valid_0's binary_logloss: 0.0114526
# [92]	training's binary_logloss: 0.08019	valid_0's binary_logloss: 0.0114575
# [93]	training's binary_logloss: 0.0798889	valid_0's binary_logloss: 0.0113999
# [94]	training's binary_logloss: 0.0795977	valid_0's binary_logloss: 0.0112821
# [95]	training's binary_logloss: 0.079259	valid_0's binary_logloss: 0.011263
# [96]	training's binary_logloss: 0.0790142	valid_0's binary_logloss: 0.0112604
# [97]	training's binary_logloss: 0.0786157	valid_0's binary_logloss: 0.011356
# [98]	training's binary_logloss: 0.0781818	valid_0's binary_logloss: 0.0112861
# [99]	training's binary_logloss: 0.0777959	valid_0's binary_logloss: 0.0112453
# [100]	training's binary_logloss: 0.0774467	valid_0's binary_logloss: 0.0112062
# [101]	training's binary_logloss: 0.0771172	valid_0's binary_logloss: 0.0112264
# [102]	training's binary_logloss: 0.0768974	valid_0's binary_logloss: 0.0111564
# [103]	training's binary_logloss: 0.0765702	valid_0's binary_logloss: 0.0111523
# [104]	training's binary_logloss: 0.0762861	valid_0's binary_logloss: 0.0111234
# [105]	training's binary_logloss: 0.0761252	valid_0's binary_logloss: 0.0111083
# [106]	training's binary_logloss: 0.075868	valid_0's binary_logloss: 0.0110436
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.612732	valid_0's binary_logloss: 0.675837
# [2]	training's binary_logloss: 0.553241	valid_0's binary_logloss: 0.600325
# [3]	training's binary_logloss: 0.502439	valid_0's binary_logloss: 0.536319
# [4]	training's binary_logloss: 0.458981	valid_0's binary_logloss: 0.482263
# [5]	training's binary_logloss: 0.421251	valid_0's binary_logloss: 0.435297
# [6]	training's binary_logloss: 0.388755	valid_0's binary_logloss: 0.395148
# [7]	training's binary_logloss: 0.360096	valid_0's binary_logloss: 0.359322
# [8]	training's binary_logloss: 0.33496	valid_0's binary_logloss: 0.328216
# [9]	training's binary_logloss: 0.312656	valid_0's binary_logloss: 0.300674
# [10]	training's binary_logloss: 0.292556	valid_0's binary_logloss: 0.276058
# [11]	training's binary_logloss: 0.274973	valid_0's binary_logloss: 0.254324
# [12]	training's binary_logloss: 0.259111	valid_0's binary_logloss: 0.234686
# [13]	training's binary_logloss: 0.24505	valid_0's binary_logloss: 0.217141
# [14]	training's binary_logloss: 0.232305	valid_0's binary_logloss: 0.20151
# [15]	training's binary_logloss: 0.22094	valid_0's binary_logloss: 0.187399
# [16]	training's binary_logloss: 0.210634	valid_0's binary_logloss: 0.174348
# [17]	training's binary_logloss: 0.201208	valid_0's binary_logloss: 0.162907
# [18]	training's binary_logloss: 0.192673	valid_0's binary_logloss: 0.152661
# [19]	training's binary_logloss: 0.184983	valid_0's binary_logloss: 0.143528
# [20]	training's binary_logloss: 0.177741	valid_0's binary_logloss: 0.13428
# [21]	training's binary_logloss: 0.171219	valid_0's binary_logloss: 0.126103
# [22]	training's binary_logloss: 0.16527	valid_0's binary_logloss: 0.118459
# [23]	training's binary_logloss: 0.159717	valid_0's binary_logloss: 0.111988
# [24]	training's binary_logloss: 0.154824	valid_0's binary_logloss: 0.105703
# [25]	training's binary_logloss: 0.150324	valid_0's binary_logloss: 0.100113
# [26]	training's binary_logloss: 0.146197	valid_0's binary_logloss: 0.095163
# [27]	training's binary_logloss: 0.142124	valid_0's binary_logloss: 0.0902326
# [28]	training's binary_logloss: 0.138739	valid_0's binary_logloss: 0.0861091
# [29]	training's binary_logloss: 0.135584	valid_0's binary_logloss: 0.0823349
# [30]	training's binary_logloss: 0.132521	valid_0's binary_logloss: 0.0787084
# [31]	training's binary_logloss: 0.129911	valid_0's binary_logloss: 0.0753693
# [32]	training's binary_logloss: 0.127259	valid_0's binary_logloss: 0.0722956
# [33]	training's binary_logloss: 0.124868	valid_0's binary_logloss: 0.0691473
# [34]	training's binary_logloss: 0.122389	valid_0's binary_logloss: 0.0662496
# [35]	training's binary_logloss: 0.120284	valid_0's binary_logloss: 0.0641143
# [36]	training's binary_logloss: 0.118286	valid_0's binary_logloss: 0.0614666
# [37]	training's binary_logloss: 0.116545	valid_0's binary_logloss: 0.0589182
# [38]	training's binary_logloss: 0.114767	valid_0's binary_logloss: 0.0568742
# [39]	training's binary_logloss: 0.113267	valid_0's binary_logloss: 0.0550057
# [40]	training's binary_logloss: 0.111733	valid_0's binary_logloss: 0.0533617
# [41]	training's binary_logloss: 0.110334	valid_0's binary_logloss: 0.0518403
# [42]	training's binary_logloss: 0.108899	valid_0's binary_logloss: 0.0500104
# [43]	training's binary_logloss: 0.107669	valid_0's binary_logloss: 0.0490057
# [44]	training's binary_logloss: 0.106414	valid_0's binary_logloss: 0.0476533
# [45]	training's binary_logloss: 0.105299	valid_0's binary_logloss: 0.046254
# [46]	training's binary_logloss: 0.104217	valid_0's binary_logloss: 0.0450973
# [47]	training's binary_logloss: 0.103321	valid_0's binary_logloss: 0.044025
# [48]	training's binary_logloss: 0.102349	valid_0's binary_logloss: 0.04262
# [49]	training's binary_logloss: 0.101424	valid_0's binary_logloss: 0.04168
# [50]	training's binary_logloss: 0.100578	valid_0's binary_logloss: 0.0411573
# [51]	training's binary_logloss: 0.0998502	valid_0's binary_logloss: 0.0403685
# [52]	training's binary_logloss: 0.0991412	valid_0's binary_logloss: 0.0396413
# [53]	training's binary_logloss: 0.0983547	valid_0's binary_logloss: 0.0390173
# [54]	training's binary_logloss: 0.0976967	valid_0's binary_logloss: 0.0384632
# [55]	training's binary_logloss: 0.0970041	valid_0's binary_logloss: 0.0378182
# [56]	training's binary_logloss: 0.0963179	valid_0's binary_logloss: 0.0372568
# [57]	training's binary_logloss: 0.0957273	valid_0's binary_logloss: 0.0367005
# [58]	training's binary_logloss: 0.0950256	valid_0's binary_logloss: 0.03596
# [59]	training's binary_logloss: 0.0943834	valid_0's binary_logloss: 0.0355753
# [60]	training's binary_logloss: 0.0937542	valid_0's binary_logloss: 0.0352387
# [61]	training's binary_logloss: 0.0931613	valid_0's binary_logloss: 0.0347293
# [62]	training's binary_logloss: 0.0926341	valid_0's binary_logloss: 0.0345071
# [63]	training's binary_logloss: 0.0921625	valid_0's binary_logloss: 0.0342544
# [64]	training's binary_logloss: 0.0916654	valid_0's binary_logloss: 0.0340302
# [65]	training's binary_logloss: 0.0911631	valid_0's binary_logloss: 0.0336986
# [66]	training's binary_logloss: 0.0906636	valid_0's binary_logloss: 0.0334799
# [67]	training's binary_logloss: 0.0901194	valid_0's binary_logloss: 0.0332724
# [68]	training's binary_logloss: 0.0898105	valid_0's binary_logloss: 0.0328892
# [69]	training's binary_logloss: 0.0894377	valid_0's binary_logloss: 0.032663
# [70]	training's binary_logloss: 0.0889965	valid_0's binary_logloss: 0.0324992
# [71]	training's binary_logloss: 0.0887485	valid_0's binary_logloss: 0.0323234
# [72]	training's binary_logloss: 0.0881958	valid_0's binary_logloss: 0.0318423
# [73]	training's binary_logloss: 0.0876492	valid_0's binary_logloss: 0.0312551
# [74]	training's binary_logloss: 0.08709	valid_0's binary_logloss: 0.0310022
# [75]	training's binary_logloss: 0.0867671	valid_0's binary_logloss: 0.0306993
# [76]	training's binary_logloss: 0.086293	valid_0's binary_logloss: 0.0305545
# [77]	training's binary_logloss: 0.0858134	valid_0's binary_logloss: 0.0302922
# [78]	training's binary_logloss: 0.0853764	valid_0's binary_logloss: 0.0301768
# [79]	training's binary_logloss: 0.0849164	valid_0's binary_logloss: 0.0300822
# [80]	training's binary_logloss: 0.084683	valid_0's binary_logloss: 0.0298788
# [81]	training's binary_logloss: 0.0842759	valid_0's binary_logloss: 0.0297679
# [82]	training's binary_logloss: 0.0838548	valid_0's binary_logloss: 0.0297039
# [83]	training's binary_logloss: 0.083448	valid_0's binary_logloss: 0.0295254
# [84]	training's binary_logloss: 0.0832295	valid_0's binary_logloss: 0.0294662
# [85]	training's binary_logloss: 0.0828553	valid_0's binary_logloss: 0.0293738
# [86]	training's binary_logloss: 0.0825058	valid_0's binary_logloss: 0.0293535
# [87]	training's binary_logloss: 0.0821357	valid_0's binary_logloss: 0.0290392
# [88]	training's binary_logloss: 0.081963	valid_0's binary_logloss: 0.0288879
# [89]	training's binary_logloss: 0.0815429	valid_0's binary_logloss: 0.0287975
# [90]	training's binary_logloss: 0.0811231	valid_0's binary_logloss: 0.0286751
# [91]	training's binary_logloss: 0.0809491	valid_0's binary_logloss: 0.0285551
# [92]	training's binary_logloss: 0.0805306	valid_0's binary_logloss: 0.0284796
# [93]	training's binary_logloss: 0.0801727	valid_0's binary_logloss: 0.0283934
# [94]	training's binary_logloss: 0.0798543	valid_0's binary_logloss: 0.0283787
# [95]	training's binary_logloss: 0.0796302	valid_0's binary_logloss: 0.0283406
# [96]	training's binary_logloss: 0.0793967	valid_0's binary_logloss: 0.0282461
# [97]	training's binary_logloss: 0.0790843	valid_0's binary_logloss: 0.0281617
# [98]	training's binary_logloss: 0.0787082	valid_0's binary_logloss: 0.0280997
# [99]	training's binary_logloss: 0.0783856	valid_0's binary_logloss: 0.0280945
# [100]	training's binary_logloss: 0.0781018	valid_0's binary_logloss: 0.0280258
# [101]	training's binary_logloss: 0.0777481	valid_0's binary_logloss: 0.0279276
# [102]	training's binary_logloss: 0.0773781	valid_0's binary_logloss: 0.0277272
# [103]	training's binary_logloss: 0.077182	valid_0's binary_logloss: 0.0276198
# [104]	training's binary_logloss: 0.0768419	valid_0's binary_logloss: 0.0274498
# [105]	training's binary_logloss: 0.0766163	valid_0's binary_logloss: 0.0274337
# [106]	training's binary_logloss: 0.0763147	valid_0's binary_logloss: 0.027354
# ---Run time is 5.75461859999632 seconds ---
#
# Accuracy of each fold:
#  [0.9164759725400458, 0.9545638945233266, 0.9962216624685138, 0.9316546762589928, 0.9973876698014629, 0.9582150101419878, 0.7580569827183559, 0.998638529611981, 0.9397590361445783, 0.9707828004410143, 0.9823049001814882, 0.9913854989231874, 0.8303854875283446, 0.956687898089172, 0.601165695253955, 0.9884802835622508, 0.9890335846470185, 0.9878822850548182, 0.7540152155536771, 0.9708631115997801, 0.9965782720273738, 0.9968612680477087, 0.9978858350951374]
#
# Avg accuracy :
# 0.9332732856614858
#
# Std of accuracy :
# 0.09955941484364123

# %%
print(confusion_matrix(Truth, Output))
print(classification_report(Truth, Output))
print(acc_score)
print(elapsed)
# [[22875  1868]
#  [ 1984 18241]]
# Accuracy of each fold: 
#  [0.9096109839816934, 0.9533468559837728, 0.9955919395465995, 0.8974820143884892, 0.9947753396029259, 0.9484787018255578, 0.832788416627744, 0.9965963240299524, 0.9362449799196787, 0.964167585446527, 0.9818511796733213, 0.9899497487437185, 0.7836734693877551, 0.9178343949044586, 0.4995836802664446, 0.9787328311918476, 0.9876627827278959, 0.9924985574148875, 0.7176669484361792, 0.9741616272677295, 0.9957228400342173, 0.9912115505335845, 0.9877378435517971]

# Avg accuracy : 
# 0.9229291563255121

# Std of accuracy : 
# 0.11533339006243011
# Out:
# [[23106  1637]
#  [ 1709 18516]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93     24743
#            1       0.92      0.92      0.92     20225
#
#     accuracy                           0.93     44968
#    macro avg       0.92      0.92      0.92     44968
# weighted avg       0.93      0.93      0.93     44968
#
# [0.9164759725400458, 0.9545638945233266, 0.9962216624685138, 0.9316546762589928, 0.9973876698014629, 0.9582150101419878, 0.7580569827183559, 0.998638529611981, 0.9397590361445783, 0.9707828004410143, 0.9823049001814882, 0.9913854989231874, 0.8303854875283446, 0.956687898089172, 0.601165695253955, 0.9884802835622508, 0.9890335846470185, 0.9878822850548182, 0.7540152155536771, 0.9708631115997801, 0.9965782720273738, 0.9968612680477087, 0.9978858350951374]
# 5.75461859999632

# %%
import lightgbm

#Implementing cross validation 
kf = KFold(n_splits=23, random_state=1, shuffle=True)


from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
n_estimators_list = []
max_depth_list = []

x_values = ['StoS', 'StoR', 'StoL', 'RtoS', 'RtoR', 'RtoL', 'LtoS',
       'LtoR', 'LtoL', 'STD', 'CoefVar', 'Range', 'Volatility', 'ShEn',
       'AppEn', 'SampEn']
y_values = ['Rhythm']
df = features_maindf

for idx, subject in enumerate(good_list):
    
    train_index = ~df['Subject'].str.contains(subject)
    test_index = df['Subject'].str.contains(subject)
    X_train , X_test = df.loc[train_index,x_values], df.loc[test_index,x_values]
    y_train , y_test = df.loc[train_index,y_values].values.ravel(), df.loc[test_index,y_values]

#     temp_model = model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],eval_metric='logloss')    
#     param_distributions = {'n_estimators': randint(105, 110),
#                            'max_depth': randint(7,10)}

#     search = RandomizedSearchCV(estimator=temp_model, param_distributions=param_distributions, random_state=0)
#     search.fit(X_train, y_train)

#     n_estimators_list.append(search.best_params_['n_estimators'])
#     max_depth_list.append(search.best_params_['max_depth'])

#     model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],
#           eval_metric='logloss')
    model = lightgbm.LGBMClassifier(learning_rate=0.09,max_depth=5, random_state=42)
    
    # Create the LightGBM data containers
    model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],
          eval_metric='logloss')

    pred_values = model.predict(X_test)
     
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list  
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)}, 
                          index = (X_train.columns))
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    #plt.savefig('plot1.png')


elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
# Out:
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.619785	valid_0's binary_logloss: 0.571695
# [2]	training's binary_logloss: 0.560111	valid_0's binary_logloss: 0.522158
# [3]	training's binary_logloss: 0.508618	valid_0's binary_logloss: 0.479956
# [4]	training's binary_logloss: 0.464706	valid_0's binary_logloss: 0.445
# [5]	training's binary_logloss: 0.426801	valid_0's binary_logloss: 0.414863
# [6]	training's binary_logloss: 0.393525	valid_0's binary_logloss: 0.389393
# [7]	training's binary_logloss: 0.364499	valid_0's binary_logloss: 0.366794
# [8]	training's binary_logloss: 0.338916	valid_0's binary_logloss: 0.347773
# [9]	training's binary_logloss: 0.316286	valid_0's binary_logloss: 0.330947
# [10]	training's binary_logloss: 0.296104	valid_0's binary_logloss: 0.316558
# [11]	training's binary_logloss: 0.278171	valid_0's binary_logloss: 0.304312
# [12]	training's binary_logloss: 0.262098	valid_0's binary_logloss: 0.293579
# [13]	training's binary_logloss: 0.247713	valid_0's binary_logloss: 0.284032
# [14]	training's binary_logloss: 0.234962	valid_0's binary_logloss: 0.27596
# [15]	training's binary_logloss: 0.223295	valid_0's binary_logloss: 0.268809
# [16]	training's binary_logloss: 0.212947	valid_0's binary_logloss: 0.263501
# [17]	training's binary_logloss: 0.203376	valid_0's binary_logloss: 0.258292
# [18]	training's binary_logloss: 0.194764	valid_0's binary_logloss: 0.254183
# [19]	training's binary_logloss: 0.187042	valid_0's binary_logloss: 0.250499
# [20]	training's binary_logloss: 0.179714	valid_0's binary_logloss: 0.247688
# [21]	training's binary_logloss: 0.17324	valid_0's binary_logloss: 0.244053
# [22]	training's binary_logloss: 0.166922	valid_0's binary_logloss: 0.242555
# [23]	training's binary_logloss: 0.161323	valid_0's binary_logloss: 0.240105
# [24]	training's binary_logloss: 0.156492	valid_0's binary_logloss: 0.238033
# [25]	training's binary_logloss: 0.152064	valid_0's binary_logloss: 0.237149
# [26]	training's binary_logloss: 0.147591	valid_0's binary_logloss: 0.235951
# [27]	training's binary_logloss: 0.143732	valid_0's binary_logloss: 0.235391
# [28]	training's binary_logloss: 0.140392	valid_0's binary_logloss: 0.23546
# [29]	training's binary_logloss: 0.137194	valid_0's binary_logloss: 0.235599
# [30]	training's binary_logloss: 0.134378	valid_0's binary_logloss: 0.235939
# [31]	training's binary_logloss: 0.131821	valid_0's binary_logloss: 0.236727
# [32]	training's binary_logloss: 0.1291	valid_0's binary_logloss: 0.237445
# [33]	training's binary_logloss: 0.126759	valid_0's binary_logloss: 0.237199
# [34]	training's binary_logloss: 0.124732	valid_0's binary_logloss: 0.237253
# [35]	training's binary_logloss: 0.122743	valid_0's binary_logloss: 0.238253
# [36]	training's binary_logloss: 0.120935	valid_0's binary_logloss: 0.237986
# [37]	training's binary_logloss: 0.1193	valid_0's binary_logloss: 0.23851
# [38]	training's binary_logloss: 0.117695	valid_0's binary_logloss: 0.238828
# [39]	training's binary_logloss: 0.116018	valid_0's binary_logloss: 0.239667
# [40]	training's binary_logloss: 0.114464	valid_0's binary_logloss: 0.239787
# [41]	training's binary_logloss: 0.113063	valid_0's binary_logloss: 0.240745
# [42]	training's binary_logloss: 0.111872	valid_0's binary_logloss: 0.24111
# [43]	training's binary_logloss: 0.110766	valid_0's binary_logloss: 0.242471
# [44]	training's binary_logloss: 0.10955	valid_0's binary_logloss: 0.242116
# [45]	training's binary_logloss: 0.108561	valid_0's binary_logloss: 0.242822
# [46]	training's binary_logloss: 0.107328	valid_0's binary_logloss: 0.244018
# [47]	training's binary_logloss: 0.106377	valid_0's binary_logloss: 0.244498
# [48]	training's binary_logloss: 0.105382	valid_0's binary_logloss: 0.244598
# [49]	training's binary_logloss: 0.104475	valid_0's binary_logloss: 0.244916
# [50]	training's binary_logloss: 0.103543	valid_0's binary_logloss: 0.245397
# [51]	training's binary_logloss: 0.102844	valid_0's binary_logloss: 0.246685
# [52]	training's binary_logloss: 0.102254	valid_0's binary_logloss: 0.246968
# [53]	training's binary_logloss: 0.101363	valid_0's binary_logloss: 0.247039
# [54]	training's binary_logloss: 0.100859	valid_0's binary_logloss: 0.246906
# [55]	training's binary_logloss: 0.100355	valid_0's binary_logloss: 0.247453
# [56]	training's binary_logloss: 0.0997699	valid_0's binary_logloss: 0.248444
# [57]	training's binary_logloss: 0.0992898	valid_0's binary_logloss: 0.248413
# [58]	training's binary_logloss: 0.0984303	valid_0's binary_logloss: 0.250022
# [59]	training's binary_logloss: 0.0978823	valid_0's binary_logloss: 0.249676
# [60]	training's binary_logloss: 0.0973609	valid_0's binary_logloss: 0.250453
# [61]	training's binary_logloss: 0.0969296	valid_0's binary_logloss: 0.25012
# [62]	training's binary_logloss: 0.0963086	valid_0's binary_logloss: 0.250423
# [63]	training's binary_logloss: 0.0955841	valid_0's binary_logloss: 0.251118
# [64]	training's binary_logloss: 0.0950864	valid_0's binary_logloss: 0.251393
# [65]	training's binary_logloss: 0.0944721	valid_0's binary_logloss: 0.251205
# [66]	training's binary_logloss: 0.0940888	valid_0's binary_logloss: 0.25143
# [67]	training's binary_logloss: 0.0935849	valid_0's binary_logloss: 0.252221
# [68]	training's binary_logloss: 0.0930246	valid_0's binary_logloss: 0.252457
# [69]	training's binary_logloss: 0.0924621	valid_0's binary_logloss: 0.253603
# [70]	training's binary_logloss: 0.0921429	valid_0's binary_logloss: 0.254048
# [71]	training's binary_logloss: 0.09186	valid_0's binary_logloss: 0.254412
# [72]	training's binary_logloss: 0.0912819	valid_0's binary_logloss: 0.254691
# [73]	training's binary_logloss: 0.0910022	valid_0's binary_logloss: 0.255154
# [74]	training's binary_logloss: 0.0904694	valid_0's binary_logloss: 0.255866
# [75]	training's binary_logloss: 0.0900535	valid_0's binary_logloss: 0.255023
# [76]	training's binary_logloss: 0.0897939	valid_0's binary_logloss: 0.254903
# [77]	training's binary_logloss: 0.0893774	valid_0's binary_logloss: 0.255953
# [78]	training's binary_logloss: 0.0888311	valid_0's binary_logloss: 0.257101
# [79]	training's binary_logloss: 0.0886319	valid_0's binary_logloss: 0.257553
# [80]	training's binary_logloss: 0.0882713	valid_0's binary_logloss: 0.25867
# [81]	training's binary_logloss: 0.0878791	valid_0's binary_logloss: 0.259094
# [82]	training's binary_logloss: 0.0874142	valid_0's binary_logloss: 0.258936
# [83]	training's binary_logloss: 0.0868763	valid_0's binary_logloss: 0.259305
# [84]	training's binary_logloss: 0.0866718	valid_0's binary_logloss: 0.26056
# [85]	training's binary_logloss: 0.0861692	valid_0's binary_logloss: 0.260707
# [86]	training's binary_logloss: 0.0860402	valid_0's binary_logloss: 0.261565
# [87]	training's binary_logloss: 0.0858138	valid_0's binary_logloss: 0.261514
# [88]	training's binary_logloss: 0.0853743	valid_0's binary_logloss: 0.26155
# [89]	training's binary_logloss: 0.0850156	valid_0's binary_logloss: 0.261586
# [90]	training's binary_logloss: 0.0846387	valid_0's binary_logloss: 0.261698
# [91]	training's binary_logloss: 0.0845146	valid_0's binary_logloss: 0.262401
# [92]	training's binary_logloss: 0.084141	valid_0's binary_logloss: 0.262589
# [93]	training's binary_logloss: 0.0838539	valid_0's binary_logloss: 0.263666
# [94]	training's binary_logloss: 0.0835828	valid_0's binary_logloss: 0.263632
# [95]	training's binary_logloss: 0.0831111	valid_0's binary_logloss: 0.263875
# [96]	training's binary_logloss: 0.082971	valid_0's binary_logloss: 0.264535
# [97]	training's binary_logloss: 0.0824538	valid_0's binary_logloss: 0.264662
# [98]	training's binary_logloss: 0.0823093	valid_0's binary_logloss: 0.264559
# [99]	training's binary_logloss: 0.0820113	valid_0's binary_logloss: 0.264655
# [100]	training's binary_logloss: 0.0816826	valid_0's binary_logloss: 0.265243
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.619457	valid_0's binary_logloss: 0.588633
# [2]	training's binary_logloss: 0.560417	valid_0's binary_logloss: 0.532332
# [3]	training's binary_logloss: 0.509475	valid_0's binary_logloss: 0.483348
# [4]	training's binary_logloss: 0.465921	valid_0's binary_logloss: 0.442001
# [5]	training's binary_logloss: 0.428195	valid_0's binary_logloss: 0.405542
# [6]	training's binary_logloss: 0.395441	valid_0's binary_logloss: 0.375074
# [7]	training's binary_logloss: 0.366724	valid_0's binary_logloss: 0.346869
# [8]	training's binary_logloss: 0.341186	valid_0's binary_logloss: 0.322124
# [9]	training's binary_logloss: 0.318579	valid_0's binary_logloss: 0.300297
# [10]	training's binary_logloss: 0.298644	valid_0's binary_logloss: 0.281749
# [11]	training's binary_logloss: 0.280906	valid_0's binary_logloss: 0.264615
# [12]	training's binary_logloss: 0.264934	valid_0's binary_logloss: 0.250217
# [13]	training's binary_logloss: 0.250709	valid_0's binary_logloss: 0.236351
# [14]	training's binary_logloss: 0.237901	valid_0's binary_logloss: 0.224414
# [15]	training's binary_logloss: 0.226489	valid_0's binary_logloss: 0.213185
# [16]	training's binary_logloss: 0.21611	valid_0's binary_logloss: 0.203975
# [17]	training's binary_logloss: 0.206866	valid_0's binary_logloss: 0.194955
# [18]	training's binary_logloss: 0.198408	valid_0's binary_logloss: 0.187321
# [19]	training's binary_logloss: 0.190646	valid_0's binary_logloss: 0.180647
# [20]	training's binary_logloss: 0.183308	valid_0's binary_logloss: 0.174208
# [21]	training's binary_logloss: 0.176967	valid_0's binary_logloss: 0.168783
# [22]	training's binary_logloss: 0.170896	valid_0's binary_logloss: 0.163673
# [23]	training's binary_logloss: 0.165569	valid_0's binary_logloss: 0.159333
# [24]	training's binary_logloss: 0.160684	valid_0's binary_logloss: 0.155425
# [25]	training's binary_logloss: 0.156172	valid_0's binary_logloss: 0.15143
# [26]	training's binary_logloss: 0.151984	valid_0's binary_logloss: 0.148154
# [27]	training's binary_logloss: 0.148335	valid_0's binary_logloss: 0.145468
# [28]	training's binary_logloss: 0.144929	valid_0's binary_logloss: 0.142772
# [29]	training's binary_logloss: 0.141619	valid_0's binary_logloss: 0.140039
# [30]	training's binary_logloss: 0.138353	valid_0's binary_logloss: 0.137848
# [31]	training's binary_logloss: 0.135504	valid_0's binary_logloss: 0.136149
# [32]	training's binary_logloss: 0.133006	valid_0's binary_logloss: 0.134523
# [33]	training's binary_logloss: 0.130529	valid_0's binary_logloss: 0.13286
# [34]	training's binary_logloss: 0.128369	valid_0's binary_logloss: 0.131595
# [35]	training's binary_logloss: 0.126003	valid_0's binary_logloss: 0.130306
# [36]	training's binary_logloss: 0.124246	valid_0's binary_logloss: 0.129421
# [37]	training's binary_logloss: 0.122394	valid_0's binary_logloss: 0.128724
# [38]	training's binary_logloss: 0.120605	valid_0's binary_logloss: 0.127758
# [39]	training's binary_logloss: 0.118954	valid_0's binary_logloss: 0.127116
# [40]	training's binary_logloss: 0.11758	valid_0's binary_logloss: 0.126357
# [41]	training's binary_logloss: 0.116379	valid_0's binary_logloss: 0.125941
# [42]	training's binary_logloss: 0.115297	valid_0's binary_logloss: 0.125144
# [43]	training's binary_logloss: 0.114226	valid_0's binary_logloss: 0.125112
# [44]	training's binary_logloss: 0.113413	valid_0's binary_logloss: 0.124515
# [45]	training's binary_logloss: 0.112312	valid_0's binary_logloss: 0.124445
# [46]	training's binary_logloss: 0.111414	valid_0's binary_logloss: 0.124636
# [47]	training's binary_logloss: 0.110426	valid_0's binary_logloss: 0.124011
# [48]	training's binary_logloss: 0.109376	valid_0's binary_logloss: 0.123948
# [49]	training's binary_logloss: 0.108477	valid_0's binary_logloss: 0.123855
# [50]	training's binary_logloss: 0.10777	valid_0's binary_logloss: 0.123805
# [51]	training's binary_logloss: 0.106932	valid_0's binary_logloss: 0.124049
# [52]	training's binary_logloss: 0.106197	valid_0's binary_logloss: 0.123628
# [53]	training's binary_logloss: 0.105435	valid_0's binary_logloss: 0.123531
# [54]	training's binary_logloss: 0.104847	valid_0's binary_logloss: 0.123567
# [55]	training's binary_logloss: 0.104259	valid_0's binary_logloss: 0.12347
# [56]	training's binary_logloss: 0.103809	valid_0's binary_logloss: 0.123567
# [57]	training's binary_logloss: 0.103174	valid_0's binary_logloss: 0.123073
# [58]	training's binary_logloss: 0.102599	valid_0's binary_logloss: 0.122716
# [59]	training's binary_logloss: 0.101994	valid_0's binary_logloss: 0.122087
# [60]	training's binary_logloss: 0.10151	valid_0's binary_logloss: 0.122012
# [61]	training's binary_logloss: 0.101036	valid_0's binary_logloss: 0.121736
# [62]	training's binary_logloss: 0.10069	valid_0's binary_logloss: 0.121795
# [63]	training's binary_logloss: 0.100106	valid_0's binary_logloss: 0.121863
# [64]	training's binary_logloss: 0.0994898	valid_0's binary_logloss: 0.121508
# [65]	training's binary_logloss: 0.0991224	valid_0's binary_logloss: 0.121341
# [66]	training's binary_logloss: 0.0986256	valid_0's binary_logloss: 0.121462
# [67]	training's binary_logloss: 0.0983237	valid_0's binary_logloss: 0.121531
# [68]	training's binary_logloss: 0.0977618	valid_0's binary_logloss: 0.121403
# [69]	training's binary_logloss: 0.0971718	valid_0's binary_logloss: 0.121018
# [70]	training's binary_logloss: 0.0967972	valid_0's binary_logloss: 0.12094
# [71]	training's binary_logloss: 0.0962983	valid_0's binary_logloss: 0.120897
# [72]	training's binary_logloss: 0.0956627	valid_0's binary_logloss: 0.12094
# [73]	training's binary_logloss: 0.0954412	valid_0's binary_logloss: 0.121001
# [74]	training's binary_logloss: 0.0949713	valid_0's binary_logloss: 0.120782
# [75]	training's binary_logloss: 0.0946001	valid_0's binary_logloss: 0.12091
# [76]	training's binary_logloss: 0.0943921	valid_0's binary_logloss: 0.120749
# [77]	training's binary_logloss: 0.0941873	valid_0's binary_logloss: 0.120793
# [78]	training's binary_logloss: 0.0938188	valid_0's binary_logloss: 0.12069
# [79]	training's binary_logloss: 0.0936619	valid_0's binary_logloss: 0.120575
# [80]	training's binary_logloss: 0.093466	valid_0's binary_logloss: 0.120525
# [81]	training's binary_logloss: 0.0928999	valid_0's binary_logloss: 0.12064
# [82]	training's binary_logloss: 0.0926151	valid_0's binary_logloss: 0.120842
# [83]	training's binary_logloss: 0.0921517	valid_0's binary_logloss: 0.120852
# [84]	training's binary_logloss: 0.0917606	valid_0's binary_logloss: 0.12076
# [85]	training's binary_logloss: 0.0915367	valid_0's binary_logloss: 0.120909
# [86]	training's binary_logloss: 0.0912201	valid_0's binary_logloss: 0.120797
# [87]	training's binary_logloss: 0.0908262	valid_0's binary_logloss: 0.12091
# [88]	training's binary_logloss: 0.0904129	valid_0's binary_logloss: 0.12113
# [89]	training's binary_logloss: 0.0902776	valid_0's binary_logloss: 0.121203
# [90]	training's binary_logloss: 0.0899599	valid_0's binary_logloss: 0.12125
# [91]	training's binary_logloss: 0.0897576	valid_0's binary_logloss: 0.121261
# [92]	training's binary_logloss: 0.0894607	valid_0's binary_logloss: 0.121151
# [93]	training's binary_logloss: 0.0890539	valid_0's binary_logloss: 0.121284
# [94]	training's binary_logloss: 0.0886074	valid_0's binary_logloss: 0.121356
# [95]	training's binary_logloss: 0.0883409	valid_0's binary_logloss: 0.121539
# [96]	training's binary_logloss: 0.088121	valid_0's binary_logloss: 0.12166
# [97]	training's binary_logloss: 0.0878066	valid_0's binary_logloss: 0.121542
# [98]	training's binary_logloss: 0.0875487	valid_0's binary_logloss: 0.121439
# [99]	training's binary_logloss: 0.0874306	valid_0's binary_logloss: 0.121435
# [100]	training's binary_logloss: 0.0871104	valid_0's binary_logloss: 0.121255
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.620399	valid_0's binary_logloss: 0.555687
# [2]	training's binary_logloss: 0.561544	valid_0's binary_logloss: 0.493788
# [3]	training's binary_logloss: 0.511606	valid_0's binary_logloss: 0.440647
# [4]	training's binary_logloss: 0.46808	valid_0's binary_logloss: 0.394532
# [5]	training's binary_logloss: 0.430544	valid_0's binary_logloss: 0.35443
# [6]	training's binary_logloss: 0.397563	valid_0's binary_logloss: 0.319224
# [7]	training's binary_logloss: 0.368817	valid_0's binary_logloss: 0.288419
# [8]	training's binary_logloss: 0.34345	valid_0's binary_logloss: 0.261193
# [9]	training's binary_logloss: 0.321015	valid_0's binary_logloss: 0.236824
# [10]	training's binary_logloss: 0.301176	valid_0's binary_logloss: 0.215177
# [11]	training's binary_logloss: 0.283526	valid_0's binary_logloss: 0.195767
# [12]	training's binary_logloss: 0.267752	valid_0's binary_logloss: 0.178418
# [13]	training's binary_logloss: 0.253645	valid_0's binary_logloss: 0.162775
# [14]	training's binary_logloss: 0.240949	valid_0's binary_logloss: 0.148869
# [15]	training's binary_logloss: 0.229344	valid_0's binary_logloss: 0.136286
# [16]	training's binary_logloss: 0.219058	valid_0's binary_logloss: 0.124858
# [17]	training's binary_logloss: 0.2097	valid_0's binary_logloss: 0.114374
# [18]	training's binary_logloss: 0.201449	valid_0's binary_logloss: 0.105022
# [19]	training's binary_logloss: 0.193711	valid_0's binary_logloss: 0.0964327
# [20]	training's binary_logloss: 0.186832	valid_0's binary_logloss: 0.0888099
# [21]	training's binary_logloss: 0.180241	valid_0's binary_logloss: 0.0819007
# [22]	training's binary_logloss: 0.174264	valid_0's binary_logloss: 0.0755814
# [23]	training's binary_logloss: 0.168871	valid_0's binary_logloss: 0.0697963
# [24]	training's binary_logloss: 0.16407	valid_0's binary_logloss: 0.0646452
# [25]	training's binary_logloss: 0.159644	valid_0's binary_logloss: 0.0598225
# [26]	training's binary_logloss: 0.155611	valid_0's binary_logloss: 0.0555077
# [27]	training's binary_logloss: 0.151849	valid_0's binary_logloss: 0.05159
# [28]	training's binary_logloss: 0.148452	valid_0's binary_logloss: 0.0478808
# [29]	training's binary_logloss: 0.144746	valid_0's binary_logloss: 0.0446134
# [30]	training's binary_logloss: 0.141602	valid_0's binary_logloss: 0.0415591
# [31]	training's binary_logloss: 0.138834	valid_0's binary_logloss: 0.038778
# [32]	training's binary_logloss: 0.136378	valid_0's binary_logloss: 0.0362232
# [33]	training's binary_logloss: 0.134175	valid_0's binary_logloss: 0.0339841
# [34]	training's binary_logloss: 0.131951	valid_0's binary_logloss: 0.0319507
# [35]	training's binary_logloss: 0.129798	valid_0's binary_logloss: 0.0301278
# [36]	training's binary_logloss: 0.128019	valid_0's binary_logloss: 0.0283811
# [37]	training's binary_logloss: 0.126243	valid_0's binary_logloss: 0.0267937
# [38]	training's binary_logloss: 0.124691	valid_0's binary_logloss: 0.0253564
# [39]	training's binary_logloss: 0.122997	valid_0's binary_logloss: 0.024042
# [40]	training's binary_logloss: 0.121689	valid_0's binary_logloss: 0.0228232
# [41]	training's binary_logloss: 0.120557	valid_0's binary_logloss: 0.0218679
# [42]	training's binary_logloss: 0.11913	valid_0's binary_logloss: 0.0208374
# [43]	training's binary_logloss: 0.117984	valid_0's binary_logloss: 0.0198732
# [44]	training's binary_logloss: 0.116961	valid_0's binary_logloss: 0.0190362
# [45]	training's binary_logloss: 0.11585	valid_0's binary_logloss: 0.0182587
# [46]	training's binary_logloss: 0.114775	valid_0's binary_logloss: 0.0174851
# [47]	training's binary_logloss: 0.113896	valid_0's binary_logloss: 0.0168188
# [48]	training's binary_logloss: 0.1132	valid_0's binary_logloss: 0.0161827
# [49]	training's binary_logloss: 0.112392	valid_0's binary_logloss: 0.0156123
# [50]	training's binary_logloss: 0.111498	valid_0's binary_logloss: 0.0150402
# [51]	training's binary_logloss: 0.110828	valid_0's binary_logloss: 0.0145653
# [52]	training's binary_logloss: 0.11008	valid_0's binary_logloss: 0.0142394
# [53]	training's binary_logloss: 0.109289	valid_0's binary_logloss: 0.0138086
# [54]	training's binary_logloss: 0.108837	valid_0's binary_logloss: 0.0135237
# [55]	training's binary_logloss: 0.108035	valid_0's binary_logloss: 0.0131646
# [56]	training's binary_logloss: 0.107555	valid_0's binary_logloss: 0.0128751
# [57]	training's binary_logloss: 0.106927	valid_0's binary_logloss: 0.0125809
# [58]	training's binary_logloss: 0.106139	valid_0's binary_logloss: 0.0123608
# [59]	training's binary_logloss: 0.105659	valid_0's binary_logloss: 0.0122031
# [60]	training's binary_logloss: 0.104889	valid_0's binary_logloss: 0.0119894
# [61]	training's binary_logloss: 0.104276	valid_0's binary_logloss: 0.0118488
# [62]	training's binary_logloss: 0.103565	valid_0's binary_logloss: 0.0116154
# [63]	training's binary_logloss: 0.103077	valid_0's binary_logloss: 0.011431
# [64]	training's binary_logloss: 0.102701	valid_0's binary_logloss: 0.0113698
# [65]	training's binary_logloss: 0.102052	valid_0's binary_logloss: 0.0112444
# [66]	training's binary_logloss: 0.101412	valid_0's binary_logloss: 0.0110928
# [67]	training's binary_logloss: 0.101109	valid_0's binary_logloss: 0.0110365
# [68]	training's binary_logloss: 0.100493	valid_0's binary_logloss: 0.0109761
# [69]	training's binary_logloss: 0.0999773	valid_0's binary_logloss: 0.0109554
# [70]	training's binary_logloss: 0.0996668	valid_0's binary_logloss: 0.010887
# [71]	training's binary_logloss: 0.0992213	valid_0's binary_logloss: 0.0108329
# [72]	training's binary_logloss: 0.0988367	valid_0's binary_logloss: 0.0107107
# [73]	training's binary_logloss: 0.0984877	valid_0's binary_logloss: 0.0107253
# [74]	training's binary_logloss: 0.0977929	valid_0's binary_logloss: 0.0106744
# [75]	training's binary_logloss: 0.0975425	valid_0's binary_logloss: 0.0106103
# [76]	training's binary_logloss: 0.0973236	valid_0's binary_logloss: 0.0106733
# [77]	training's binary_logloss: 0.0971389	valid_0's binary_logloss: 0.0105737
# [78]	training's binary_logloss: 0.0967031	valid_0's binary_logloss: 0.0105117
# [79]	training's binary_logloss: 0.0964633	valid_0's binary_logloss: 0.0105421
# [80]	training's binary_logloss: 0.0962548	valid_0's binary_logloss: 0.0104768
# [81]	training's binary_logloss: 0.0961051	valid_0's binary_logloss: 0.010422
# [82]	training's binary_logloss: 0.0955235	valid_0's binary_logloss: 0.0104212
# [83]	training's binary_logloss: 0.0951191	valid_0's binary_logloss: 0.0103623
# [84]	training's binary_logloss: 0.0946864	valid_0's binary_logloss: 0.0104097
# [85]	training's binary_logloss: 0.0942472	valid_0's binary_logloss: 0.0103946
# [86]	training's binary_logloss: 0.0940244	valid_0's binary_logloss: 0.0105368
# [87]	training's binary_logloss: 0.0936585	valid_0's binary_logloss: 0.010598
# [88]	training's binary_logloss: 0.0935085	valid_0's binary_logloss: 0.0105796
# [89]	training's binary_logloss: 0.0933641	valid_0's binary_logloss: 0.0106113
# [90]	training's binary_logloss: 0.0930983	valid_0's binary_logloss: 0.0105617
# [91]	training's binary_logloss: 0.092821	valid_0's binary_logloss: 0.0106321
# [92]	training's binary_logloss: 0.0925854	valid_0's binary_logloss: 0.0105764
# [93]	training's binary_logloss: 0.0922614	valid_0's binary_logloss: 0.0105368
# [94]	training's binary_logloss: 0.0918919	valid_0's binary_logloss: 0.0105085
# [95]	training's binary_logloss: 0.0917793	valid_0's binary_logloss: 0.0106287
# [96]	training's binary_logloss: 0.0914334	valid_0's binary_logloss: 0.0106377
# [97]	training's binary_logloss: 0.0911337	valid_0's binary_logloss: 0.0105849
# [98]	training's binary_logloss: 0.0908701	valid_0's binary_logloss: 0.0105729
# [99]	training's binary_logloss: 0.0905758	valid_0's binary_logloss: 0.0105459
# [100]	training's binary_logloss: 0.0903229	valid_0's binary_logloss: 0.0105197
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.618607	valid_0's binary_logloss: 0.58306
# [2]	training's binary_logloss: 0.558485	valid_0's binary_logloss: 0.542338
# [3]	training's binary_logloss: 0.507351	valid_0's binary_logloss: 0.510876
# [4]	training's binary_logloss: 0.463656	valid_0's binary_logloss: 0.482032
# [5]	training's binary_logloss: 0.425722	valid_0's binary_logloss: 0.459296
# [6]	training's binary_logloss: 0.392816	valid_0's binary_logloss: 0.438448
# [7]	training's binary_logloss: 0.363873	valid_0's binary_logloss: 0.418649
# [8]	training's binary_logloss: 0.338315	valid_0's binary_logloss: 0.401452
# [9]	training's binary_logloss: 0.315669	valid_0's binary_logloss: 0.383506
# [10]	training's binary_logloss: 0.295801	valid_0's binary_logloss: 0.368383
# [11]	training's binary_logloss: 0.277991	valid_0's binary_logloss: 0.356025
# [12]	training's binary_logloss: 0.262093	valid_0's binary_logloss: 0.345996
# [13]	training's binary_logloss: 0.247917	valid_0's binary_logloss: 0.336213
# [14]	training's binary_logloss: 0.235142	valid_0's binary_logloss: 0.325624
# [15]	training's binary_logloss: 0.223431	valid_0's binary_logloss: 0.316242
# [16]	training's binary_logloss: 0.21297	valid_0's binary_logloss: 0.307554
# [17]	training's binary_logloss: 0.203452	valid_0's binary_logloss: 0.300388
# [18]	training's binary_logloss: 0.195097	valid_0's binary_logloss: 0.294166
# [19]	training's binary_logloss: 0.187413	valid_0's binary_logloss: 0.285981
# [20]	training's binary_logloss: 0.180328	valid_0's binary_logloss: 0.279836
# [21]	training's binary_logloss: 0.174011	valid_0's binary_logloss: 0.274559
# [22]	training's binary_logloss: 0.168293	valid_0's binary_logloss: 0.269537
# [23]	training's binary_logloss: 0.163149	valid_0's binary_logloss: 0.263948
# [24]	training's binary_logloss: 0.15807	valid_0's binary_logloss: 0.259217
# [25]	training's binary_logloss: 0.153687	valid_0's binary_logloss: 0.256075
# [26]	training's binary_logloss: 0.149686	valid_0's binary_logloss: 0.251785
# [27]	training's binary_logloss: 0.146076	valid_0's binary_logloss: 0.247738
# [28]	training's binary_logloss: 0.142345	valid_0's binary_logloss: 0.246668
# [29]	training's binary_logloss: 0.139341	valid_0's binary_logloss: 0.246745
# [30]	training's binary_logloss: 0.136613	valid_0's binary_logloss: 0.243385
# [31]	training's binary_logloss: 0.134164	valid_0's binary_logloss: 0.239808
# [32]	training's binary_logloss: 0.131441	valid_0's binary_logloss: 0.234855
# [33]	training's binary_logloss: 0.128903	valid_0's binary_logloss: 0.229278
# [34]	training's binary_logloss: 0.126628	valid_0's binary_logloss: 0.227142
# [35]	training's binary_logloss: 0.124728	valid_0's binary_logloss: 0.22303
# [36]	training's binary_logloss: 0.122625	valid_0's binary_logloss: 0.219477
# [37]	training's binary_logloss: 0.121031	valid_0's binary_logloss: 0.216871
# [38]	training's binary_logloss: 0.119581	valid_0's binary_logloss: 0.215954
# [39]	training's binary_logloss: 0.118189	valid_0's binary_logloss: 0.214147
# [40]	training's binary_logloss: 0.116901	valid_0's binary_logloss: 0.213556
# [41]	training's binary_logloss: 0.115667	valid_0's binary_logloss: 0.211623
# [42]	training's binary_logloss: 0.114501	valid_0's binary_logloss: 0.209741
# [43]	training's binary_logloss: 0.113478	valid_0's binary_logloss: 0.209206
# [44]	training's binary_logloss: 0.112532	valid_0's binary_logloss: 0.207859
# [45]	training's binary_logloss: 0.111461	valid_0's binary_logloss: 0.205543
# [46]	training's binary_logloss: 0.110651	valid_0's binary_logloss: 0.204831
# [47]	training's binary_logloss: 0.10961	valid_0's binary_logloss: 0.2035
# [48]	training's binary_logloss: 0.108792	valid_0's binary_logloss: 0.201372
# [49]	training's binary_logloss: 0.107881	valid_0's binary_logloss: 0.199712
# [50]	training's binary_logloss: 0.107042	valid_0's binary_logloss: 0.199495
# [51]	training's binary_logloss: 0.106203	valid_0's binary_logloss: 0.198117
# [52]	training's binary_logloss: 0.105581	valid_0's binary_logloss: 0.197372
# [53]	training's binary_logloss: 0.104957	valid_0's binary_logloss: 0.196102
# [54]	training's binary_logloss: 0.10414	valid_0's binary_logloss: 0.195574
# [55]	training's binary_logloss: 0.103642	valid_0's binary_logloss: 0.194891
# [56]	training's binary_logloss: 0.102843	valid_0's binary_logloss: 0.19426
# [57]	training's binary_logloss: 0.102393	valid_0's binary_logloss: 0.193307
# [58]	training's binary_logloss: 0.101981	valid_0's binary_logloss: 0.192656
# [59]	training's binary_logloss: 0.101383	valid_0's binary_logloss: 0.19195
# [60]	training's binary_logloss: 0.100702	valid_0's binary_logloss: 0.190514
# [61]	training's binary_logloss: 0.100274	valid_0's binary_logloss: 0.189817
# [62]	training's binary_logloss: 0.0999882	valid_0's binary_logloss: 0.189427
# [63]	training's binary_logloss: 0.0995248	valid_0's binary_logloss: 0.188782
# [64]	training's binary_logloss: 0.0989687	valid_0's binary_logloss: 0.187983
# [65]	training's binary_logloss: 0.0983302	valid_0's binary_logloss: 0.187985
# [66]	training's binary_logloss: 0.0979076	valid_0's binary_logloss: 0.187533
# [67]	training's binary_logloss: 0.0974599	valid_0's binary_logloss: 0.1865
# [68]	training's binary_logloss: 0.0969209	valid_0's binary_logloss: 0.185003
# [69]	training's binary_logloss: 0.0964643	valid_0's binary_logloss: 0.184116
# [70]	training's binary_logloss: 0.0959299	valid_0's binary_logloss: 0.183161
# [71]	training's binary_logloss: 0.0956783	valid_0's binary_logloss: 0.183871
# [72]	training's binary_logloss: 0.0950706	valid_0's binary_logloss: 0.183205
# [73]	training's binary_logloss: 0.0945021	valid_0's binary_logloss: 0.181726
# [74]	training's binary_logloss: 0.0942524	valid_0's binary_logloss: 0.181806
# [75]	training's binary_logloss: 0.0937954	valid_0's binary_logloss: 0.181221
# [76]	training's binary_logloss: 0.0935975	valid_0's binary_logloss: 0.181302
# [77]	training's binary_logloss: 0.0930298	valid_0's binary_logloss: 0.180119
# [78]	training's binary_logloss: 0.0925814	valid_0's binary_logloss: 0.179776
# [79]	training's binary_logloss: 0.0920379	valid_0's binary_logloss: 0.179737
# [80]	training's binary_logloss: 0.0916615	valid_0's binary_logloss: 0.1797
# [81]	training's binary_logloss: 0.0914321	valid_0's binary_logloss: 0.179012
# [82]	training's binary_logloss: 0.0910958	valid_0's binary_logloss: 0.178313
# [83]	training's binary_logloss: 0.0908178	valid_0's binary_logloss: 0.179735
# [84]	training's binary_logloss: 0.0905358	valid_0's binary_logloss: 0.180011
# [85]	training's binary_logloss: 0.0900447	valid_0's binary_logloss: 0.180208
# [86]	training's binary_logloss: 0.0898276	valid_0's binary_logloss: 0.181179
# [87]	training's binary_logloss: 0.0896973	valid_0's binary_logloss: 0.181674
# [88]	training's binary_logloss: 0.0894277	valid_0's binary_logloss: 0.180772
# [89]	training's binary_logloss: 0.0892577	valid_0's binary_logloss: 0.180214
# [90]	training's binary_logloss: 0.0889593	valid_0's binary_logloss: 0.179935
# [91]	training's binary_logloss: 0.0888124	valid_0's binary_logloss: 0.179752
# [92]	training's binary_logloss: 0.0886875	valid_0's binary_logloss: 0.179912
# [93]	training's binary_logloss: 0.0884286	valid_0's binary_logloss: 0.179377
# [94]	training's binary_logloss: 0.0882569	valid_0's binary_logloss: 0.180316
# [95]	training's binary_logloss: 0.0877801	valid_0's binary_logloss: 0.179831
# [96]	training's binary_logloss: 0.0874986	valid_0's binary_logloss: 0.180101
# [97]	training's binary_logloss: 0.0871778	valid_0's binary_logloss: 0.179897
# [98]	training's binary_logloss: 0.0868389	valid_0's binary_logloss: 0.180068
# [99]	training's binary_logloss: 0.0865511	valid_0's binary_logloss: 0.179649
# [100]	training's binary_logloss: 0.0862095	valid_0's binary_logloss: 0.17952
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.61593	valid_0's binary_logloss: 0.645337
# [2]	training's binary_logloss: 0.557411	valid_0's binary_logloss: 0.571588
# [3]	training's binary_logloss: 0.506942	valid_0's binary_logloss: 0.509261
# [4]	training's binary_logloss: 0.463915	valid_0's binary_logloss: 0.456162
# [5]	training's binary_logloss: 0.426835	valid_0's binary_logloss: 0.41047
# [6]	training's binary_logloss: 0.394324	valid_0's binary_logloss: 0.370273
# [7]	training's binary_logloss: 0.365992	valid_0's binary_logloss: 0.335065
# [8]	training's binary_logloss: 0.340873	valid_0's binary_logloss: 0.304186
# [9]	training's binary_logloss: 0.318751	valid_0's binary_logloss: 0.276634
# [10]	training's binary_logloss: 0.299116	valid_0's binary_logloss: 0.252716
# [11]	training's binary_logloss: 0.281675	valid_0's binary_logloss: 0.231095
# [12]	training's binary_logloss: 0.266105	valid_0's binary_logloss: 0.211497
# [13]	training's binary_logloss: 0.252157	valid_0's binary_logloss: 0.193908
# [14]	training's binary_logloss: 0.239425	valid_0's binary_logloss: 0.178659
# [15]	training's binary_logloss: 0.227932	valid_0's binary_logloss: 0.164479
# [16]	training's binary_logloss: 0.217886	valid_0's binary_logloss: 0.151778
# [17]	training's binary_logloss: 0.208602	valid_0's binary_logloss: 0.140358
# [18]	training's binary_logloss: 0.200285	valid_0's binary_logloss: 0.130229
# [19]	training's binary_logloss: 0.19268	valid_0's binary_logloss: 0.121123
# [20]	training's binary_logloss: 0.185547	valid_0's binary_logloss: 0.112502
# [21]	training's binary_logloss: 0.179237	valid_0's binary_logloss: 0.104607
# [22]	training's binary_logloss: 0.17326	valid_0's binary_logloss: 0.0976658
# [23]	training's binary_logloss: 0.167918	valid_0's binary_logloss: 0.0911877
# [24]	training's binary_logloss: 0.163156	valid_0's binary_logloss: 0.0857584
# [25]	training's binary_logloss: 0.158734	valid_0's binary_logloss: 0.0802754
# [26]	training's binary_logloss: 0.154823	valid_0's binary_logloss: 0.0758133
# [27]	training's binary_logloss: 0.151058	valid_0's binary_logloss: 0.0713414
# [28]	training's binary_logloss: 0.147687	valid_0's binary_logloss: 0.0671953
# [29]	training's binary_logloss: 0.144299	valid_0's binary_logloss: 0.0638068
# [30]	training's binary_logloss: 0.141525	valid_0's binary_logloss: 0.0602372
# [31]	training's binary_logloss: 0.138776	valid_0's binary_logloss: 0.0571463
# [32]	training's binary_logloss: 0.136025	valid_0's binary_logloss: 0.0544315
# [33]	training's binary_logloss: 0.133725	valid_0's binary_logloss: 0.0516978
# [34]	training's binary_logloss: 0.131731	valid_0's binary_logloss: 0.0492894
# [35]	training's binary_logloss: 0.12982	valid_0's binary_logloss: 0.0472889
# [36]	training's binary_logloss: 0.128089	valid_0's binary_logloss: 0.0449429
# [37]	training's binary_logloss: 0.126626	valid_0's binary_logloss: 0.0431162
# [38]	training's binary_logloss: 0.125168	valid_0's binary_logloss: 0.0413158
# [39]	training's binary_logloss: 0.123784	valid_0's binary_logloss: 0.0396314
# [40]	training's binary_logloss: 0.12259	valid_0's binary_logloss: 0.0384268
# [41]	training's binary_logloss: 0.120961	valid_0's binary_logloss: 0.0373504
# [42]	training's binary_logloss: 0.11982	valid_0's binary_logloss: 0.0362861
# [43]	training's binary_logloss: 0.118434	valid_0's binary_logloss: 0.0354122
# [44]	training's binary_logloss: 0.117124	valid_0's binary_logloss: 0.0344323
# [45]	training's binary_logloss: 0.116168	valid_0's binary_logloss: 0.0334891
# [46]	training's binary_logloss: 0.115298	valid_0's binary_logloss: 0.0326617
# [47]	training's binary_logloss: 0.114461	valid_0's binary_logloss: 0.0315741
# [48]	training's binary_logloss: 0.113263	valid_0's binary_logloss: 0.0309792
# [49]	training's binary_logloss: 0.11256	valid_0's binary_logloss: 0.0300257
# [50]	training's binary_logloss: 0.111783	valid_0's binary_logloss: 0.0293857
# [51]	training's binary_logloss: 0.110898	valid_0's binary_logloss: 0.0289801
# [52]	training's binary_logloss: 0.110089	valid_0's binary_logloss: 0.0285292
# [53]	training's binary_logloss: 0.109551	valid_0's binary_logloss: 0.0279849
# [54]	training's binary_logloss: 0.108874	valid_0's binary_logloss: 0.027618
# [55]	training's binary_logloss: 0.108179	valid_0's binary_logloss: 0.0269935
# [56]	training's binary_logloss: 0.107575	valid_0's binary_logloss: 0.0265872
# [57]	training's binary_logloss: 0.106924	valid_0's binary_logloss: 0.0260971
# [58]	training's binary_logloss: 0.106496	valid_0's binary_logloss: 0.0256852
# [59]	training's binary_logloss: 0.10592	valid_0's binary_logloss: 0.0251413
# [60]	training's binary_logloss: 0.105457	valid_0's binary_logloss: 0.0247832
# [61]	training's binary_logloss: 0.105064	valid_0's binary_logloss: 0.0243553
# [62]	training's binary_logloss: 0.10473	valid_0's binary_logloss: 0.0240212
# [63]	training's binary_logloss: 0.104192	valid_0's binary_logloss: 0.023892
# [64]	training's binary_logloss: 0.103651	valid_0's binary_logloss: 0.0237353
# [65]	training's binary_logloss: 0.103047	valid_0's binary_logloss: 0.0235441
# [66]	training's binary_logloss: 0.10278	valid_0's binary_logloss: 0.023464
# [67]	training's binary_logloss: 0.102128	valid_0's binary_logloss: 0.0231882
# [68]	training's binary_logloss: 0.101506	valid_0's binary_logloss: 0.0231503
# [69]	training's binary_logloss: 0.10116	valid_0's binary_logloss: 0.0228513
# [70]	training's binary_logloss: 0.100828	valid_0's binary_logloss: 0.0226692
# [71]	training's binary_logloss: 0.100315	valid_0's binary_logloss: 0.0225623
# [72]	training's binary_logloss: 0.0997877	valid_0's binary_logloss: 0.0223952
# [73]	training's binary_logloss: 0.0991251	valid_0's binary_logloss: 0.0223423
# [74]	training's binary_logloss: 0.0988271	valid_0's binary_logloss: 0.0220834
# [75]	training's binary_logloss: 0.0985482	valid_0's binary_logloss: 0.0218361
# [76]	training's binary_logloss: 0.097951	valid_0's binary_logloss: 0.0217272
# [77]	training's binary_logloss: 0.0977733	valid_0's binary_logloss: 0.0216315
# [78]	training's binary_logloss: 0.0972866	valid_0's binary_logloss: 0.0215453
# [79]	training's binary_logloss: 0.0966121	valid_0's binary_logloss: 0.0213662
# [80]	training's binary_logloss: 0.0962126	valid_0's binary_logloss: 0.0210515
# [81]	training's binary_logloss: 0.0960109	valid_0's binary_logloss: 0.0209033
# [82]	training's binary_logloss: 0.0957574	valid_0's binary_logloss: 0.0208174
# [83]	training's binary_logloss: 0.0955994	valid_0's binary_logloss: 0.0207372
# [84]	training's binary_logloss: 0.0953302	valid_0's binary_logloss: 0.0205572
# [85]	training's binary_logloss: 0.0948974	valid_0's binary_logloss: 0.0204706
# [86]	training's binary_logloss: 0.094648	valid_0's binary_logloss: 0.0203256
# [87]	training's binary_logloss: 0.0942105	valid_0's binary_logloss: 0.0202447
# [88]	training's binary_logloss: 0.0939592	valid_0's binary_logloss: 0.0201213
# [89]	training's binary_logloss: 0.0935659	valid_0's binary_logloss: 0.0200404
# [90]	training's binary_logloss: 0.09337	valid_0's binary_logloss: 0.020033
# [91]	training's binary_logloss: 0.0929753	valid_0's binary_logloss: 0.0199398
# [92]	training's binary_logloss: 0.0928844	valid_0's binary_logloss: 0.0199818
# [93]	training's binary_logloss: 0.0926266	valid_0's binary_logloss: 0.0198553
# [94]	training's binary_logloss: 0.0923531	valid_0's binary_logloss: 0.0198242
# [95]	training's binary_logloss: 0.0919605	valid_0's binary_logloss: 0.019772
# [96]	training's binary_logloss: 0.0915584	valid_0's binary_logloss: 0.0197039
# [97]	training's binary_logloss: 0.0912291	valid_0's binary_logloss: 0.019688
# [98]	training's binary_logloss: 0.0910612	valid_0's binary_logloss: 0.0196139
# [99]	training's binary_logloss: 0.0906386	valid_0's binary_logloss: 0.019538
# [100]	training's binary_logloss: 0.0904548	valid_0's binary_logloss: 0.0194793
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.62037	valid_0's binary_logloss: 0.590617
# [2]	training's binary_logloss: 0.560248	valid_0's binary_logloss: 0.53401
# [3]	training's binary_logloss: 0.509252	valid_0's binary_logloss: 0.486109
# [4]	training's binary_logloss: 0.465653	valid_0's binary_logloss: 0.444785
# [5]	training's binary_logloss: 0.42789	valid_0's binary_logloss: 0.409881
# [6]	training's binary_logloss: 0.395011	valid_0's binary_logloss: 0.379257
# [7]	training's binary_logloss: 0.366265	valid_0's binary_logloss: 0.352787
# [8]	training's binary_logloss: 0.340747	valid_0's binary_logloss: 0.329379
# [9]	training's binary_logloss: 0.318356	valid_0's binary_logloss: 0.308795
# [10]	training's binary_logloss: 0.298353	valid_0's binary_logloss: 0.291515
# [11]	training's binary_logloss: 0.280591	valid_0's binary_logloss: 0.280709
# [12]	training's binary_logloss: 0.264793	valid_0's binary_logloss: 0.265561
# [13]	training's binary_logloss: 0.250517	valid_0's binary_logloss: 0.256576
# [14]	training's binary_logloss: 0.237779	valid_0's binary_logloss: 0.244339
# [15]	training's binary_logloss: 0.226148	valid_0's binary_logloss: 0.236847
# [16]	training's binary_logloss: 0.215819	valid_0's binary_logloss: 0.226431
# [17]	training's binary_logloss: 0.206572	valid_0's binary_logloss: 0.217239
# [18]	training's binary_logloss: 0.198002	valid_0's binary_logloss: 0.213402
# [19]	training's binary_logloss: 0.190384	valid_0's binary_logloss: 0.20596
# [20]	training's binary_logloss: 0.183365	valid_0's binary_logloss: 0.202048
# [21]	training's binary_logloss: 0.176694	valid_0's binary_logloss: 0.196212
# [22]	training's binary_logloss: 0.171045	valid_0's binary_logloss: 0.19285
# [23]	training's binary_logloss: 0.165644	valid_0's binary_logloss: 0.190601
# [24]	training's binary_logloss: 0.160916	valid_0's binary_logloss: 0.188555
# [25]	training's binary_logloss: 0.156131	valid_0's binary_logloss: 0.182423
# [26]	training's binary_logloss: 0.151947	valid_0's binary_logloss: 0.178255
# [27]	training's binary_logloss: 0.147984	valid_0's binary_logloss: 0.175844
# [28]	training's binary_logloss: 0.144575	valid_0's binary_logloss: 0.170899
# [29]	training's binary_logloss: 0.141516	valid_0's binary_logloss: 0.168664
# [30]	training's binary_logloss: 0.138228	valid_0's binary_logloss: 0.166542
# [31]	training's binary_logloss: 0.135672	valid_0's binary_logloss: 0.163954
# [32]	training's binary_logloss: 0.133378	valid_0's binary_logloss: 0.162588
# [33]	training's binary_logloss: 0.13086	valid_0's binary_logloss: 0.161862
# [34]	training's binary_logloss: 0.128488	valid_0's binary_logloss: 0.160165
# [35]	training's binary_logloss: 0.126329	valid_0's binary_logloss: 0.157527
# [36]	training's binary_logloss: 0.124627	valid_0's binary_logloss: 0.155543
# [37]	training's binary_logloss: 0.122998	valid_0's binary_logloss: 0.153614
# [38]	training's binary_logloss: 0.121313	valid_0's binary_logloss: 0.153473
# [39]	training's binary_logloss: 0.12004	valid_0's binary_logloss: 0.152517
# [40]	training's binary_logloss: 0.118759	valid_0's binary_logloss: 0.150199
# [41]	training's binary_logloss: 0.117447	valid_0's binary_logloss: 0.149479
# [42]	training's binary_logloss: 0.116363	valid_0's binary_logloss: 0.149679
# [43]	training's binary_logloss: 0.115448	valid_0's binary_logloss: 0.149414
# [44]	training's binary_logloss: 0.114248	valid_0's binary_logloss: 0.149066
# [45]	training's binary_logloss: 0.113209	valid_0's binary_logloss: 0.147314
# [46]	training's binary_logloss: 0.112124	valid_0's binary_logloss: 0.146922
# [47]	training's binary_logloss: 0.111326	valid_0's binary_logloss: 0.145222
# [48]	training's binary_logloss: 0.110518	valid_0's binary_logloss: 0.145047
# [49]	training's binary_logloss: 0.10986	valid_0's binary_logloss: 0.144588
# [50]	training's binary_logloss: 0.109086	valid_0's binary_logloss: 0.144524
# [51]	training's binary_logloss: 0.108487	valid_0's binary_logloss: 0.143043
# [52]	training's binary_logloss: 0.107849	valid_0's binary_logloss: 0.142091
# [53]	training's binary_logloss: 0.107078	valid_0's binary_logloss: 0.141748
# [54]	training's binary_logloss: 0.10646	valid_0's binary_logloss: 0.140816
# [55]	training's binary_logloss: 0.105788	valid_0's binary_logloss: 0.141102
# [56]	training's binary_logloss: 0.105264	valid_0's binary_logloss: 0.140418
# [57]	training's binary_logloss: 0.104757	valid_0's binary_logloss: 0.140117
# [58]	training's binary_logloss: 0.10411	valid_0's binary_logloss: 0.139767
# [59]	training's binary_logloss: 0.103691	valid_0's binary_logloss: 0.139277
# [60]	training's binary_logloss: 0.103389	valid_0's binary_logloss: 0.139358
# [61]	training's binary_logloss: 0.10279	valid_0's binary_logloss: 0.138568
# [62]	training's binary_logloss: 0.102327	valid_0's binary_logloss: 0.138001
# [63]	training's binary_logloss: 0.102049	valid_0's binary_logloss: 0.137574
# [64]	training's binary_logloss: 0.101724	valid_0's binary_logloss: 0.137495
# [65]	training's binary_logloss: 0.101125	valid_0's binary_logloss: 0.137428
# [66]	training's binary_logloss: 0.100438	valid_0's binary_logloss: 0.137246
# [67]	training's binary_logloss: 0.100067	valid_0's binary_logloss: 0.136775
# [68]	training's binary_logloss: 0.0995423	valid_0's binary_logloss: 0.137017
# [69]	training's binary_logloss: 0.0991079	valid_0's binary_logloss: 0.136837
# [70]	training's binary_logloss: 0.0985302	valid_0's binary_logloss: 0.136443
# [71]	training's binary_logloss: 0.0980673	valid_0's binary_logloss: 0.136014
# [72]	training's binary_logloss: 0.0975857	valid_0's binary_logloss: 0.135298
# [73]	training's binary_logloss: 0.0972289	valid_0's binary_logloss: 0.134991
# [74]	training's binary_logloss: 0.0967376	valid_0's binary_logloss: 0.134526
# [75]	training's binary_logloss: 0.0965441	valid_0's binary_logloss: 0.13419
# [76]	training's binary_logloss: 0.0961305	valid_0's binary_logloss: 0.13373
# [77]	training's binary_logloss: 0.0956705	valid_0's binary_logloss: 0.133417
# [78]	training's binary_logloss: 0.0952864	valid_0's binary_logloss: 0.133478
# [79]	training's binary_logloss: 0.0948661	valid_0's binary_logloss: 0.133612
# [80]	training's binary_logloss: 0.0945219	valid_0's binary_logloss: 0.133623
# [81]	training's binary_logloss: 0.0943075	valid_0's binary_logloss: 0.133466
# [82]	training's binary_logloss: 0.0941554	valid_0's binary_logloss: 0.133323
# [83]	training's binary_logloss: 0.0937247	valid_0's binary_logloss: 0.132798
# [84]	training's binary_logloss: 0.0934309	valid_0's binary_logloss: 0.132623
# [85]	training's binary_logloss: 0.093041	valid_0's binary_logloss: 0.132476
# [86]	training's binary_logloss: 0.0925435	valid_0's binary_logloss: 0.131573
# [87]	training's binary_logloss: 0.0922982	valid_0's binary_logloss: 0.131512
# [88]	training's binary_logloss: 0.091919	valid_0's binary_logloss: 0.131109
# [89]	training's binary_logloss: 0.0917187	valid_0's binary_logloss: 0.130938
# [90]	training's binary_logloss: 0.0913406	valid_0's binary_logloss: 0.13033
# [91]	training's binary_logloss: 0.0911987	valid_0's binary_logloss: 0.130078
# [92]	training's binary_logloss: 0.0909285	valid_0's binary_logloss: 0.12982
# [93]	training's binary_logloss: 0.090523	valid_0's binary_logloss: 0.129316
# [94]	training's binary_logloss: 0.0902119	valid_0's binary_logloss: 0.129152
# [95]	training's binary_logloss: 0.0899509	valid_0's binary_logloss: 0.128047
# [96]	training's binary_logloss: 0.0897039	valid_0's binary_logloss: 0.128389
# [97]	training's binary_logloss: 0.0895849	valid_0's binary_logloss: 0.128308
# [98]	training's binary_logloss: 0.0893941	valid_0's binary_logloss: 0.127524
# [99]	training's binary_logloss: 0.0890582	valid_0's binary_logloss: 0.127231
# [100]	training's binary_logloss: 0.0888209	valid_0's binary_logloss: 0.127037
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.612442	valid_0's binary_logloss: 0.705193
# [2]	training's binary_logloss: 0.552381	valid_0's binary_logloss: 0.653016
# ...
# [5]	training's binary_logloss: 0.429132	valid_0's binary_logloss: 0.36212
# [6]	training's binary_logloss: 0.396642	valid_0's binary_logloss: 0.327661
# [7]	training's binary_logloss: 0.367862	valid_0's binary_logloss: 0.297414
# [8]	training's binary_logloss: 0.342639	valid_0's binary_logloss: 0.270936
# [9]	training's binary_logloss: 0.320362	valid_0's binary_logloss: 0.246686
# [10]	training's binary_logloss: 0.300607	valid_0's binary_logloss: 0.224887
# [11]	training's binary_logloss: 0.282925	valid_0's binary_logloss: 0.206226
# [12]	training's binary_logloss: 0.26716	valid_0's binary_logloss: 0.188672
# [13]	training's binary_logloss: 0.252829	valid_0's binary_logloss: 0.172697
# [14]	training's binary_logloss: 0.240218	valid_0's binary_logloss: 0.158837
# [15]	training's binary_logloss: 0.228731	valid_0's binary_logloss: 0.145758
# [16]	training's binary_logloss: 0.218562	valid_0's binary_logloss: 0.134373
# [17]	training's binary_logloss: 0.209264	valid_0's binary_logloss: 0.123981
# [18]	training's binary_logloss: 0.200694	valid_0's binary_logloss: 0.114368
# [19]	training's binary_logloss: 0.193096	valid_0's binary_logloss: 0.105665
# [20]	training's binary_logloss: 0.185803	valid_0's binary_logloss: 0.0979224
# [21]	training's binary_logloss: 0.179028	valid_0's binary_logloss: 0.0902903
# [22]	training's binary_logloss: 0.173081	valid_0's binary_logloss: 0.0838363
# [23]	training's binary_logloss: 0.16775	valid_0's binary_logloss: 0.077878
# [24]	training's binary_logloss: 0.162993	valid_0's binary_logloss: 0.0726724
# [25]	training's binary_logloss: 0.158617	valid_0's binary_logloss: 0.0677814
# [26]	training's binary_logloss: 0.154618	valid_0's binary_logloss: 0.0633001
# [27]	training's binary_logloss: 0.151006	valid_0's binary_logloss: 0.0591874
# [28]	training's binary_logloss: 0.14775	valid_0's binary_logloss: 0.0551599
# [29]	training's binary_logloss: 0.144675	valid_0's binary_logloss: 0.0518434
# [30]	training's binary_logloss: 0.141906	valid_0's binary_logloss: 0.0485177
# [31]	training's binary_logloss: 0.138942	valid_0's binary_logloss: 0.0454454
# [32]	training's binary_logloss: 0.136584	valid_0's binary_logloss: 0.0429558
# [33]	training's binary_logloss: 0.134138	valid_0's binary_logloss: 0.0404738
# [34]	training's binary_logloss: 0.131915	valid_0's binary_logloss: 0.0383448
# [35]	training's binary_logloss: 0.129818	valid_0's binary_logloss: 0.0363484
# [36]	training's binary_logloss: 0.128193	valid_0's binary_logloss: 0.0342127
# [37]	training's binary_logloss: 0.126703	valid_0's binary_logloss: 0.032515
# [38]	training's binary_logloss: 0.124846	valid_0's binary_logloss: 0.0309141
# [39]	training's binary_logloss: 0.123308	valid_0's binary_logloss: 0.0297913
# [40]	training's binary_logloss: 0.121915	valid_0's binary_logloss: 0.028232
# [41]	training's binary_logloss: 0.120465	valid_0's binary_logloss: 0.0270314
# [42]	training's binary_logloss: 0.11923	valid_0's binary_logloss: 0.0260843
# [43]	training's binary_logloss: 0.118051	valid_0's binary_logloss: 0.0251487
# [44]	training's binary_logloss: 0.116877	valid_0's binary_logloss: 0.0241613
# [45]	training's binary_logloss: 0.116031	valid_0's binary_logloss: 0.0232916
# [46]	training's binary_logloss: 0.115053	valid_0's binary_logloss: 0.0223046
# [47]	training's binary_logloss: 0.114102	valid_0's binary_logloss: 0.0214122
# [48]	training's binary_logloss: 0.11328	valid_0's binary_logloss: 0.0205099
# [49]	training's binary_logloss: 0.112438	valid_0's binary_logloss: 0.0198145
# [50]	training's binary_logloss: 0.111656	valid_0's binary_logloss: 0.0192593
# [51]	training's binary_logloss: 0.110693	valid_0's binary_logloss: 0.0187181
# [52]	training's binary_logloss: 0.110049	valid_0's binary_logloss: 0.0182297
# [53]	training's binary_logloss: 0.10932	valid_0's binary_logloss: 0.0177052
# [54]	training's binary_logloss: 0.10835	valid_0's binary_logloss: 0.0172533
# [55]	training's binary_logloss: 0.107939	valid_0's binary_logloss: 0.0168803
# [56]	training's binary_logloss: 0.107176	valid_0's binary_logloss: 0.0165792
# [57]	training's binary_logloss: 0.106651	valid_0's binary_logloss: 0.016241
# [58]	training's binary_logloss: 0.105909	valid_0's binary_logloss: 0.0159184
# [59]	training's binary_logloss: 0.105311	valid_0's binary_logloss: 0.015565
# [60]	training's binary_logloss: 0.104931	valid_0's binary_logloss: 0.0150302
# [61]	training's binary_logloss: 0.104547	valid_0's binary_logloss: 0.0147182
# [62]	training's binary_logloss: 0.104072	valid_0's binary_logloss: 0.0143587
# [63]	training's binary_logloss: 0.103707	valid_0's binary_logloss: 0.0141178
# [64]	training's binary_logloss: 0.102978	valid_0's binary_logloss: 0.0140378
# [65]	training's binary_logloss: 0.102409	valid_0's binary_logloss: 0.0137882
# [66]	training's binary_logloss: 0.10187	valid_0's binary_logloss: 0.0135667
# [67]	training's binary_logloss: 0.101503	valid_0's binary_logloss: 0.013434
# [68]	training's binary_logloss: 0.101217	valid_0's binary_logloss: 0.0133127
# [69]	training's binary_logloss: 0.100866	valid_0's binary_logloss: 0.0130425
# [70]	training's binary_logloss: 0.100374	valid_0's binary_logloss: 0.0129032
# [71]	training's binary_logloss: 0.100083	valid_0's binary_logloss: 0.0127971
# [72]	training's binary_logloss: 0.099535	valid_0's binary_logloss: 0.0127479
# [73]	training's binary_logloss: 0.0990046	valid_0's binary_logloss: 0.0126215
# [74]	training's binary_logloss: 0.0987126	valid_0's binary_logloss: 0.0125015
# [75]	training's binary_logloss: 0.0982195	valid_0's binary_logloss: 0.0124115
# [76]	training's binary_logloss: 0.0977112	valid_0's binary_logloss: 0.0122737
# [77]	training's binary_logloss: 0.097524	valid_0's binary_logloss: 0.0122625
# [78]	training's binary_logloss: 0.0971362	valid_0's binary_logloss: 0.0121065
# [79]	training's binary_logloss: 0.0967826	valid_0's binary_logloss: 0.0120695
# [80]	training's binary_logloss: 0.0962127	valid_0's binary_logloss: 0.0118889
# [81]	training's binary_logloss: 0.096043	valid_0's binary_logloss: 0.0117893
# [82]	training's binary_logloss: 0.0957778	valid_0's binary_logloss: 0.0117854
# [83]	training's binary_logloss: 0.09561	valid_0's binary_logloss: 0.0117852
# [84]	training's binary_logloss: 0.095375	valid_0's binary_logloss: 0.0116905
# [85]	training's binary_logloss: 0.095225	valid_0's binary_logloss: 0.0116842
# [86]	training's binary_logloss: 0.0949987	valid_0's binary_logloss: 0.0115086
# [87]	training's binary_logloss: 0.0947568	valid_0's binary_logloss: 0.0115032
# [88]	training's binary_logloss: 0.0944276	valid_0's binary_logloss: 0.0114872
# [89]	training's binary_logloss: 0.0941368	valid_0's binary_logloss: 0.0114586
# [90]	training's binary_logloss: 0.0939497	valid_0's binary_logloss: 0.0113935
# [91]	training's binary_logloss: 0.0936075	valid_0's binary_logloss: 0.0113041
# [92]	training's binary_logloss: 0.0930577	valid_0's binary_logloss: 0.011279
# [93]	training's binary_logloss: 0.0928887	valid_0's binary_logloss: 0.0112182
# [94]	training's binary_logloss: 0.0925481	valid_0's binary_logloss: 0.0111965
# [95]	training's binary_logloss: 0.0921848	valid_0's binary_logloss: 0.0111731
# [96]	training's binary_logloss: 0.0920044	valid_0's binary_logloss: 0.0111579
# [97]	training's binary_logloss: 0.0918098	valid_0's binary_logloss: 0.0110851
# [98]	training's binary_logloss: 0.0914829	valid_0's binary_logloss: 0.0111364
# [99]	training's binary_logloss: 0.0911205	valid_0's binary_logloss: 0.0111083
# [100]	training's binary_logloss: 0.0907806	valid_0's binary_logloss: 0.0111031
# C:\Users\LMS-Sapkals\.conda\envs\afib\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [1]	training's binary_logloss: 0.614138	valid_0's binary_logloss: 0.676483
# [2]	training's binary_logloss: 0.555766	valid_0's binary_logloss: 0.600478
# [3]	training's binary_logloss: 0.505385	valid_0's binary_logloss: 0.536879
# [4]	training's binary_logloss: 0.462467	valid_0's binary_logloss: 0.484106
# [5]	training's binary_logloss: 0.425388	valid_0's binary_logloss: 0.438263
# [6]	training's binary_logloss: 0.393206	valid_0's binary_logloss: 0.398141
# [7]	training's binary_logloss: 0.364942	valid_0's binary_logloss: 0.36305
# [8]	training's binary_logloss: 0.340089	valid_0's binary_logloss: 0.33213
# [9]	training's binary_logloss: 0.318103	valid_0's binary_logloss: 0.304505
# [10]	training's binary_logloss: 0.29863	valid_0's binary_logloss: 0.280145
# [11]	training's binary_logloss: 0.28121	valid_0's binary_logloss: 0.258943
# [12]	training's binary_logloss: 0.265665	valid_0's binary_logloss: 0.238759
# [13]	training's binary_logloss: 0.251716	valid_0's binary_logloss: 0.221686
# [14]	training's binary_logloss: 0.239027	valid_0's binary_logloss: 0.205749
# [15]	training's binary_logloss: 0.227851	valid_0's binary_logloss: 0.191411
# [16]	training's binary_logloss: 0.21758	valid_0's binary_logloss: 0.178152
# [17]	training's binary_logloss: 0.208537	valid_0's binary_logloss: 0.166386
# [18]	training's binary_logloss: 0.200075	valid_0's binary_logloss: 0.155703
# [19]	training's binary_logloss: 0.192551	valid_0's binary_logloss: 0.146788
# [20]	training's binary_logloss: 0.185545	valid_0's binary_logloss: 0.138291
# [21]	training's binary_logloss: 0.179093	valid_0's binary_logloss: 0.129869
# [22]	training's binary_logloss: 0.173258	valid_0's binary_logloss: 0.122853
# [23]	training's binary_logloss: 0.168152	valid_0's binary_logloss: 0.116557
# [24]	training's binary_logloss: 0.163385	valid_0's binary_logloss: 0.110544
# [25]	training's binary_logloss: 0.159127	valid_0's binary_logloss: 0.104656
# [26]	training's binary_logloss: 0.155203	valid_0's binary_logloss: 0.099979
# [27]	training's binary_logloss: 0.151514	valid_0's binary_logloss: 0.0956896
# [28]	training's binary_logloss: 0.148201	valid_0's binary_logloss: 0.0912141
# [29]	training's binary_logloss: 0.144959	valid_0's binary_logloss: 0.0869968
# [30]	training's binary_logloss: 0.142161	valid_0's binary_logloss: 0.0832421
# [31]	training's binary_logloss: 0.139049	valid_0's binary_logloss: 0.0794325
# [32]	training's binary_logloss: 0.136369	valid_0's binary_logloss: 0.0760124
# [33]	training's binary_logloss: 0.133666	valid_0's binary_logloss: 0.0728422
# [34]	training's binary_logloss: 0.131657	valid_0's binary_logloss: 0.0703161
# [35]	training's binary_logloss: 0.129528	valid_0's binary_logloss: 0.067733
# [36]	training's binary_logloss: 0.127563	valid_0's binary_logloss: 0.0650719
# [37]	training's binary_logloss: 0.125944	valid_0's binary_logloss: 0.0626966
# [38]	training's binary_logloss: 0.124473	valid_0's binary_logloss: 0.0609507
# [39]	training's binary_logloss: 0.122925	valid_0's binary_logloss: 0.0594553
# [40]	training's binary_logloss: 0.121565	valid_0's binary_logloss: 0.0579697
# [41]	training's binary_logloss: 0.120181	valid_0's binary_logloss: 0.0565328
# [42]	training's binary_logloss: 0.119051	valid_0's binary_logloss: 0.055196
# [43]	training's binary_logloss: 0.118006	valid_0's binary_logloss: 0.0538281
# [44]	training's binary_logloss: 0.116856	valid_0's binary_logloss: 0.0527188
# [45]	training's binary_logloss: 0.116042	valid_0's binary_logloss: 0.0514334
# [46]	training's binary_logloss: 0.115228	valid_0's binary_logloss: 0.050294
# [47]	training's binary_logloss: 0.11431	valid_0's binary_logloss: 0.049451
# [48]	training's binary_logloss: 0.113374	valid_0's binary_logloss: 0.0480404
# [49]	training's binary_logloss: 0.112742	valid_0's binary_logloss: 0.0474829
# [50]	training's binary_logloss: 0.111952	valid_0's binary_logloss: 0.0466341
# [51]	training's binary_logloss: 0.111283	valid_0's binary_logloss: 0.0460413
# [52]	training's binary_logloss: 0.110687	valid_0's binary_logloss: 0.044988
# [53]	training's binary_logloss: 0.109881	valid_0's binary_logloss: 0.0438455
# [54]	training's binary_logloss: 0.109395	valid_0's binary_logloss: 0.0430589
# [55]	training's binary_logloss: 0.108885	valid_0's binary_logloss: 0.0427047
# [56]	training's binary_logloss: 0.108273	valid_0's binary_logloss: 0.0419777
# [57]	training's binary_logloss: 0.10753	valid_0's binary_logloss: 0.0411821
# [58]	training's binary_logloss: 0.107032	valid_0's binary_logloss: 0.0408076
# [59]	training's binary_logloss: 0.106368	valid_0's binary_logloss: 0.0402689
# [60]	training's binary_logloss: 0.105832	valid_0's binary_logloss: 0.0395747
# [61]	training's binary_logloss: 0.105203	valid_0's binary_logloss: 0.0390794
# [62]	training's binary_logloss: 0.10444	valid_0's binary_logloss: 0.0385405
# [63]	training's binary_logloss: 0.104038	valid_0's binary_logloss: 0.0382814
# [64]	training's binary_logloss: 0.10336	valid_0's binary_logloss: 0.0379874
# [65]	training's binary_logloss: 0.10261	valid_0's binary_logloss: 0.0375267
# [66]	training's binary_logloss: 0.102265	valid_0's binary_logloss: 0.0373141
# [67]	training's binary_logloss: 0.101738	valid_0's binary_logloss: 0.0371099
# [68]	training's binary_logloss: 0.101443	valid_0's binary_logloss: 0.0367091
# [69]	training's binary_logloss: 0.101124	valid_0's binary_logloss: 0.0365369
# [70]	training's binary_logloss: 0.100466	valid_0's binary_logloss: 0.0359781
# [71]	training's binary_logloss: 0.10018	valid_0's binary_logloss: 0.0357582
# [72]	training's binary_logloss: 0.099924	valid_0's binary_logloss: 0.0354305
# [73]	training's binary_logloss: 0.0994119	valid_0's binary_logloss: 0.0352239
# [74]	training's binary_logloss: 0.0989584	valid_0's binary_logloss: 0.0347626
# [75]	training's binary_logloss: 0.0983026	valid_0's binary_logloss: 0.0343376
# [76]	training's binary_logloss: 0.0979988	valid_0's binary_logloss: 0.0340305
# [77]	training's binary_logloss: 0.0977546	valid_0's binary_logloss: 0.0338168
# [78]	training's binary_logloss: 0.0976249	valid_0's binary_logloss: 0.0336793
# [79]	training's binary_logloss: 0.0972473	valid_0's binary_logloss: 0.033557
# [80]	training's binary_logloss: 0.0969419	valid_0's binary_logloss: 0.0332921
# [81]	training's binary_logloss: 0.09648	valid_0's binary_logloss: 0.0332651
# [82]	training's binary_logloss: 0.0959578	valid_0's binary_logloss: 0.0329453
# [83]	training's binary_logloss: 0.0957125	valid_0's binary_logloss: 0.0329713
# [84]	training's binary_logloss: 0.0951648	valid_0's binary_logloss: 0.0327187
# [85]	training's binary_logloss: 0.0950022	valid_0's binary_logloss: 0.0325235
# [86]	training's binary_logloss: 0.0947069	valid_0's binary_logloss: 0.032412
# [87]	training's binary_logloss: 0.0945311	valid_0's binary_logloss: 0.0323516
# [88]	training's binary_logloss: 0.0940916	valid_0's binary_logloss: 0.0321717
# [89]	training's binary_logloss: 0.0938074	valid_0's binary_logloss: 0.0319697
# [90]	training's binary_logloss: 0.0934457	valid_0's binary_logloss: 0.0319233
# [91]	training's binary_logloss: 0.0930324	valid_0's binary_logloss: 0.0317462
# [92]	training's binary_logloss: 0.0926182	valid_0's binary_logloss: 0.0315811
# [93]	training's binary_logloss: 0.0924142	valid_0's binary_logloss: 0.0313852
# [94]	training's binary_logloss: 0.0921079	valid_0's binary_logloss: 0.0311726
# [95]	training's binary_logloss: 0.0917058	valid_0's binary_logloss: 0.0310276
# [96]	training's binary_logloss: 0.0914837	valid_0's binary_logloss: 0.0308585
# [97]	training's binary_logloss: 0.0913623	valid_0's binary_logloss: 0.0308123
# [98]	training's binary_logloss: 0.0911315	valid_0's binary_logloss: 0.0306859
# [99]	training's binary_logloss: 0.0910031	valid_0's binary_logloss: 0.0305883
# [100]	training's binary_logloss: 0.0907865	valid_0's binary_logloss: 0.0305106
# ---Run time is 5.280834200006211 seconds ---
#
# Accuracy of each fold:
#  [0.914187643020595, 0.9525354969574037, 0.9962216624685138, 0.9292565947242206, 0.9979101358411703, 0.954158215010142, 0.7860812704343765, 0.9979577944179714, 0.9372489959839357, 0.9691289966923925, 0.9832123411978222, 0.990667623833453, 0.8054421768707483, 0.9598726114649682, 0.577435470441299, 0.9893664155959238, 0.9917751884852639, 0.9861511829197923, 0.7502113271344041, 0.9719626168224299, 0.995295124037639, 0.9962335216572504, 0.9987315010570824]
#
# Avg accuracy :
# 0.9317845176986433
#
# Std of accuracy :
# 0.10265051679211624

# %%
print(confusion_matrix(Truth, Output))
print(classification_report(Truth, Output))
print(acc_score)
print(elapsed)
# Out:
# [[23043  1700]
#  [ 1729 18496]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93     24743
#            1       0.92      0.91      0.92     20225
#
#     accuracy                           0.92     44968
#    macro avg       0.92      0.92      0.92     44968
# weighted avg       0.92      0.92      0.92     44968
#
# [0.914187643020595, 0.9525354969574037, 0.9962216624685138, 0.9292565947242206, 0.9979101358411703, 0.954158215010142, 0.7860812704343765, 0.9979577944179714, 0.9372489959839357, 0.9691289966923925, 0.9832123411978222, 0.990667623833453, 0.8054421768707483, 0.9598726114649682, 0.577435470441299, 0.9893664155959238, 0.9917751884852639, 0.9861511829197923, 0.7502113271344041, 0.9719626168224299, 0.995295124037639, 0.9962335216572504, 0.9987315010570824]
# 5.280834200006211
